# %%
from selenium.webdriver.common.by import By
import requests
import re
import pandas as pd
import numpy as np
import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import warnings
warnings.filterwarnings('ignore')
import sqlite3
from bs4 import BeautifulSoup, BeautifulStoneSoup
import json
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('window-size=1920,1080')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent={0}'.format(user_agent))
# options =  webdriver.Chrome('/home/porter/NOTEBOOK/chromedriver',options=options)
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

from datetime import datetime, timedelta

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan

# %%
driver = webdriver.Chrome('/home/lsi8505/chromedriver',options=options)
driver.get("https://www.youtube.com/c/SmartMoney0/videos")
time.sleep(10)

# %%
# driver.execute_script("window.scrollTo(0, 1080)") 
# time.sleep(5)

# %%
html= driver.page_source
html_res = BeautifulSoup(html, "html.parser") 
res_data_table =  html_res.find_all("ytd-grid-video-renderer")[1]
videos_l = []
for vid in range(len(html_res.find_all("ytd-grid-video-renderer"))):
    if "days ago" in html_res.find_all("ytd-grid-video-renderer")[vid].find_all("span", {"class": "style-scope ytd-grid-video-renderer"})[1].text :#("1 day ago" in html_res.find_all("ytd-grid-video-renderer")[vid].find_all("span", {"class": "style-scope ytd-grid-video-renderer"})[1].text) & ("11" not in html_res.find_all("ytd-grid-video-renderer")[vid].find_all("span", {"class": "style-scope ytd-grid-video-renderer"})[1].text):
        
        sub_url = html_res.find_all("ytd-grid-video-renderer")[vid].find_all("a", {"class": "yt-simple-endpoint style-scope ytd-grid-video-renderer"})[0]['href']
        videos_l.append("https://www.youtube.com{}".format( sub_url))
videos_l
# Out:
# ['https://www.youtube.com/watch?v=0UP0t-PksQ8',
#  'https://www.youtube.com/watch?v=RjHK7jlfPcA',
#  'https://www.youtube.com/watch?v=b20B107s_hE',
#  'https://www.youtube.com/watch?v=8WiXYMRfZis',
#  'https://www.youtube.com/watch?v=_VMkyYumBL0',
#  'https://www.youtube.com/shorts/3IzPqG8JXb4',
#  'https://www.youtube.com/watch?v=4cZHA1Igx_s',
#  'https://www.youtube.com/watch?v=kTXHSqW9JQE',
#  'https://www.youtube.com/watch?v=ZfBSfscW9z0',
#  'https://www.youtube.com/watch?v=3qG0MiCTrig',
#  'https://www.youtube.com/watch?v=QpRdFsBexVA',
#  'https://www.youtube.com/watch?v=K2UA9UOnZhE',
#  'https://www.youtube.com/watch?v=mrcNbPIgl7k',
#  'https://www.youtube.com/watch?v=MJ0LNuXAp6k',
#  'https://www.youtube.com/watch?v=0r9VqsR6Nqw',
#  'https://www.youtube.com/watch?v=-_IqXmMicNQ',
#  'https://www.youtube.com/watch?v=r5jjJsSPa6A',
#  'https://www.youtube.com/watch?v=UEFaEkU_JkA',
#  'https://www.youtube.com/watch?v=P1lGLtgJ3DM',
#  'https://www.youtube.com/watch?v=gfRdep9CrcU',
#  'https://www.youtube.com/watch?v=yR3b8ukW9FQ',
#  'https://www.youtube.com/shorts/rr2BxYZOOws',
#  'https://www.youtube.com/watch?v=8jQ5C2av4OA',
#  'https://www.youtube.com/watch?v=H1R3YP-1z7k',
#  'https://www.youtube.com/watch?v=1GJ-O_qVQ4Q']

# %%
df_ttl = pd.DataFrame()
for i in range(len(videos_l)):
    driver.get(videos_l[i])
    time.sleep(10)
    driver.execute_script("window.scrollTo(0, 1080)") 
    time.sleep(5)
    driver.execute_script("window.scrollTo(0, 500)") 
    time.sleep(1)
    
    html_source = driver.page_source
    soup = BeautifulSoup(html_source, 'html.parser')

    id_list = soup.select("div#header-author > h3 > #author-text > span")
    comment_list = soup.select("yt-formatted-string#content-text")

    id_final = []
    comment_final = []
    comment_list

    for i in range(len(comment_list)):
        temp_id = id_list[i].text
        temp_id = temp_id.replace('\n', '')
        temp_id = temp_id.replace('\t', '')
        temp_id = temp_id.replace('    ', '')
        id_final.append(temp_id) # 댓글 작성자

        temp_comment = comment_list[i].text
        temp_comment = temp_comment.replace('\n', '')
        temp_comment = temp_comment.replace('\t', '')
        temp_comment = temp_comment.replace('    ', '')
        comment_final.append(temp_comment) # 댓글 내용

    df_ = pd.DataFrame()
    df_['WRITER'] = id_final
    df_['DATETIME'] =(datetime.now() - timedelta(hours=15)).strftime('%Y%m%d-%H%M%S')
    df_['VIEWS'] = np.nan
    df_['LIKES'] = np.nan
    df_['TITLE'] =  comment_final
    df_['CONTENT'] = np.nan

    df_['SOURCE'] = "Youtube_스마트머니"
    df_['RELATED_ITEM'] = np.nan
    df_['POSITIVITY'] = np.nan
#     for i in range(len(df_)):
#         df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])

    df_['OTHERS'] = df_[['WRITER']].to_dict('records')
    df_['OTHERS'] = df_['OTHERS'].astype(str)
    df_['NUM_REPLY'] =np.nan
    df_['CRAWLING_DATETIME'] = (datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
    df_['URL'] =  videos_l[i]
    df_
    df_ttl = df_ttl.append(df_)
driver.close()
df_ttl
# Out:
# Error : {"status":400,"error":{"errorCode":"E001","message":"Unsupported empty or blank text"}}
# Error : {"status":400,"error":{"errorCode":"E001","message":"Unsupported empty or blank text"}}
#           WRITER         DATETIME  VIEWS  LIKES  \
# 0            이재웅  20220921-134826    NaN    NaN
# 1            문준영  20220921-134826    NaN    NaN
# 2            문준영  20220921-134826    NaN    NaN
# 0     미래에셋 스마트머니  20220921-134846    NaN    NaN
# 1             둉닝  20220921-134846    NaN    NaN
# ..           ...              ...    ...    ...
# 5           뭉게구름  20220921-135600    NaN    NaN
# 6            포메타  20220921-135600    NaN    NaN
# 7             근찡  20220921-135600    NaN    NaN
# 8            김정열  20220921-135600    NaN    NaN
# 9          2000원  20220921-135600    NaN    NaN
#
#                                                 TITLE  CONTENT         SOURCE  \
# 0   서상영 본부장님, 김석환 선임 연구원님, 박희찬 이사님 항상 매크로 관련하여 많이 ...      NaN  Youtube_스마트머니
# 1                                 아주 반가운 시장 뉴스와 분석입니다      NaN  Youtube_스마트머니
# 2                                                          NaN  Youtube_스마트머니
# 0   오늘 방송내용00:00 시작\r01:26 오프닝\r02:00 배터리 업황 점검\r0...      NaN  Youtube_스마트머니
# 1                                    유익한 정보 고맙읍니 다 ∙.      NaN  Youtube_스마트머니
# ..                                                ...      ...            ...
# 5   홍콩h증시 전망에 대해서 말씀 좀 해 주세요. 홍콩h증시 는 els에 많은 영향을 ...      NaN  Youtube_스마트머니
# 6                                          이차전지 소재업체들      NaN  Youtube_스마트머니
# 7                         편집자님 썸네일 무엇?! ㅋㅋㅋ 신경많이 쓰셨네여      NaN  Youtube_스마트머니
# 8                                              미하방가방가      NaN  Youtube_스마트머니
# 9                            갓달러에 대항하다니 신이 벌을 내릴 것이다!      NaN  Youtube_스마트머니
#
#     RELATED_ITEM  POSITIVITY                      OTHERS  NUM_REPLY  \
# 0            NaN   99.974570         {'WRITER': '  이재웅'}        NaN
# 1            NaN   99.960030         {'WRITER': '  문준영'}        NaN
# 2            NaN         NaN         {'WRITER': '  문준영'}        NaN
# 0            NaN    0.027706  {'WRITER': '  미래에셋 스마트머니'}        NaN
# 1            NaN   99.951645          {'WRITER': '  둉닝'}        NaN
# ..           ...         ...                         ...        ...
# 5            NaN    0.141361        {'WRITER': '  뭉게구름'}        NaN
# 6            NaN    0.029945         {'WRITER': '  포메타'}        NaN
# 7            NaN    0.012819          {'WRITER': '  근찡'}        NaN
# 8            NaN    0.020892         {'WRITER': '  김정열'}        NaN
# 9            NaN    0.010187       {'WRITER': '  2000원'}        NaN
#
#    CRAWLING_DATETIME                                          URL
# 0    20220922-134827  https://www.youtube.com/watch?v=b20B107s_hE
# 1    20220922-134827  https://www.youtube.com/watch?v=b20B107s_hE
# 2    20220922-134827  https://www.youtube.com/watch?v=b20B107s_hE
# 0    20220922-134846  https://www.youtube.com/watch?v=b20B107s_hE
# 1    20220922-134846  https://www.youtube.com/watch?v=b20B107s_hE
# ..               ...                                          ...
# 5    20220922-135601  https://www.youtube.com/watch?v=3qG0MiCTrig
# 6    20220922-135601  https://www.youtube.com/watch?v=3qG0MiCTrig
# 7    20220922-135601  https://www.youtube.com/watch?v=3qG0MiCTrig
# 8    20220922-135601  https://www.youtube.com/watch?v=3qG0MiCTrig
# 9    20220922-135601  https://www.youtube.com/watch?v=3qG0MiCTrig
#
# [75 rows x 13 columns]

# %%
df_new = df_ttl[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
# df_new['YYYYMMDD'] = df_new['DATETIME'] .str[:8]
df_new
# Out:
#            SOURCE  RELATED_ITEM         DATETIME  \
# 0   Youtube_스마트머니           NaN  20220921-134826
# 1   Youtube_스마트머니           NaN  20220921-134826
# 2   Youtube_스마트머니           NaN  20220921-134826
# 0   Youtube_스마트머니           NaN  20220921-134846
# 1   Youtube_스마트머니           NaN  20220921-134846
# ..            ...           ...              ...
# 5   Youtube_스마트머니           NaN  20220921-135600
# 6   Youtube_스마트머니           NaN  20220921-135600
# 7   Youtube_스마트머니           NaN  20220921-135600
# 8   Youtube_스마트머니           NaN  20220921-135600
# 9   Youtube_스마트머니           NaN  20220921-135600
#
#                                                 TITLE  CONTENT  POSITIVITY  \
# 0   서상영 본부장님, 김석환 선임 연구원님, 박희찬 이사님 항상 매크로 관련하여 많이 ...      NaN   99.974570
# 1                                 아주 반가운 시장 뉴스와 분석입니다      NaN   99.960030
# 2                                                          NaN         NaN
# 0   오늘 방송내용00:00 시작\r01:26 오프닝\r02:00 배터리 업황 점검\r0...      NaN    0.027706
# 1                                    유익한 정보 고맙읍니 다 ∙.      NaN   99.951645
# ..                                                ...      ...         ...
# 5   홍콩h증시 전망에 대해서 말씀 좀 해 주세요. 홍콩h증시 는 els에 많은 영향을 ...      NaN    0.141361
# 6                                          이차전지 소재업체들      NaN    0.029945
# 7                         편집자님 썸네일 무엇?! ㅋㅋㅋ 신경많이 쓰셨네여      NaN    0.012819
# 8                                              미하방가방가      NaN    0.020892
# 9                            갓달러에 대항하다니 신이 벌을 내릴 것이다!      NaN    0.010187
#
#     NUM_REPLY                                          URL CRAWLING_DATETIME  \
# 0         NaN  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 1         NaN  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 2         NaN  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 0         NaN  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134846
# 1         NaN  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134846
# ..        ...                                          ...               ...
# 5         NaN  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 6         NaN  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 7         NaN  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 8         NaN  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 9         NaN  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
#
#                         OTHERS
# 0          {'WRITER': '  이재웅'}
# 1          {'WRITER': '  문준영'}
# 2          {'WRITER': '  문준영'}
# 0   {'WRITER': '  미래에셋 스마트머니'}
# 1           {'WRITER': '  둉닝'}
# ..                         ...
# 5         {'WRITER': '  뭉게구름'}
# 6          {'WRITER': '  포메타'}
# 7           {'WRITER': '  근찡'}
# 8          {'WRITER': '  김정열'}
# 9        {'WRITER': '  2000원'}
#
# [75 rows x 10 columns]

# %%
df_already = pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE = 'Youtube_스마트머니'",conn)
df_already
# Out:
#            SOURCE RELATED_ITEM         DATETIME  \
# 0   Youtube_스마트머니         None  20220921-134826
# 1   Youtube_스마트머니         None  20220921-134826
# 2   Youtube_스마트머니         None  20220921-134826
# 3   Youtube_스마트머니         None  20220921-134846
# 4   Youtube_스마트머니         None  20220921-134846
# ..            ...          ...              ...
# 70  Youtube_스마트머니         None  20220921-135600
# 71  Youtube_스마트머니         None  20220921-135600
# 72  Youtube_스마트머니         None  20220921-135600
# 73  Youtube_스마트머니         None  20220921-135600
# 74  Youtube_스마트머니         None  20220921-135600
#
#                                                 TITLE CONTENT  POSITIVITY  \
# 0   서상영 본부장님, 김석환 선임 연구원님, 박희찬 이사님 항상 매크로 관련하여 많이 ...    None   99.974570
# 1                                 아주 반가운 시장 뉴스와 분석입니다    None   99.960030
# 2                                                        None         NaN
# 3   오늘 방송내용00:00 시작\r01:26 오프닝\r02:00 배터리 업황 점검\r0...    None    0.027706
# 4                                    유익한 정보 고맙읍니 다 ∙.    None   99.951645
# ..                                                ...     ...         ...
# 70  홍콩h증시 전망에 대해서 말씀 좀 해 주세요. 홍콩h증시 는 els에 많은 영향을 ...    None    0.141361
# 71                                         이차전지 소재업체들    None    0.029945
# 72                        편집자님 썸네일 무엇?! ㅋㅋㅋ 신경많이 쓰셨네여    None    0.012819
# 73                                             미하방가방가    None    0.020892
# 74                           갓달러에 대항하다니 신이 벌을 내릴 것이다!    None    0.010187
#
#    NUM_REPLY                                          URL CRAWLING_DATETIME  \
# 0       None  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 1       None  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 2       None  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134827
# 3       None  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134846
# 4       None  https://www.youtube.com/watch?v=b20B107s_hE   20220922-134846
# ..       ...                                          ...               ...
# 70      None  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 71      None  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 72      None  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 73      None  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
# 74      None  https://www.youtube.com/watch?v=3qG0MiCTrig   20220922-135601
#
#                         OTHERS
# 0          {'WRITER': '  이재웅'}
# 1          {'WRITER': '  문준영'}
# 2          {'WRITER': '  문준영'}
# 3   {'WRITER': '  미래에셋 스마트머니'}
# 4           {'WRITER': '  둉닝'}
# ..                         ...
# 70        {'WRITER': '  뭉게구름'}
# 71         {'WRITER': '  포메타'}
# 72          {'WRITER': '  근찡'}
# 73         {'WRITER': '  김정열'}
# 74       {'WRITER': '  2000원'}
#
# [75 rows x 10 columns]

# %%
df_final = pd.DataFrame() 
df_new = df_new[~df_new['URL'].isin(df_already['URL'])].reset_index(drop=True)
df_final = df_final.append(df_new)
df_final
# Out:
# Empty DataFrame
# Columns: [SOURCE, RELATED_ITEM, DATETIME, TITLE, CONTENT, POSITIVITY, NUM_REPLY, URL, CRAWLING_DATETIME, OTHERS]
# Index: []

# %%
if len(df_final) >0:

    df_final = df_final.reset_index(drop=True)
#     for i in range(len(df_final)):
#         df_final.loc[i,"POSITIVITY"] = get_sentiment(df_final.loc[i,"TITLE"])
    df_final
    df_final.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')  , " Youtube_스마트머니 - SUCCESS  : ",len(df_final))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " Youtube_스마트머니 - NO DATA TO UPDATE")
# Out:
# 20220922-141553  Youtube_스마트머니 - SUCCESS  :  75
