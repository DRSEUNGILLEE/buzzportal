# %%
from selenium import webdriver 
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities 
from time import sleep
from dateutil.relativedelta import relativedelta as rd
import time
from bs4 import BeautifulSoup
import pandas as pd
import logging
from selenium.webdriver.remote.remote_connection import LOGGER
LOGGER.setLevel(logging.WARNING)
from lxml import etree
from bs4 import BeautifulSoup
import pandas as pd 
from selenium.webdriver.common.keys import Keys
from lxml import html 
from io import StringIO
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import requests
import json
import pandas as pd

user_id = 'miraeguest' 
user_pw = '955641' 


headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.39.132 Safari/53.36'}


chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument("--single-process")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--log-level=3")
chrome_options.add_argument('--disable-logging')

#browser = webdriver.Remote('http://127.0.0.1:9515/wd/hub', DesiredCapabilities.CHROME, options=chrome_options) 
browser = webdriver.Chrome('/home/buzzportal/crawling/chromedriver',options=chrome_options)

url = "https://mirae-rpa.some.co.kr/login.html"
browser.get(url)


# 3. id 복사 붙여넣기 
elem_id = browser.find_element(By.NAME, 'username')
# elem_id.click()
# pyperclip.copy(user_id)
elem_id.send_keys(user_id) 

time.sleep(1)


# 4. pw 복사 붙여넣기 
elem_pw = browser.find_element(By.NAME, 'password')
# elem_pw.click()
# pyperclip.copy(user_pw)
elem_pw.send_keys(user_pw) 

time.sleep(1)



# 5. 로그인 버튼 클릭 
#browser.find_element_by_link_text('로그인').click()
browser.find_element(By.XPATH, "/html/body/div/div/div/div/div[2]/form/div[2]/a").click()
time.sleep(3)
html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")   
tree = etree.parse(StringIO(html),parser = etree.HTMLParser()) 

num = 200

URL = "https://mirae-rpa.some.co.kr/api/access_report_list?page=1&limit={}&templateId=&title=&isOwner=false&grpSeqs=".format(str(num))    
browser.get(URL)
report_info = browser.find_element(By.XPATH, '/html/body/pre').text
cont_all = json.loads(report_info)
#print(len(cont_all['data']['list']))

titles = []
urls = []
for el in cont_all['data']['list']:
    ti = el['title']
    rid = el['report_id']
    url = "https://mirae-rpa.some.co.kr/report.html?report_id={}".format(rid)
    titles.append(ti)
    urls.append(url)
# Out:
# /tmp/ipykernel_1660072/549070454.py:40: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('/home/buzzportal/crawling/chromedriver',options=chrome_options)

# %%
tot_df = pd.DataFrame({
  'item_name': [],
  'item_code': [],
  'news_score': [],
  'news_rank': [],
  'chart_score': [],
  'chart_rank': [],
  'fin_score': [],
  'fin_rank': [],
  'price': [],
  'updown': [],
  'market': [],
  'total_value': [],
  'total_rank': [],
  'sector': [],
  'per': [],
  'pbr': [],
  'roe': [],
  'evebitda': [],
  'baedang': [],
  'title_1': [],
  'content_1': [],
  'sent_1': [],
  'title_2': [],
  'content_2': [],
  'sent_2': [],
  'title_3': [],
  'content_3': [],
  'sent_3': [],
  'peer_1': [],
  'peer_2': [],
  'peer_3': [],
  'peer_4': [],
  'roe_1': [],
  'roe_2': [],
  'roe_3': [],
  'roe_4': [],
  'yoy_1': [],
  'yoy_2': [],
  'yoy_3': [],
  'yoy_4': [],
  'safe_1': [],
  'safe_2': [],
  'safe_3': [],
  'safe_4': [],
  'active_1': [],
  'active_2': [],
  'active_3': [],
  'active_4': [],
  'theme_1' : [],
  'theme_2' : [],
  'theme_3' : [],
  'theme_4' : [],
  'theme_1_1' : [],
  'theme_1_2' : [],
  'theme_1_3' : [],
  'theme_1_4' : [],
  'theme_2_1' : [],
  'theme_2_2' : [],
  'theme_2_3' : [],
  'theme_2_4' : [],
  'theme_3_1' : [],
  'theme_3_2' : [],
  'theme_3_3' : [],
  'theme_3_4' : [],
  'theme_4_1' : [],
  'theme_4_2' : [],
  'theme_4_3' : [],
  'theme_4_4' : [],
    'news' : []

})

# %%
for url in urls:
    print(url)
    browser.get(url)
    time.sleep(2)
    html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")   
    time.sleep(3)
    tree = etree.parse(StringIO(html),parser = etree.HTMLParser())     

    
    

    item = tree.xpath('/html/body/div[1]/div/div/div[1]/div/div/h1/a/text()')

    if len(item) == 0:
        print("시장 읽어주는 AI")
        continue
        
    item_name = item[0][:-1]
    
    
    item = tree.xpath('/html/body/div[1]/div/div/div[1]/div/div/h6')[0].text
    date = item[1:-1]
    
    if date == 
    
    
        
    item = tree.xpath('/html/body/div[1]/div/div/div[1]/div/div/h1/a/small')[0].text
    item_code = item[1:-1]

    
    
    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[1]/div[1]/div/h5/em")[0].text
    news_score = item.strip()
    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[1]/div[2]/div[1]/h5/em")[0].text
    news_rank = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[2]/div[1]/div/h5/em")[0].text
    chart_score = item.strip()
    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[2]/div[2]/div[1]/h5/em")[0].text
    chart_rank = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[3]/div[1]/div/h5/em")[0].text
    fin_score = item.strip()
    item = tree.xpath("/html/body/div[1]/div/div/div[4]/div/div/ul/li[3]/div[2]/div[1]/h5/em")[0].text
    fin_rank = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/div/div[2]/h6")[0].text
    price = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/div/div[2]/div/p[2]")[0].text
    updown = item.strip()[:-1]
    
    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[1]/dl[1]/dd")[0].text
    market = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[1]/dl[2]/dd")[0].text
    total_value = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[1]/dl[3]/dd")[0].text
    total_rank = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[1]/dl[4]/dd")[0].text
    sector = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[1]/dl[5]/dd")[0].text
    stock_amount = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[2]/dl[1]/dd")[0].text
    per = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[2]/dl[2]/dd")[0].text
    pbr = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[2]/dl[3]/dd")[0].text
    roe = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[2]/dl[4]/dd")[0].text
    evebitda = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[6]/div/div/div[2]/ul/li[2]/dl[5]/dd")[0].text
    baedang = item.strip()

    title_1 = ""
    title_2 = ""
    title_3 = ""
    content_1 = "" 
    content_2 = "" 
    content_3 = ""
    sent_1=""
    sent_2=""
    sent_3 = ""
    
    try:
    
        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[1]/div[1]/a/h6")[0].text
        title_1 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[1]/div[1]/a/p[1]")[0].text
        content_1 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[1]/div[2]/p")[0].text
        sent_1 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[2]/div[1]/a/h6")[0].text
        title_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[2]/div[1]/a/p[1]")[0].text
        content_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[2]/div[2]/p")[0].text
        sent_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[3]/div[1]/a/h6")[0].text
        title_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[3]/div[1]/a/p[1]")[0].text
        content_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[9]/div/div/ul/li[3]/div[2]/p")[0].text
        sent_3 = item.strip()
    except:
        pass

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[10]/g/text/tspan")[0].text
    peer_1 = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[9]/g/text/tspan")[0].text
    peer_2 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[8]/g/text/tspan")[0].text
    peer_3 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[7]/g/text/tspan")[0].text
    peer_4 = item.strip()
        
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[10]/g/text/tspan")[0].text
    roe_1 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[9]/g/text/tspan")[0].text
    roe_2 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[8]/g/text/tspan")[0].text
    roe_3 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[1]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[7]/g/text/tspan")[0].text
    roe_4 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[2]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[10]/g/text/tspan")[0].text
    yoy_1 = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[2]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[9]/g/text/tspan")[0].text
    yoy_2 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[2]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[8]/g/text/tspan")[0].text
    yoy_3 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[2]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[7]/g/text/tspan")[0].text
    yoy_4 = item.strip()    
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[3]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[10]/g/text/tspan")[0].text
    safe_1 = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[3]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[9]/g/text/tspan")[0].text
    safe_2 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[3]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[8]/g/text/tspan")[0].text
    safe_3 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[3]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[7]/g/text/tspan")[0].text
    safe_4 = item.strip()    
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[4]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[10]/g/text/tspan")[0].text
    active_1 = item.strip()
    
    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[4]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[9]/g/text/tspan")[0].text
    active_2 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[4]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[8]/g/text/tspan")[0].text
    active_3 = item.strip()

    item = tree.xpath("/html/body/div[1]/div/div/div[12]/div/div/div[2]/div[4]/div[2]/div/div/div/svg/g/g[2]/g[1]/g/g/g/g/g/g[1]/g/g[2]/g/g/g/g[3]/g/g[7]/g/text/tspan")[0].text
    active_4 = item.strip()    

    item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]")   
    theme_num = len(item)

    theme_1 = ""
    theme_2 = ""
    theme_3 = ""
    theme_4 = ""
    
    theme_1_1 = ""
    theme_1_2 = ""
    theme_1_3 = ""
    theme_1_4 = ""

    theme_2_1 = ""
    theme_2_2 = ""
    theme_2_3 = ""
    theme_2_4 = ""

    theme_3_1 = ""
    theme_3_2 = ""
    theme_3_3 = ""
    theme_3_4 = ""

    theme_4_1 = ""
    theme_4_2 = ""
    theme_4_3 = ""
    theme_4_4 = ""
    
    try:
        item = tree.xpath("/html/body/div[1]/div/div/div[10]/div/div/div[2]/div[1]/div[2]/ul[1]/li[1]/h6")[0].text
        theme_1 = item.strip()  
    except:
        theme_1 = ""

    try:
        item = tree.xpath("/html/body/div[1]/div/div/div[10]/div/div/div[2]/div[1]/div[2]/ul[2]/li[1]/h6")[0].text
        theme_2 = item.strip()    
    except:
        theme_2 = ""

    try:
        item = tree.xpath("/html/body/div[1]/div/div/div[10]/div/div/div[2]/div[1]/div[2]/ul[3]/li[1]/h6")[0].text
        theme_3 = item.strip()    
    except:
        theme_3 = ""

    try:
        item = tree.xpath("/html/body/div[1]/div/div/div[10]/div/div/div[2]/div[1]/div[2]/ul[4]/li[1]/h6")[0].text
        theme_4 = item.strip()    
    except:
        theme_4 = ""        
        
    try:
        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[1]/li[1]/h6".format(str(i)))[0].text
        theme_1_1 = item.strip()    

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[1]/li[2]/h6/a".format(str(i)))[0].text
        theme_1_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[1]/li[3]/h6/a".format(str(i)))[0].text
        theme_1_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[1]/li[4]/h6/a".format(str(i)))[0].text
        theme_1_4 = item.strip()    

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[2]/li[1]/h6".format(str(i)))[0].text
        theme_2_1 = item.strip()    

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[2]/li[2]/h6/a".format(str(i)))[0].text
        theme_2_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[2]/li[3]/h6/a".format(str(i)))[0].text
        theme_2_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[2]/li[4]/h6/a".format(str(i)))[0].text
        theme_2_4 = item.strip()       

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[3]/li[1]/h6".format(str(i)))[0].text
        theme_3_1 = item.strip()    

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[3]/li[2]/h6/a".format(str(i)))[0].text
        theme_3_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[3]/li[3]/h6/a".format(str(i)))[0].text
        theme_3_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[3]/li[4]/h6/a".format(str(i)))[0].text
        theme_3_4 = item.strip()       

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[4]/li[1]/h6".format(str(i)))[0].text
        theme_4_1 = item.strip()    

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[4]/li[2]/h6/a".format(str(i)))[0].text
        theme_4_2 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[4]/li[3]/h6/a".format(str(i)))[0].text
        theme_4_3 = item.strip()

        item = tree.xpath("/html/body/div[1]/div/div/div[15]/div/div/div[2]/ul[4]/li[4]/h6/a".format(str(i)))[0].text
        theme_4_4 = item.strip()       
    except:
        pass

    item = tree.xpath("/html/body/script[2]")
    #item = tree.xpath("/html/body/div[1]/div/div/div[8]/div/div/div[3]/div/div/div/svg/g/g[2]/g[2]/g/g[5]/g[2]/g/g/text[1]")
    tt = item[0].text

    start_idx = tt.find("var reportData =")
    end_idx = tt.find("var coverInfo =")
    tt_2 = tt[start_idx+17: end_idx].strip()[:-1]        
    data = json.loads(tt_2.strip())
    total_news = ""
    for row in data['all_rendering_data']:
        try:
            if 'diy.50f807b8868d3b467a87c9fa0db699ea.test' in row['id']:
                total_news = row
            else:
                continue
        except:
            continue  
    
        
    data = {'item_name': item_name, 'item_code': item_code, 'news_score': news_score, 'news_rank': news_rank, 'chart_score': chart_score, 'chart_rank':chart_rank, 'fin_score': fin_score, 'fin_rank': fin_rank, 'price': price, 'updown': updown, 'market': market, 'total_value': total_value, 'total_rank': total_rank, 'sector': sector, 'per': per, 'pbr': pbr, 'roe': roe, 'evebitda': evebitda, 'baedang': baedang, 'title_1': title_1, 'content_1':content_1, 'sent_1': sent_1, 'title_2':title_2, 'content_2':content_2, 'sent_2':sent_2, 'title_3': title_3, 'content_3':content_3, 'sent_3': sent_3 , 'peer_1': peer_1,  'peer_2': peer_2,  'peer_3': peer_3,  'peer_4': peer_4, 'roe_1': roe_1,'roe_2': roe_2,'roe_3': roe_3,'roe_4': roe_4, 'yoy_1':yoy_1, 'yoy_2':yoy_2, 'yoy_3':yoy_3, 'yoy_4':yoy_4, 'safe_1': safe_1, 'safe_2': safe_2, 'safe_3': safe_3, 'safe_4': safe_4, 'active_1': active_1, 'active_2': active_2, 'active_3': active_3, 'active_4': active_4,'theme_1':theme_1, 'theme_2':theme_2, 'theme_3':theme_3, 'theme_4':theme_4,  'theme_1_1': theme_1_1,'theme_1_2': theme_1_2,'theme_1_3': theme_1_3,'theme_1_4': theme_1_4, 'theme_2_1': theme_2_1, 'theme_2_2': theme_2_2, 'theme_2_3': theme_2_3, 'theme_2_4': theme_2_4, 'theme_3_1': theme_3_1, 'theme_3_2': theme_3_2, 'theme_3_3': theme_3_3, 'theme_3_4': theme_3_4, 'theme_4_1': theme_4_1, 'theme_4_2': theme_4_2, 'theme_4_3': theme_4_3, 'theme_4_4': theme_4_4 , 'news' : json.dumps(total_news, ensure_ascii=False) }
    df= pd.DataFrame(data, index=[0])
    tot_df = pd.concat([tot_df, df])
    tot_df.to_excel('vaiv_221121_4.xlsx', index=False)        
    
    time.sleep(1)
# Out:
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2757
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2756
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2755
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2754
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2753
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2752
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2751
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2750
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2749
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2748
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2747
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2746
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2745
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2744
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2743
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2742
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2741
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2740
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2739
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2738
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2737
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2736
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2735
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2734
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2733
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2732
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2731
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2730
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2729
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2728
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2727
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2726
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2725
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2724
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2723
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2722
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2721
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2720
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2719
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2718
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2717
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2716
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2715
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2714
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2713
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2712
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2711
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2710
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2709
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2708
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2707
# 시장 읽어주는 AI
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2706
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2705
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2704
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2703
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2702
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2701
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2700
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2699
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2698
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2697
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2696
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2695
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2694
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2693
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2692
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2691
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2690
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2689
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2688
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2687
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2686
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2685
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2684
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2683
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2682
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2681
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2680
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2679
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2678
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2677
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2676
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2675
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2674
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2673
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2672
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2671
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2670
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2669
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2668
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2667
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2666
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2665
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2664
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2663
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2662
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2661
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2660
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2659
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2658
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2657
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2656
# 시장 읽어주는 AI
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2655
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2654
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2653
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2652
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2651
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2650
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2649
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2648
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2647
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2646
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2645
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2644
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2643
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2642
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2641
# https://mirae-rpa.some.co.kr/report.html?report_id=1_2640
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
#       2 print(url)
#       3 browser.get(url)
# ----> 4 time.sleep(2)
#       5 html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")
#       6 time.sleep(3)
#
# KeyboardInterrupt:

# %%
url = urls[0]

# %%
url = "https://mirae-rpa.some.co.kr/report.html?report_id=1_2737"

# %%
browser.get(url)
time.sleep(2)
html = browser.execute_script("return document.getElementsByTagName('html')[0].innerHTML")   
time.sleep(3)
tree = etree.parse(StringIO(html),parser = etree.HTMLParser())     

item = tree.xpath("/html/body/script[2]")
#item = tree.xpath("/html/body/div[1]/div/div/div[8]/div/div/div[3]/div/div/div/svg/g/g[2]/g[2]/g/g[5]/g[2]/g/g/text[1]")

# %%
tt = item[0].text

start_idx = tt.find("var reportData =")
end_idx = tt.find("var coverInfo =")
tt_2 = tt[start_idx+17: end_idx].strip()[:-1]

# %%
tt_2
# Out:
# '{"report_id":"1_2737","template_id":"report_diy","template_name":"DIY 보고서","complete":true,"configs":[{"name":"title","class":"config_text","type":"text","label":"제목","default":"DIY 보고서","options":{"style":"text"},"value":"린드먼아시아_277070_2022.11.20"},{"name":"sub_title","class":"config_text","type":"text","label":"부제목","default":"","options":{"style":"text"},"value":""},{"name":"info","class":"config_list","type":"list","label":"추가정보","default":[],"options":{"item_type":{"class":"config_object","type":"object","name":"item","label":"항목","default":{"name":"","value":""},"options":{"notnull":true,"repr_field":"name","fields":[{"class":"config_text","type":"text","name":"name","label":"필드명","default":"","options":{"style":"text"}},{"class":"config_text","type":"text","name":"value","label":"필드값","default":"","options":{"style":"text"}}]}}},"value":[]}],"layout":{"title":"컨테이너","processing":false,"visible":true,"level":"","errors":{},"children":[{"title":"모바일 종목보고서 헤더","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.d4f6333c7eeef4ae45535f93c969eeb4"},{"title":"내비게이션","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.8f2f52e454ad3db07716c1f3d5c68aba"},{"title":"섹션 상단 모양","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.1a697900e0e24ee4726106466634e513"},{"title":"섹션제목 - 개요","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.364c5bd1d019194834872da20ab7895d"},{"title":"종목 지수","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.3a267a787d2b8f5f8107d643a5a82201"},{"title":"주가 (3개월)","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.4c73eacf2522e5190ce7f5e3d62da8ab"},{"title":"기본 정보","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.a70249e95173b102b176d69bf12ceaa7"},{"title":"섹션제목 - 뉴스 분석","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.bb72e2492962f19bf947062db370f637"},{"title":"투자 심리 분석","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.50f807b8868d3b467a87c9fa0db699ea"},{"title":"종목 대표 뉴스","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.9a039b2a772bab717fc1e4cf9ca982ea"},{"title":"섹션제목 - 경쟁사 분석","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.f11a66901ccc14b89596e47343b5ea03"},{"title":"경쟁사 분석_주가 추이 비교","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.c989cb3b5314755f8e8a97bd997dc981"},{"title":"경쟁사 분석_재무 비교","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.ec71ba31f41727cebf7cc1268a8b3b97"},{"title":"섹션제목 - 종목 테마 분석","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.bee068f394f28bd57c8667ac4b5f347c"},{"title":"테마 분석_언급량 추이","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.40a7144f79b5819ff0e2cb22790c312f"},{"title":"테마 분석_관련 종목","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.f85f27d749bbdaf42ce5c777ad2cd1a9"},{"title":"위험고지 문구","processing":false,"visible":true,"level":"","errors":{},"children":[],"component_id":"diy.5e123b51ab92c7c3baec4d46617b1b30"}],"component_id":"diy"},"all_rendering_data":[{"type":"text","id":"diy.d4f6333c7eeef4ae45535f93c969eeb4.header","visible":true,"data":"<div class=\\"report-top blue\\"><div class=\\"report-inner\\"><div class=\\"report-top-title\\"><h6>2022년 11월 20일(일)</h6><h1><span class=\\"title-desc\\">종목 읽어주는 AI</span><a onclick=\\"calApp(\'quote_stock\', \'277070\')\\">린드먼아시아&nbsp<small>(277070)</small></a></h1></div></div></div>","options":{"xlsx":false}},{"type":"text","id":"diy.8f2f52e454ad3db07716c1f3d5c68aba.nav","visible":true,"data": ...

# %%
import json
data = json.loads(tt_2)

# %%
data
# Out:
# {'report_id': '1_2737',
#  'template_id': 'report_diy',
#  'template_name': 'DIY 보고서',
#  'complete': True,
#  'configs': [{'name': 'title',
#    'class': 'config_text',
#    'type': 'text',
#    'label': '제목',
#    'default': 'DIY 보고서',
#    'options': {'style': 'text'},
#    'value': '린드먼아시아_277070_2022.11.20'},
#   {'name': 'sub_title',
#    'class': 'config_text',
#    'type': 'text',
#    'label': '부제목',
#    'default': '',
#    'options': {'style': 'text'},
#    'value': ''},
#   {'name': 'info',
#    'class': 'config_list',
#    'type': 'list',
#    'label': '추가정보',
#    'default': [],
#    'options': {'item_type': {'class': 'config_object',
#      'type': 'object',
#      'name': 'item',
#      'label': '항목',
#      'default': {'name': '', 'value': ''},
#      'options': {'notnull': True,
#       'repr_field': 'name',
#       'fields': [{'class': 'config_text',
#         'type': 'text',
#         'name': 'name',
#         'label': '필드명',
#         'default': '',
#         'options': {'style': 'text'}},
#        {'class': 'config_text',
#         'type': 'text',
#         'name': 'value',
#         'label': '필드값',
#         'default': '',
#         'options': {'style': 'text'}}]}}},
#    'value': []}],
#  'layout': {'title': '컨테이너',
#   'processing': False,
#   'visible': True,
#   'level': '',
#   'errors': {},
#   'children': [{'title': '모바일 종목보고서 헤더',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.d4f6333c7eeef4ae45535f93c969eeb4'},
#    {'title': '내비게이션',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.8f2f52e454ad3db07716c1f3d5c68aba'},
#    {'title': '섹션 상단 모양',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.1a697900e0e24ee4726106466634e513'},
#    {'title': '섹션제목 - 개요',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.364c5bd1d019194834872da20ab7895d'},
#    {'title': '종목 지수',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.3a267a787d2b8f5f8107d643a5a82201'},
#    {'title': '주가 (3개월)',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab'},
#    {'title': '기본 정보',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.a70249e95173b102b176d69bf12ceaa7'},
#    {'title': '섹션제목 - 뉴스 분석',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.bb72e2492962f19bf947062db370f637'},
#    {'title': '투자 심리 분석',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.50f807b8868d3b467a87c9fa0db699ea'},
#    {'title': '종목 대표 뉴스',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea'},
#    {'title': '섹션제목 - 경쟁사 분석',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.f11a66901ccc14b89596e47343b5ea03'},
#    {'title': '경쟁사 분석_주가 추이 비교',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.c989cb3b5314755f8e8a97bd997dc981'},
#    {'title': '경쟁사 분석_재무 비교',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.ec71ba31f41727cebf7cc1268a8b3b97'},
#    {'title': '섹션제목 - 종목 테마 분석',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.bee068f394f28bd57c8667ac4b5f347c'},
#    {'title': '테마 분석_언급량 추이',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.40a7144f79b5819ff0e2cb22790c312f'},
#    {'title': '테마 분석_관련 종목',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9'},
#    {'title': '위험고지 문구',
#     'processing': False,
#     'visible': True,
#     'level': '',
#     'errors': {},
#     'children': [],
#     'component_id': 'diy.5e123b51ab92c7c3baec4d46617b1b30'}],
#   'component_id': 'diy'},
#  'all_rendering_data': [{'type': 'text',
#    'id': 'diy.d4f6333c7eeef4ae45535f93c969eeb4.header',
#    'visible': True,
#    'data': '<div class="report-top blue"><div class="report-inner"><div class="report-top-title"><h6>2022년 11월 20일(일)</h6><h1><span class="title-desc">종목 읽어주는 AI</span><a onclick="calApp(\'quote_stock\', \'277070\')">린드먼아시아&nbsp<small>(277070)</small></a></h1></div></div></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.8f2f52e454ad3db07716c1f3d5c68aba.nav',
#    'visible': True,
#    'data': '<nav class="report-gnb blue"><div class="report-inner"><ul class="report-gnb-list"><li class="active"><a href="#section1" onclick="activeGnb(this);">개요</a></li><li><a href="#section2" onclick="activeGnb(this);">뉴스 분석</a></li><li><a href="#section3" onclick="activeGnb(this);">경쟁사 분석</a></li><li><a href="#section4" onclick="activeGnb(this);">종목 테마 분석</a></li></ul></div></nav>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.1a697900e0e24ee4726106466634e513.radius',
#    'visible': True,
#    'data': '<div class="report-radius blue"></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae title">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.nav_unit',
#    'visible': True,
#    'data': '<div class="report-gnb-point" id="section1"></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.section_title',
#    'visible': True,
#    'data': '<div class="report-section-title"><h2>개요</h2><div class="report-base-date"><p>기준일: 2022년 11월 20일</p></div></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.364c5bd1d019194834872da20ab7895d.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.title_help',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>종목 지수<i class="ri-information-line report-bottomsheet-trigger" onclick="openBottomSheet(this);"></i><div class="report-bottomsheet"><div class="bg" onclick="closeBottomSheet(this);"></div><div class="content"><div class="title"><h6>종목 지수란 무엇인가요?</h6><button type="button" onclick="closeBottomSheet(this);"><i class="ri-close-line"></i></button></div><div class="text"><p> 종목의 뉴스 점수, 차트 점수, 재무 점수를 분석하여 순위와 함께 보여드려요.</p><div class="gutter"></div>                   <h4 class="type-gray">점수 기준</h4><h5>뉴스 점수란 무엇인가요?</h5><p>뉴스 점수는 종목 뉴스에 나타난 긍정 심리&middot;부정 심리, 종목과 관련된 키워드의 언급량을 토대로 계산해요. 점수가 높을수록 최근 긍정적인 관심을 많이 받고 있다는 것을 의미해요.</p><div class="gutter"></div><h5>차트 점수란 무엇인가요?</h5><p>차트 점수는 주가, 거래량을 분석해서 현재 주가의 흐름을 평가한 점수에요. 과거 비슷한 주가 패턴을 보였던 종목의 이후 주가 흐름과 기술적 분석 방법을 종합하여 점수를 계산했어요. 점수가 높을수록 긍정적인 주가 흐름을 보이고 있음을 의미해요.</p><h6 class="type-gray">차트 점수에서 사용한 기술적 지표</h6><ul class="list"><li>이동평균선, 이격도, MACD 오실레이터, 스토캐스틱, 상대강도지수(RSI) 등</li></ul><div class="gutter"></div><h5>재무 점수란 무엇인가요?</h5><p>재무 점수는 재무적인 측면에서 종목의 수익성, 성장성, 안정성, 활동성을 평가한 점수에요. 점수가 높을수록 재무적으로 좋은 평가를 받는 종목임을 의미해요.</p><h6 class="type-gray">재무 점수에서 사용한 지표</h6><ul class="list"><li>수익성: 영업이익률, 순이익률, 자기자본이익률(ROE), 총자산이익률(ROA)</li><li>성장성: 매출액증가율, 영업이익증가율</li><li>안정성: 부채비율, 순부채비율, 당좌비율, 이자보상비율, 자본유보율</li><li>활동성: 총자산회전율, 매출채권회전율, 잉여현금흐름율</li></ul><h5>출처</h5><ul class="list"><li>점수: (주)바이브컴퍼니</li><li>점수 산정 데이터: FnGuide</li></ul></div></div></div></h3></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.score_donut',
#    'visible': True,
#    'data': '<ul class="report-score-list"><li>   <div class="score"><svg width="100%" height="100%" viewBox="0 0 42 42" role="img"><filter id="shadow" color-interpolation-filters="sRGB"><feDropShadow dx="0.5" dy="0.5" stdDeviation="1.5" flood-opacity="0.4"></feDropShadow></filter><circle class="donut-segment" cx="21" cy="21" r="15.91549430918954" stroke-linecap="round"fill="transparent" stroke=#ff8822 stroke-width="3.2"stroke-dasharray="74 26" stroke-dashoffset="25"></circle><circle class="donut-hole" cx="21" cy="21" r="14.51549430918954" fill="#fff"filter="url(#shadow)"></circle></svg><div class="score-label"><h5><em>74</em>점</h5><h6>뉴스</h6></div></div></div><div class="rank"><div class="rank-text"><h5><em>336</em>위</h5><h6>/2250</h6></div><div class="rank-grade"><div class="rank-grade-bar"><span style="width: 70%;"></span></div><div class="rank-grade-text"><p style="right: 70%;">3등급</p></div></div></li><li>   <div class="score"><svg width="100%" height="100%" viewBox="0 0 42 42" role="img"><filter id="shadow" color-interpolation-filters="sRGB"><feDropShadow dx="0.5" dy="0.5" stdDeviation="1.5" flood-opacity="0.4"></feDropShadow></filter><circle class="donut-segment" cx="21" cy="21" r="15.91549430918954" stroke-linecap="round"fill="transparent" stroke=#f0b36b stroke-width="3.2"stroke-dasharray="73 27" stroke-dashoffset="25"></circle><circle class="donut-hole" cx="21" cy="21" r="14.51549430918954" fill="#fff"filter="url(#shadow)"></circle></svg><div class="score-label"><h5><em>73</em>점</h5><h6>차트</h6></div></div></div><div class="rank"><div class="rank-text"><h5><em>283</em>위</h5><h6>/2250</h6></div><div class="rank-grade"><div class="rank-grade-bar"><span style="width: 70%;"></span></div><div class="rank-grade-text"><p style="right: 70%;">3등급</p></div></div></li><li>   <div class="score"><svg width="100%" height="100%" viewBox="0 0 42 42" role="img"><filter id="shadow" color-interpolation-filters="sRGB"><feDropShadow dx="0.5" dy="0.5" stdDeviation="1.5" flood-opacity="0.4"></feDropShadow></filter><circle class="donut-segment" cx="21" cy="21" r="15.91549430918954" stroke-linecap="round"fill="transparent" stroke=#9fa0a0 stroke-width="3.2"stroke-dasharray="71 29" stroke-dashoffset="25"></circle><circle class="donut-hole" cx="21" cy="21" r="14.51549430918954" fill="#fff"filter="url(#shadow)"></circle></svg><div class="score-label"><h5><em>71</em>점</h5><h6>재무</h6></div></div></div><div class="rank"><div class="rank-text"><h5><em>1183</em>위</h5><h6>/2250</h6></div><div class="rank-grade"><div class="rank-grade-bar"><span style="width: 50%;"></span></div><div class="rank-grade-text"><p style="right: 50%;">5등급</p></div></div></li></ul>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.3a267a787d2b8f5f8107d643a5a82201.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.box_title',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>주가 (3개월)</h3></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.report_chart_open',
#    'visible': True,
#    'data': '<div class="report-chart report-chart-price">',
#    'options': {'xlsx': False}},
#   {'type': 'amchart_common',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.price_chart',
#    'visible': True,
#    'data': [{'date': '2022-08-23',
#      'close': 4560.0,
#      'sector_close': 3150.8362049542516,
#      'div_close': 4.56,
#      'div_sector_close': 3.1508362049542518},
#     {'date': '2022-08-24',
#      'close': 4540.0,
#      'sector_close': 3140.0666150021975,
#      'div_close': 4.54,
#      'div_sector_close': 3.1400666150021976},
#     {'date': '2022-08-25',
#      'close': 4650.0,
#      'sector_close': 3174.3204975792614,
#      'div_close': 4.65,
#      'div_sector_close': 3.1743204975792616},
#     {'date': '2022-08-26',
#      'close': 4650.0,
#      'sector_close': 3175.5391189553093,
#      'div_close': 4.65,
#      'div_sector_close': 3.1755391189553093},
#     {'date': '2022-08-29',
#      'close': 4610.0,
#      'sector_close': 3130.472055384791,
#      'div_close': 4.61,
#      'div_sector_close': 3.130472055384791},
#     {'date': '2022-08-30',
#      'close': 4630.0,
#      'sector_close': 3144.457780828299,
#      'div_close': 4.63,
#      'div_sector_close': 3.144457780828299},
#     {'date': '2022-08-31',
#      'close': 4655.0,
#      'sector_close': 3157.2990149653283,
#      'div_close': 4.655,
#      'div_sector_close': 3.157299014965328},
#     {'date': '2022-09-01',
#      'close': 4530.0,
#      'sector_close': 3112.8617809942525,
#      'div_close': 4.53,
#      'div_sector_close': 3.1128617809942525},
#     {'date': '2022-09-02',
#      'close': 4520.0,
#      'sector_close': 3109.7422489958985,
#      'div_close': 4.52,
#      'div_sector_close': 3.1097422489958984},
#     {'date': '2022-09-05',
#      'close': 4385.0,
#      'sector_close': 3084.261291498003,
#      'div_close': 4.385,
#      'div_sector_close': 3.084261291498003},
#     {'date': '2022-09-06',
#      'close': 4420.0,
#      'sector_close': 3097.4686046409597,
#      'div_close': 4.42,
#      'div_sector_close': 3.0974686046409596},
#     {'date': '2022-09-07',
#      'close': 4370.0,
#      'sector_close': 3063.1804171134177,
#      'div_close': 4.37,
#      'div_sector_close': 3.0631804171134176},
#     {'date': '2022-09-08',
#      'close': 4385.0,
#      'sector_close': 3087.258332431176,
#      'div_close': 4.385,
#      'div_sector_close': 3.0872583324311758},
#     {'date': '2022-09-13',
#      'close': 4405.0,
#      'sector_close': 3135.388819196556,
#      'div_close': 4.405,
#      'div_sector_close': 3.135388819196556},
#     {'date': '2022-09-14',
#      'close': 4490.0,
#      'sector_close': 3128.665536313557,
#      'div_close': 4.49,
#      'div_sector_close': 3.128665536313557},
#     {'date': '2022-09-15',
#      'close': 4525.0,
#      'sector_close': 3116.204969284301,
#      'div_close': 4.525,
#      'div_sector_close': 3.116204969284301},
#     {'date': '2022-09-16',
#      'close': 4640.0,
#      'sector_close': 3107.903957994166,
#      'div_close': 4.64,
#      'div_sector_close': 3.107903957994166},
#     {'date': '2022-09-19',
#      'close': 4300.0,
#      'sector_close': 3075.344766400271,
#      'div_close': 4.3,
#      'div_sector_close': 3.075344766400271},
#     {'date': '2022-09-20',
#      'close': 4295.0,
#      'sector_close': 3091.073691616501,
#      'div_close': 4.295,
#      'div_sector_close': 3.091073691616501},
#     {'date': '2022-09-21',
#      'close': 4295.0,
#      'sector_close': 3083.482680535804,
#      'div_close': 4.295,
#      'div_sector_close': 3.0834826805358038},
#     {'date': '2022-09-22',
#      'close': 4235.0,
#      'sector_close': 3049.510222927551,
#      'div_close': 4.235,
#      'div_sector_close': 3.049510222927551},
#     {'date': '2022-09-23',
#      'close': 4155.0,
#      'sector_close': 3012.7178922966405,
#      'div_close': 4.155,
#      'div_sector_close': 3.0127178922966404},
#     {'date': '2022-09-26',
#      'close': 3910.0,
#      'sector_close': 2934.471290615354,
#      'div_close': 3.91,
#      'div_sector_close': 2.9344712906153543},
#     {'date': '2022-09-27',
#      'close': 3710.0,
#      'sector_close': 2921.341955841981,
#      'div_close': 3.71,
#      'div_sector_close': 2.921341955841981},
#     {'date': '2022-09-28',
#      'close': 3440.0,
#      'sector_close': 2865.9988175412964,
#      'div_close': 3.44,
#      'div_sector_close': 2.8659988175412963},
#     {'date': '2022-09-29',
#      'close': 3415.0,
#      'sector_close': 2859.6639371210204,
#      'div_close': 3.415,
#      'div_sector_close': 2.85966393712102},
#     {'date': '2022-09-30',
#      'close': 3435.0,
#      'sector_close': 2845.0378977232463,
#      'div_close': 3.435,
#      'div_sector_close': 2.8450378977232464},
#     {'date': '2022-10-04',
#      'close': 3635.0,
#      'sector_close': 2867.3856804198626,
#      'div_close': 3.635,
#      'div_sector_close': 2.8673856804198627},
#     {'date': '2022-10-05',
#      'close': 3600.0,
#      'sector_close': 2847.7958813948444,
#      'div_close': 3.6,
#      'div_sector_close': 2.8477958813948443},
#     {'date': '2022-10-06',
#      'close': 3700.0,
#      'sector_close': 2857.673296543012,
#      'div_close': 3.7,
#      'div_sector_close': 2.857673296543012},
#     {'date': '2022-10-07',
#      'close': 3700.0,
#      'sector_close': 2848.9278776004844,
#      'div_close': 3.7,
#      'div_sector_close': 2.8489278776004845},
#     {'date': '2022-10-11',
#      'close': 3515.0,
#      'sector_close': 2738.4515727069956,
#      'div_close': 3.515,
#      'div_sector_close': 2.7384515727069956},
#     {'date': '2022-10-12',
#      'close': 3430.0,
#      'sector_close': 2701.430740568573,
#      'div_close': 3.43,
#      'div_sector_close': 2.701430740568573},
#     {'date': '2022-10-13',
#      'close': 3410.0,
#      'sector_close': 2604.4309375804196,
#      'div_close': 3.41,
#      'div_sector_close': 2.6044309375804198},
#     {'date': '2022-10-14',
#      'close': 3490.0,
#      'sector_close': 2621.8690482343723,
#      'div_close': 3.49,
#      'div_sector_close': 2.6218690482343723},
#     {'date': '2022-10-17',
#      'close': 3450.0,
#      'sector_close': 2590.3815248613932,
#      'div_close': 3.45,
#      'div_sector_close': 2.5903815248613933},
#     {'date': '2022-10-18',
#      'close': 3535.0,
#      'sector_close': 2614.3030866856625,
#      'div_close': 3.535,
#      'div_sector_close': 2.6143030866856627},
#     {'date': '2022-10-19',
#      'close': 3580.0,
#      'sector_close': 2587.754425128249,
#      'div_close': 3.58,
#      'div_sector_close': 2.587754425128249},
#     {'date': '2022-10-20',
#      'close': 3595.0,
#      'sector_close': 2516.0948023342485,
#      'div_close': 3.595,
#      'div_sector_close': 2.5160948023342486},
#     {'date': '2022-10-21',
#      'close': 3480.0,
#      'sector_close': 2476.9718790377465,
#      'div_close': 3.48,
#      'div_sector_close': 2.4769718790377464},
#     {'date': '2022-10-24',
#      'close': 3515.0,
#      'sector_close': 2493.8727531355808,
#      'div_close': 3.515,
#      'div_sector_close': 2.4938727531355807},
#     {'date': '2022-10-25',
#      'close': 3600.0,
#      'sector_close': 2498.8217667522963,
#      'div_close': 3.6,
#      'div_sector_close': 2.4988217667522963},
#     {'date': '2022-10-26',
#      'close': 3600.0,
#      'sector_close': 2502.428300275492,
#      'div_close': 3.6,
#      'div_sector_close': 2.5024283002754917},
#     {'date': '2022-10-27',
#      'close': 3600.0,
#      'sector_close': 2556.0763092126454,
#      'div_close': 3.6,
#      'div_sector_close': 2.5560763092126453},
#     {'date': '2022-10-28',
#      'close': 3590.0,
#      'sector_close': 2541.504301536667,
#      'div_close': 3.59,
#      'div_sector_close': 2.541504301536667},
#     {'date': '2022-10-31',
#      'close': 3640.0,
#      'sector_close': 2546.4131213624887,
#      'div_close': 3.64,
#      'div_sector_close': 2.5464131213624888},
#     {'date': '2022-11-01',
#      'close': 3650.0,
#      'sector_close': 2563.5619410626496,
#      'div_close': 3.65,
#      'div_sector_close': 2.5635619410626496},
#     {'date': '2022-11-02',
#      'close': 3630.0,
#      'sector_close': 2552.1440873309775,
#      'div_close': 3.63,
#      'div_sector_close': 2.5521440873309773},
#     {'date': '2022-11-03',
#      'close': 3535.0,
#      'sector_close': 2537.4805909989896,
#      'div_close': 3.535,
#      'div_sector_close': 2.5374805909989897},
#     {'date': '2022-11-04',
#      'close': 3435.0,
#      'sector_close': 2531.129676471599,
#      'div_close': 3.435,
#      'div_sector_close': 2.531129676471599},
#     {'date': '2022-11-07',
#      'close': 3545.0,
#      'sector_close': 2555.8403208788004,
#      'div_close': 3.545,
#      'div_sector_close': 2.5558403208788003},
#     {'date': '2022-11-08',
#      'close': 3600.0,
#      'sector_close': 2567.522270233641,
#      'div_close': 3.6,
#      'div_sector_close': 2.567522270233641},
#     {'date': '2022-11-09',
#      'close': 3695.0,
#      'sector_close': 2592.4894245166784,
#      'div_close': 3.695,
#      'div_sector_close': 2.5924894245166783},
#     {'date': '2022-11-10',
#      'close': 3795.0,
#      'sector_close': 2587.917914142421,
#      'div_close': 3.795,
#      'div_sector_close': 2.587917914142421},
#     {'date': '2022-11-11',
#      'close': 3835.0,
#      'sector_close': 2660.4166633032437,
#      'div_close': 3.835,
#      'div_sector_close': 2.6604166633032436},
#     {'date': '2022-11-14',
#      'close': 3870.0,
#      'sector_close': 2675.125606959976,
#      'div_close': 3.87,
#      'div_sector_close': 2.675125606959976},
#     {'date': '2022-11-15',
#      'close': 3880.0,
#      'sector_close': 2678.390584330396,
#      'div_close': 3.88,
#      'div_sector_close': 2.678390584330396},
#     {'date': '2022-11-16',
#      'close': 3870.0,
#      'sector_close': 2679.7059550407453,
#      'div_close': 3.87,
#      'div_sector_close': 2.6797059550407454},
#     {'date': '2022-11-17',
#      'close': 3885.0,
#      'sector_close': 2658.800577656043,
#      'div_close': 3.885,
#      'div_sector_close': 2.6588005776560433},
#     {'date': '2022-11-18',
#      'close': 4020.0,
#      'sector_close': 2655.9660747231733,
#      'color': '#F58220',
#      'opacity': 1,
#      'bullet_scale': 0.6,
#      'sector_color': '#F58220',
#      'div_close': 4.02,
#      'div_sector_close': 2.6559660747231733}],
#    'options': {'version': 4,
#     'chart_type': 'XYChart',
#     'chart_config': {'type': 'XYChart',
#      'fontSize': 12,
#      'colors': {'list': ['#F58220', '#AD624E']},
#      'xAxes': [{'type': 'DateAxis',
#        'visible': True,
#        'tooltip': {'fontSize': 10},
#        'renderer': {'grid': {'template': {'location': 0,
#           'disabled': True,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'}},
#         'labels': {'disabled': True, 'dy': 5, 'fill': '#A0A6A8'}},
#        'skipEmptyPeriods': True,
#        'axisRanges': [{'date': '2022-09-01',
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '09/01'}},
#         {'date': '2022-10-04',
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '10/04'}},
#         {'date': '2022-11-01',
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '11/01'}}],
#        'tooltipDateFormat': 'yyyy년 M월 dd일',
#        'periodChangeDateFormats': {'month': '[bolder]yyyy년 M월[/]'}}],
#      'yAxes': [{'type': 'ValueAxis',
#        'renderer': {'maxLabelPosition': 1,
#         'grid': {'template': {'strokeOpacity': 1,
#           'stroke': '#ECEFF4',
#           'disabled': True}},
#         'labels': {'disabled': True},
#         'baseGrid': {'disabled': True}},
#        'tooltip': {'disabled': True},
#        'id': 'left_axis',
#        'adjustLabelPrecision': False,
#        'title': {'type': 'Label',
#         'truncate': True,
#         'maxWidth': 144,
#         'text': '린드먼아시아(천)',
#         'ellipsis': '···(천)'},
#        'strictMinMax': True,
#        'min': 3.3,
#        'max': 4.7,
#        'axisRanges': [{'label': {'text': '4.7'}, 'value': 4.7},
#         {'label': {'text': '4.0'}, 'value': 4.0},
#         {'label': {'text': '3.3'}, 'value': 3.3}]},
#       {'type': 'ValueAxis',
#        'renderer': {'maxLabelPosition': 1,
#         'grid': {'template': {'strokeOpacity': 1,
#           'stroke': '#ECEFF4',
#           'disabled': True}},
#         'labels': {'disabled': True},
#         'baseGrid': {'disabled': True},
#         'opposite': True},
#        'tooltip': {'disabled': True},
#        'id': 'right_axis',
#        'adjustLabelPrecision': False,
#        'title': {'type': 'Label',
#         'truncate': True,
#         'maxWidth': 144,
#         'text': '기타금융(천)',
#         'ellipsis': '···(천)'},
#        'strictMinMax': True,
#        'min': 2.4,
#        'max': 3.2,
#        'axisRanges': [{'label': {'text': '3.2'}, 'value': 3.2},
#         {'label': {'text': '2.8'}, 'value': 2.8},
#         {'label': {'text': '2.4'}, 'value': 2.4}]}],
#      'series': [{'type': 'LineSeries',
#        'name': '린드먼아시아',
#        'tooltip': {'fontSize': 10,
#         'autoTextColor': False,
#         'label': {'fill': '#FFFFFF'}},
#        'tooltipText': '{name}: {close.formatNumber("#,###")}',
#        'dataFields': {'valueY': 'div_close', 'dateX': 'date'},
#        'yAxis': 'left_axis',
#        'strokeWidth': 2,
#        'bullets': [{'type': 'CircleBullet',
#          'propertyFields': {'scale': 'bullet_scale',
#           'fill': 'bullet_color',
#           'fillOpacity': 'opacity'},
#          'fillOpacity': 0,
#          'strokeWidth': 0}]},
#       {'type': 'LineSeries',
#        'name': '기타금융',
#        'tooltip': {'fontSize': 10,
#         'autoTextColor': False,
#         'label': {'fill': '#FFFFFF'}},
#        'tooltipText': '{name}: {sector_close.formatNumber("#,###.00")}',
#        'dataFields': {'valueY': 'div_sector_close', 'dateX': 'date'},
#        'yAxis': 'right_axis',
#        'strokeWidth': 2,
#        'bullets': [{'type': 'CircleBullet',
#          'propertyFields': {'scale': 'bullet_scale',
#           'fill': 'sector_bullet_color',
#           'fillOpacity': 'opacity'},
#          'fillOpacity': 0,
#          'strokeWidth': 0}]}],
#      'dateFormatter': {'dateFormat': 'M월'},
#      'numberFormatter': {'type': 'NumberFormatter', 'numberFormat': '#,###.0'},
#      'legend': {'type': 'Legend'},
#      'cursor': {'type': 'XYCursor', 'behavior': 'none'}},
#     'chart_div_options': {'classes': 'customChartArea',
#      'styles': {'height': '200px'}},
#     'inner_div_options': {'classes': 'customChart'},
#     'xlsx_name': '주가 (3개월)',
#     'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.report_chart_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.4c73eacf2522e5190ce7f5e3d62da8ab.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.box_title',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>기본 정보<i class="ri-information-line report-bottomsheet-trigger" onclick="openBottomSheet(this);"></i><div class="report-bottomsheet"><div class="bg" onclick=closeBottomSheet(this);"></div><div class="content"><div class="title"><h6>기본 정보는 무엇인가요?</h6><button type="button" onclick="closeBottomSheet(this);"><i class="ri-close-line"></i></button></div><div class="text"><p>기업을 알기 위해 필요한 기초 시장 정보, 재무 정보, 배당 정보를 나타낸 데이터에요.</p><h6>데이터 출처</h6><ul class="list"><li>FnGuide</li></ul></div></div></div></h3></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.keydata_open',
#    'visible': True,
#    'data': '<div class="report-key-data">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.title-price',
#    'visible': True,
#    'data': '<div class="title"><div class="title-name"><h6><a onclick="calApp(\'quote_Stock\', \'277070\')">린드먼아시아<span class="number"> (277070)</span></a></h6></div><div class="title-price up"><h6>4,020</h6><div class="title-price-rate"><p>▲135</p><p>+3.47%</p></div></div></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.key_data_table',
#    'visible': True,
#    'data': '<ul class="list"><li><dl><dt>시장</dt><dd>코스닥</dd></dl><dl><dt>시가총액</dt><dd>550억원</dd></dl><dl><dt>시가총액순위</dt><dd>코스닥 1249위</dd></dl><dl><dt>섹터</dt><dd>기타금융</dd></dl><dl><dt>발행주식주</dt><dd>1,369만주</dd></dl></li><li><dl><dt>PER</dt><dd>18.89배</dd></dl><dl><dt>PBR</dt><dd>0.98배</dd></dl><dl><dt>ROE</dt><dd>5.48%</dd></dl><dl><dt>EV/EBITDA</dt><dd>29.42배</dd></dl><dl><dt>현금배당수익률</dt><dd>1.04%</dd></dl></li></ul>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.keydata_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.a70249e95173b102b176d69bf12ceaa7.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae title">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.nav_unit',
#    'visible': True,
#    'data': '<div class="report-gnb-point" id="section2"></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.section_title',
#    'visible': True,
#    'data': '<div class="report-section-title"><h2>뉴스 분석</h2><div class="report-base-date"><p>기준일: 2022년 11월 20일</p></div></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.bb72e2492962f19bf947062db370f637.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.box_title',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>투자 심리 분석<i class="ri-information-line report-bottomsheet-trigger" onclick="openBottomSheet(this);"></i><div class="report-bottomsheet"><div class="bg" onclick=closeBottomSheet(this);"></div><div class="content"><div class="title"><h6>투자 심리 분석은 무엇인가요?</h6><button type="button" onclick="closeBottomSheet(this);"><i class="ri-close-line"></i></button></div><div class="text"><p>종목 뉴스에 나타난 긍정적, 부정적 심리의 시간적 추이를 시각화해서 보여드려요. 종목 뉴스가 나오는 빈도에 따라 X축의 기간이 달라져요.</p><h6>시각화 규칙</h6><ul class="list"><li>원 색상: AI 긍&middot;부정 뉴스 모델이 예측한 종목 뉴스의 긍정적, 부정적 심리 강도를 나타내요.</li><li>원 크기: AI 중요도 뉴스 모델이 예측한 종목 뉴스의 중요도를 나타내요.</li><li>원 안 아이콘 표시: 뉴스의 중요도와 작성 시간을 고려하여 상위 3개의 뉴스에 표시해요.</li></ul></div></div></div></h3><p>주목할 만한 종목 뉴스에 나타난 심리를 분석해드려요.</p></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.legend',
#    'visible': True,
#    'data': '<div class="report-treemap-legend transparent"><h6 class="negative">부정</h6><div class="gauge"><span style="height: 15px;">0</span><span style="height: 15px;"></span><span style="height: 15px;"></span><span style="height: 15px;">50</span><span style="height: 15px;"></span><span style="height: 15px;"></span><span style="height: 15px;">100</span></div><h6 class="positive">긍정</h6></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.report_chart_open',
#    'visible': True,
#    'data': '<div class="report-chart report-chart-bubble" style="height: 250px;">',
#    'options': {'xlsx': False}},
#   {'type': 'amchart_common',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.test',
#    'visible': True,
#    'data': [{'date': '2022-11-18 08:24:02',
#      'title': "한화자산운용 민간모펀드, PE부문 첫 GP '린드먼아시아'\r\n최소 결성액 대부분 출자 확약, 높은 GP커밋 비중도 가점 요인",
#      'senti_score': 68.185,
#      'sqrt_score': 7.08858236885204,
#      'score': 50.248,
#      'thumb_path': '',
#      'color': 'rgba(229, 125, 0, 0.7)',
#      'thumb_width': 11,
#      'thumb_height': 11},
#     {'date': '2022-11-17 16:57:00',
#      'title': '린드먼아시아, 20억 규모 자사주 취득 신탁계약 체결',
#      'senti_score': 98.01,
#      'sqrt_score': 7.578509088204618,
#      'score': 57.43379999999999,
#      'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg',
#      'color': 'rgba(224, 92, 96, 0.7)',
#      'thumb_width': 12,
#      'thumb_height': 12},
#     {'date': '2022-10-28 08:14:11',
#      'title': "스마트스코어, '뻐꾸기 박사장 창업' 골프백 제조사 인수 추진\r\n박노준 대표·아주IB 보유 '포시즌' 지분 90% 대상, FI로 린드먼아시아 유치",
#      'senti_score': 75.09,
#      'sqrt_score': 6.591835859606942,
#      'score': 43.452299999999994,
#      'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg',
#      'color': 'rgba(229, 125, 0, 0.7)',
#      'thumb_width': 11,
#      'thumb_height': 11},
#     {'date': '2022-10-10 08:30:00',
#      'title': '바이오플러스, 린드먼아시아 대상 200억 유상증자',
#      'senti_score': 72.5,
#      'sqrt_score': 7.836517083500807,
#      'score': 61.410999999999994,
#      'thumb_path': '',
#      'color': 'rgba(229, 125, 0, 0.7)',
#      'thumb_width': 12,
#      'thumb_height': 12},
#     {'date': '2022-10-07 17:31:00',
#      'title': '“단순 자금 투자 아니다” 바이오플러스가 린드먼아시아와 손잡은 이유',
#      'senti_score': 86.39,
#      'sqrt_score': 7.921085784158634,
#      'score': 62.7436,
#      'thumb_path': '',
#      'color': 'rgba(224, 92, 96, 0.7)',
#      'thumb_width': 12,
#      'thumb_height': 12},
#     {'date': '2022-09-06 14:34:00',
#      'title': '린드먼아시아, 종속사 린드먼아시아투자조합12호 해산사유 발생',
#      'senti_score': 39.07,
#      'sqrt_score': 7.747612535484722,
#      'score': 60.0255,
#      'thumb_path': '',
#      'color': 'rgba(141, 200, 232, 0.7)',
#      'thumb_width': 12,
#      'thumb_height': 12},
#     {'date': '2022-07-14 07:30:23',
#      'title': '린드먼아시아 투자 성장 에이치피오, 신기사 진출\r\n100% 출자 자회사 피오인베스트먼트, 신기사 인가 획득…금융권 경험 인력 이사회 배치',
#      'senti_score': 83.265,
#      'sqrt_score': 6.517092910186259,
#      'score': 42.472500000000004,
#      'thumb_path': '',
#      'color': 'rgba(229, 125, 0, 0.7)',
#      'thumb_width': 11,
#      'thumb_height': 11}],
#    'options': {'version': 4,
#     'chart_type': 'XYChart',
#     'chart_config': {'type': 'XYChart',
#      'fontSize': 12,
#      'colors': {'list': ['#67b7dc',
#        '#fdd400',
#        '#84b761',
#        '#cc4748',
#        '#cd82ad',
#        '#2f4074',
#        '#448e4d',
#        '#b7b83f',
#        '#b9783f',
#        '#b93e3d',
#        '#913167',
#        '#5292AF',
#        '#C9A700',
#        '#6A934E',
#        '#A3393A',
#        '#A36689',
#        '#25335B',
#        '#37723E',
#        '#939332',
#        '#935F32',
#        '#933030',
#        '#752753']},
#      'xAxes': [{'type': 'DateAxis',
#        'visible': True,
#        'tooltip': {'fontSize': 10},
#        'renderer': {'grid': {'template': {'location': 0,
#           'disabled': True,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'}},
#         'labels': {'disabled': True, 'dy': 5}},
#        'skipEmptyPeriods': False,
#        'axisRanges': [{'date': '2022-05-25',
#          'endDate': '2022-11-26',
#          'grid': {'disabled': False},
#          'tick': {'disabled': True, 'length': 0},
#          'label': {'paddingTop': 20,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'fontWeight': 'bolder',
#           'text': '2022년'}},
#         {'date': '2022-11-26',
#          'grid': {'disabled': False},
#          'tick': {'disabled': True},
#          'label': ''},
#         {'date': '2022-05-25',
#          'endDate': '2022-06-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 0,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '5월'}},
#         {'date': '2022-06-01',
#          'endDate': '2022-07-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '6월'}},
#         {'date': '2022-07-01',
#          'endDate': '2022-08-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '7월'}},
#         {'date': '2022-08-01',
#          'endDate': '2022-09-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '8월'}},
#         {'date': '2022-09-01',
#          'endDate': '2022-10-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '9월'}},
#         {'date': '2022-10-01',
#          'endDate': '2022-11-01',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '10월'}},
#         {'date': '2022-11-01',
#          'endDate': '2022-11-26',
#          'grid': {'disabled': False},
#          'tick': {'disabled': False,
#           'length': 5,
#           'strokeOpacity': 1,
#           'stroke': '#ebedee'},
#          'label': {'paddingTop': 0,
#           'location': 0.5,
#           'horizontalCenter': 'middle',
#           'text': '11월'}}],
#        'baseInterval': {'timeUnit': 'second', 'count': 1},
#        'min': 1653404400000,
#        'max': 1669388400000}],
#      'yAxes': [{'type': 'ValueAxis',
#        'renderer': {'maxLabelPosition': 1,
#         'grid': {'template': {'strokeOpacity': 0, 'stroke': '#ebedee'}},
#         'baseGrid': {'disabled': True},
#         'labels': {'disabled': True}},
#        'tooltip': {'disabled': True},
#        'max': 105.58850908820462,
#        'min': 0,
#        'strictMinMax': True,
#        'axisRanges': [{'value': 0,
#          'grid': {'strokeOpacity': 1, 'stroke': '#ebedee', 'strokeWidth': 2},
#          'label': {'verticalCenter': 'middle', 'text': '0'}},
#         {'value': 50,
#          'grid': {'strokeOpacity': 1, 'stroke': '#ebedee', 'strokeWidth': 1.5},
#          'label': {'verticalCenter': 'middle', 'text': '50'}},
#         {'value': 100,
#          'grid': {'strokeOpacity': 1, 'stroke': '#ebedee', 'strokeWidth': 2},
#          'label': {'verticalCenter': 'middle', 'text': '100'}},
#         {'value': 105.58850908820462,
#          'grid': {'strokeOpacity': 1, 'stroke': '#ebedee', 'strokeWidth': 1},
#          'label': {'verticalCenter': 'middle', 'text': ''}}]}],
#      'series': [{'type': 'LineSeries',
#        'name': '',
#        'bullets': {'values': [{'type': 'CircleBullet',
#           'strokeOpacity': 0,
#           'tooltipText': "[bold]제목[/]: {title}\n[bold]일자[/]: {dateX.formatDate('yyyy년 M월 dd일 HH시 MM분 ss초')}\n[bold]긍정 점수[/]: {valueY.formatNumber('##.00')}\n[bold]중요도[/]: {score.formatNumber('##.00')}",
#           'propertyFields': {'fill': 'color', 'scale': 'sqrt_score'},
#           'circle': {'type': 'Circle', 'radius': 1.5}},
#          {'type': 'Bullet',
#           'children': [{'type': 'Image',
#             'propertyFields': {'href': 'thumb_path',
#              'width': 'thumb_width',
#              'height': 'thumb_height',
#              'fill': 'color'},
#             'horizontalCenter': 'middle',
#             'verticalCenter': 'middle',
#             'maxWidth': 160,
#             'wrap': True,
#             'tooltipText': "[bold]제목[/]: {title}\n[bold]일자[/]: {dateX.formatDate('yyyy년 M월 dd일 HH시 MM분 ss초')}\n[bold]긍정 점수[/]: {valueY.formatNumber('##.00')}\n[bold]중요도[/]: {score.formatNumber('##.00')}"}]}]},
#        'strokeOpacity': 0,
#        'dataFields': {'valueY': 'senti_score', 'dateX': 'date'},
#        'tooltip': {'label': {'maxWidth': 160, 'wrap': True, 'fill': '#FFFFFF'},
#         'autoTextColor': False},
#        'sequencedInterpolation': True,
#        'sequencedInterpolationDelay': 100}],
#      'dateFormatter': {'inputDateFormat': 'yyyy-MM-dd HH:mm:ss'}},
#     'chart_div_options': {'classes': 'customChartArea',
#      'styles': {'height': '250px'}},
#     'inner_div_options': {'classes': 'customChart'},
#     'xlsx_name': '투자 심리 분석',
#     'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.report_chart_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.ref',
#    'visible': True,
#    'data': '<div class="report-text"><p>원의 색깔은 뉴스의 긍정 점수를 나타내며 원의 크기는 뉴스의 중요도를 의미해요. 원 선택시 자세한 정보를 볼 수 있어요.</p></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea.box_title',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>종목 대표 뉴스<i class="ri-information-line report-bottomsheet-trigger" onclick="openBottomSheet(this);"></i><div class="report-bottomsheet"><div class="bg" onclick=closeBottomSheet(this);"></div><div class="content"><div class="title"><h6>종목 대표 뉴스는 무엇인가요?</h6><button type="button" onclick="closeBottomSheet(this);"><i class="ri-close-line"></i></button></div><div class="text"><p>2가지 AI모델을 활용해서 투자하는데 중요하다고 생각되는 종목 뉴스를 보여드려요.</p><h6>사용 AI 모델</h6><ul class="list"><li>중요도 모델: 애널리스트가 투자에 중요하다고 생각하는 뉴스 데이터와                             조회수가 높은 뉴스 데이터를 바탕으로 &#39;중요 뉴스&#39;를 판단하도록 학습한                                 인공지능 모델로 뉴스의 중요도를 계산해요.</li><li>긍부정 모델: 긍정적인 어조가 담긴 뉴스, 부정적인 어조가 담긴 뉴스 데이터를                             바탕으로 학습한 인공지능 모델로 뉴스에 드러난 심리를 예측해요.</li></ul></div></div></div></h3><p>인공지능(AI)이 분석한 중요도 높은 대표 뉴스를 선별해드려요.</p></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.9a039b2a772bab717fc1e4cf9ca982ea.news_list',
#    'visible': True,
# ...
#         'label': {'fill': '#FFFFFF'}},
#        'tooltipText': '{name}: {moving_average_7.formatNumber("#,###.00")}',
#        'dataFields': {'valueY': 'norm_value', 'dateX': 'date'},
#        'yAxis': 'left_axis',
#        'data': [{'date': '2022-08-23',
#          'moving_average_7': 1890.5905342857184,
#          'norm_value': -1.6017629344140445},
#         {'date': '2022-08-24',
#          'moving_average_7': 1928.468220000004,
#          'norm_value': -1.4807080535940913},
#         {'date': '2022-08-25',
#          'moving_average_7': 2060.788080000004,
#          'norm_value': -1.0578214759072277},
#         {'date': '2022-08-26',
#          'moving_average_7': 2078.136294285718,
#          'norm_value': -1.0023775919107962},
#         {'date': '2022-08-27',
#          'moving_average_7': 2074.146825000004,
#          'norm_value': -1.0151277037460307},
#         {'date': '2022-08-28',
#          'moving_average_7': 2140.341845000004,
#          'norm_value': -0.8035722693032072},
#         {'date': '2022-08-29',
#          'moving_average_7': 2193.62443071429,
#          'norm_value': -0.6332842239332873},
#         {'date': '2022-08-30',
#          'moving_average_7': 2236.0249714285756,
#          'norm_value': -0.4977745615535305},
#         {'date': '2022-08-31',
#          'moving_average_7': 2273.023445000004,
#          'norm_value': -0.3795295916128185},
#         {'date': '2022-09-01',
#          'moving_average_7': 2188.465763571433,
#          'norm_value': -0.6497710241269132},
#         {'date': '2022-09-02',
#          'moving_average_7': 2174.0520807142902,
#          'norm_value': -0.6958363163311289},
#         {'date': '2022-09-03',
#          'moving_average_7': 2188.1390871428616,
#          'norm_value': -0.6508150629952244},
#         {'date': '2022-09-04',
#          'moving_average_7': 2180.3645700000043,
#          'norm_value': -0.675661967667817},
#         {'date': '2022-09-05',
#          'moving_average_7': 2186.6321771428616,
#          'norm_value': -0.6556310597230183},
#         {'date': '2022-09-06',
#          'moving_average_7': 2137.437096428576,
#          'norm_value': -0.8128556768159727},
#         {'date': '2022-09-07',
#          'moving_average_7': 2152.6219300000043,
#          'norm_value': -0.764325831774072},
#         {'date': '2022-09-08',
#          'moving_average_7': 2136.07039571429,
#          'norm_value': -0.8172235728202952},
#         {'date': '2022-09-09',
#          'moving_average_7': 2010.044876428576,
#          'norm_value': -1.2199938036227276},
#         {'date': '2022-09-10',
#          'moving_average_7': 2056.00188571429,
#          'norm_value': -1.0731178745100527},
#         {'date': '2022-09-11',
#          'moving_average_7': 1989.5660042857185,
#          'norm_value': -1.2854430880716365},
#         {'date': '2022-09-12',
#          'moving_average_7': 1866.2756335714328,
#          'norm_value': -1.679471943098456},
#         {'date': '2022-09-13',
#          'moving_average_7': 1913.0235128571471,
#          'norm_value': -1.5300684394576995},
#         {'date': '2022-09-14',
#          'moving_average_7': 1930.7671900000043,
#          'norm_value': -1.4733606791674188},
#         {'date': '2022-09-15',
#          'moving_average_7': 2036.402923571433,
#          'norm_value': -1.1357550177688744},
#         {'date': '2022-09-16',
#          'moving_average_7': 2269.277132857147,
#          'norm_value': -0.3915025873599381},
#         {'date': '2022-09-17',
#          'moving_average_7': 2316.948216428576,
#          'norm_value': -0.23914857650966936},
#         {'date': '2022-09-18',
#          'moving_average_7': 2468.6791621428615,
#          'norm_value': 0.24577470229598808},
#         {'date': '2022-09-19',
#          'moving_average_7': 2493.9604064285763,
#          'norm_value': 0.32657208883835237},
#         {'date': '2022-09-20',
#          'moving_average_7': 2434.9889078571478,
#          'norm_value': 0.13810260880763572},
#         {'date': '2022-09-21',
#          'moving_average_7': 2386.679705714291,
#          'norm_value': -0.016290791888039904},
#         {'date': '2022-09-22',
#          'moving_average_7': 2483.1318150000047,
#          'norm_value': 0.2919645403539604},
#         {'date': '2022-09-23',
#          'moving_average_7': 2481.401070000005,
#          'norm_value': 0.28643317998297313},
#         {'date': '2022-09-24',
#          'moving_average_7': 2635.3325342857192,
#          'norm_value': 0.7783891881748913},
#         {'date': '2022-09-25',
#          'moving_average_7': 2846.6989614285767,
#          'norm_value': 1.4539039976097174},
#         {'date': '2022-09-26',
#          'moving_average_7': 3056.7988335714335,
#          'norm_value': 2.1253709709192448},
#         {'date': '2022-09-27',
#          'moving_average_7': 3160.088769285719,
#          'norm_value': 2.455479598782896},
#         {'date': '2022-09-28',
#          'moving_average_7': 3232.0684607142907,
#          'norm_value': 2.6855225067121},
#         {'date': '2022-09-29',
#          'moving_average_7': 3150.923777857148,
#          'norm_value': 2.426188819154215},
#         {'date': '2022-09-30',
#          'moving_average_7': 3255.596687142862,
#          'norm_value': 2.7607173501272912},
#         {'date': '2022-10-01',
#          'moving_average_7': 3194.107341428576,
#          'norm_value': 2.56420097704982},
#         {'date': '2022-10-02',
#          'moving_average_7': 3019.327883571433,
#          'norm_value': 2.0056159937890112},
#         {'date': '2022-10-03',
#          'moving_average_7': 2930.270212142862,
#          'norm_value': 1.7209928549254294},
#         {'date': '2022-10-04',
#          'moving_average_7': 2881.068001428576,
#          'norm_value': 1.5637454507671087},
#         {'date': '2022-10-05',
#          'moving_average_7': 2753.7283321428613,
#          'norm_value': 1.156775272987198},
#         {'date': '2022-10-06',
#          'moving_average_7': 2713.292517857147,
#          'norm_value': 1.0275447620172846},
#         {'date': '2022-10-07',
#          'moving_average_7': 2588.4495764285753,
#          'norm_value': 0.6285539812751478},
#         {'date': '2022-10-08',
#          'moving_average_7': 2420.372978571432,
#          'norm_value': 0.09139094877905457},
#         {'date': '2022-10-09',
#          'moving_average_7': 2210.283399285718,
#          'norm_value': -0.5800431291576111},
#         {'date': '2022-10-10',
#          'moving_average_7': 2146.0473857142892,
#          'norm_value': -0.7853376929779515},
#         {'date': '2022-10-11',
#          'moving_average_7': 2221.1026450000036,
#          'norm_value': -0.5454654490325911},
#         {'date': '2022-10-12',
#          'moving_average_7': 2345.6540957142897,
#          'norm_value': -0.14740625566208282},
#         {'date': '2022-10-13',
#          'moving_average_7': 2274.00426571429,
#          'norm_value': -0.3763949456481932},
#         {'date': '2022-10-14',
#          'moving_average_7': 2254.624237142861,
#          'norm_value': -0.4383323899445002},
#         {'date': '2022-10-15',
#          'moving_average_7': 2290.138557857147,
#          'norm_value': -0.3248306862264181},
#         {'date': '2022-10-16',
#          'moving_average_7': 2418.21613071429,
#          'norm_value': 0.08449778845604582},
#         {'date': '2022-10-17',
#          'moving_average_7': 2452.3847878571473,
#          'norm_value': 0.1936988296549914},
#         {'date': '2022-10-18',
#          'moving_average_7': 2382.137423571433,
#          'norm_value': -0.030807661466660335},
#         {'date': '2022-10-19',
#          'moving_average_7': 2248.2496757142903,
#          'norm_value': -0.45870511756666515},
#         {'date': '2022-10-20',
#          'moving_average_7': 2266.637934285719,
#          'norm_value': -0.3999373125153856},
#         {'date': '2022-10-21',
#          'moving_average_7': 2254.9346307142905,
#          'norm_value': -0.43734039014070836},
#         {'date': '2022-10-22',
#          'moving_average_7': 2235.0501028571475,
#          'norm_value': -0.5008901848157201},
#         {'date': '2022-10-23',
#          'moving_average_7': 2336.91441071429,
#          'norm_value': -0.17533778067813882},
#         {'date': '2022-10-24',
#          'moving_average_7': 2358.1495021428614,
#          'norm_value': -0.1074716633689448},
#         {'date': '2022-10-25',
#          'moving_average_7': 2450.5610785714275,
#          'norm_value': 0.1878703608330488},
#         {'date': '2022-10-26',
#          'moving_average_7': 2593.7177057142844,
#          'norm_value': 0.6453906161117136},
#         {'date': '2022-10-27',
#          'moving_average_7': 2714.461324285713,
#          'norm_value': 1.031280199392708},
#         {'date': '2022-10-28',
#          'moving_average_7': 2763.1646778571417,
#          'norm_value': 1.1869332851327832},
#         {'date': '2022-10-29',
#          'moving_average_7': 2789.4515999999994,
#          'norm_value': 1.2709447596228118},
#         {'date': '2022-10-30',
#          'moving_average_7': 2631.2545421428563,
#          'norm_value': 0.7653561624361305},
#         {'date': '2022-10-31',
#          'moving_average_7': 2549.2749799999992,
#          'norm_value': 0.5033542492323195},
#         {'date': '2022-11-01',
#          'moving_average_7': 2426.628187142857,
#          'norm_value': 0.11138223161057591},
#         {'date': '2022-11-02',
#          'moving_average_7': 2310.587117142856,
#          'norm_value': -0.25947827990615413},
#         {'date': '2022-11-03',
#          'moving_average_7': 2247.2991885714277,
#          'norm_value': -0.46174281920102694},
#         {'date': '2022-11-04',
#          'moving_average_7': 2166.647120714285,
#          'norm_value': -0.719502137866236},
#         {'date': '2022-11-05',
#          'moving_average_7': 2128.8802314285704,
#          'norm_value': -0.8402029197436846},
#         {'date': '2022-11-06',
#          'moving_average_7': 2280.451554285713,
#          'norm_value': -0.3557897863068159},
#         {'date': '2022-11-07',
#          'moving_average_7': 2300.53851142857,
#          'norm_value': -0.29159303940664894},
#         {'date': '2022-11-08',
#          'moving_average_7': 2274.6504078571415,
#          'norm_value': -0.374329912935116},
#         {'date': '2022-11-09',
#          'moving_average_7': 2331.772202142856,
#          'norm_value': -0.19177198023462216},
#         {'date': '2022-11-10',
#          'moving_average_7': 2326.3412235714272,
#          'norm_value': -0.2091290719180786},
#         {'date': '2022-11-11',
#          'moving_average_7': 2333.702479285713,
#          'norm_value': -0.18560292673857123},
#         {'date': '2022-11-12',
#          'moving_average_7': 2415.5730742857127,
#          'norm_value': 0.07605073381349724},
#         {'date': '2022-11-13',
#          'moving_average_7': 2326.6831107142843,
#          'norm_value': -0.2080364204914675},
#         {'date': '2022-11-14',
#          'moving_average_7': 2427.3291407142847,
#          'norm_value': 0.11362243846190188},
#         {'date': '2022-11-15',
#          'moving_average_7': 2501.575849285713,
#          'norm_value': 0.3509106013445205},
#         {'date': '2022-11-16',
#          'moving_average_7': 2466.4613499999987,
#          'norm_value': 0.23868670366110714},
#         {'date': '2022-11-17',
#          'moving_average_7': 2363.6834378571416,
#          'norm_value': -0.08978552664426054},
#         {'date': '2022-11-18',
#          'moving_average_7': 2416.001094285713,
#          'norm_value': 0.07741866084260422},
#         {'date': '2022-11-19',
#          'moving_average_7': 2396.196238571428,
#          'norm_value': 0.01412349370294593},
#         {'date': '2022-11-20',
#          'moving_average_7': 2438.3161535714275,
#          'norm_value': 0.1487362926192349}],
#        'strokeWidth': 1.5}],
#      'dateFormatter': {'inputDateFormat': 'yyyy-MM-dd'},
#      'legend': {'type': 'Legend',
#       'position': 'bottom',
#       'contentAlign': 'center',
#       'dx': 20},
#      'cursor': {'type': 'XYCursor', 'behavior': 'none'}},
#     'chart_div_options': {'classes': 'customChartArea',
#      'styles': {'height': '300px'}},
#     'inner_div_options': {'classes': 'customChart'},
#     'xlsx_name': '테마 분석_언급량 추이',
#     'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.40a7144f79b5819ff0e2cb22790c312f.report_chart_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.40a7144f79b5819ff0e2cb22790c312f.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.40a7144f79b5819ff0e2cb22790c312f.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.40a7144f79b5819ff0e2cb22790c312f.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.section_open',
#    'visible': True,
#    'data': '<div class="section mmirae">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.inner',
#    'visible': True,
#    'data': '<div class="report-inner">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.box',
#    'visible': True,
#    'data': '<div class="box ">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.box_title',
#    'visible': True,
#    'data': '<div class="report-box-title"><h3>테마 관련 종목<i class="ri-information-line report-bottomsheet-trigger" onclick="openBottomSheet(this);"></i><div class="report-bottomsheet"><div class="bg" onclick=closeBottomSheet(this);"></div><div class="content"><div class="title"><h6>테마 관련 종목이란 무엇인가요?</h6><button type="button" onclick="closeBottomSheet(this);"><i class="ri-close-line"></i></button></div><div class="text"><p>종목이 포함된 테마의 다른 종목을 관련 키워드 흐름과 주가간 상관성이 높은 순으로 보여줘요.</p><h6>등락률 기준</h6><p>기준일의 종가 등락률을 의미해요.</p><h6>데이터 출처</h6><ul class="list"><li>(주)바이브컴퍼니</li></ul></div></div></div></h3><p>테마 내의 다른 종목을 보여드려요.</p></div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.grid_box_open',
#    'visible': True,
#    'data': '<div class="report-grid-col2">',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.theme_stock_table',
#    'visible': True,
#    'data': '<ul class="report-sector-list"><li class="title"><h6>은행및여신업</h6><p>등락률</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'025770\')">한국정보통신</a></a></h6><p class="negative">-3.25%</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'007330\')">푸른저축은행</a></a></h6><p class="positive">+0.79%</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'006220\')">제주은행</a></a></h6><p class="positive">+5.07%</p></li></ul><ul class="report-sector-list"><li class="title"><h6>금융</h6><p>등락률</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'006220\')">제주은행</a></a></h6><p class="positive">+5.07%</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'049720\')">고려신용정보</a></a></h6><p class="">+0.00%</p></li><li><h6><a onclick="calApp(\'quote_stock\', \'007330\')">푸른저축은행</a></a></h6><p class="positive">+0.79%</p></li></ul>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.grid_box_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.box',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.inner',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.f85f27d749bbdaf42ce5c777ad2cd1a9.section_close',
#    'visible': True,
#    'data': '</div>',
#    'options': {'xlsx': False}},
#   {'type': 'text',
#    'id': 'diy.5e123b51ab92c7c3baec4d46617b1b30.danger_notice',
#    'visible': True,
#    'data': '<div class="report-caution"><div class="report-inner"><ul class="report-caution-list"><li>본 컨텐츠는 (주) 바이브컴퍼니 데이터를 바탕으로 제공되며, (주)바이브컴퍼니 정책에 따라 데이터 항목 업데이트 주기가 상이할 수 있습니다.</li><li>본 컨텐츠는 정보 제공을 목적으로 제작되는 것으로 특정 종목에 대한 매수(매도) 신호나 추천, 판매, 투자 권유를 의미하지 않으며, 투자의 최종 판단은 이용하시는 고객에게 있습니다.</li><li>본 컨텐츠는 인공지능 모델을 활용한 분석이기 때문에 실제 결과와 차이가 있을 수 있으며 당사의 공식적인 의견과 다를 수 있습니다.</li></ul></div></div>',
#    'options': {'xlsx': False}}]}

# %%
total_news = []
for row in data['all_rendering_data']:
    try:
        if 'diy.50f807b8868d3b467a87c9fa0db699ea.test' in row['id']:
#        if 'senti_score' in row['data'][0].keys():
            print(row)
            total_news.append(row)
        else:
            continue
    except:
        continue
# Out:
# {'type': 'amchart_common', 'id': 'diy.50f807b8868d3b467a87c9fa0db699ea.test', 'visible': True, 'data': [{'date': '2022-11-18 08:24:02', 'title': "한화자산운용 민간모펀드, PE부문 첫 GP '린드먼아시아'\r\n최소 결성액 대부분 출자 확약, 높은 GP커밋 비중도 가점 요인", 'senti_score': 68.185, 'sqrt_score': 7.08858236885204, 'score': 50.248, 'thumb_path': '', 'color': 'rgba(229, 125, 0, 0.7)', 'thumb_width': 11, 'thumb_height': 11}, {'date': '2022-11-17 16:57:00', 'title': '린드먼아시아, 20억 규모 자사주 취득 신탁계약 체결', 'senti_score': 98.01, 'sqrt_score': 7.578509088204618, 'score': 57.43379999999999, 'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg', 'color': 'rgba(224, 92, 96, 0.7)', 'thumb_width': 12, 'thumb_height': 12}, {'date': '2022-10-28 08:14:11', 'title': "스마트스코어, '뻐꾸기 박사장 창업' 골프백 제조사 인수 추진\r\n박노준 대표·아주IB 보유 '포시즌' 지분 90% 대상, FI로 린드먼아시아 유치", 'senti_score': 75.09, 'sqrt_score': 6.591835859606942, 'score': 43.452299999999994, 'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg', 'color': 'rgba(229, 125, 0, 0.7)', 'thumb_width': 11, 'thumb_height': 11}, {'date': '2022-10-10 08:30:00', 'title': '바이오플러스, 린드먼아시아 대상 200억 유상증자', 'senti_score': 72.5, 'sqrt_score': 7.836517083500807, 'score': 61.410999999999994, 'thumb_path': '', 'color': 'rgba(229, 125, 0, 0.7)', 'thumb_width': 12, 'thumb_height': 12}, {'date': '2022-10-07 17:31:00', 'title': '“단순 자금 투자 아니다” 바이오플러스가 린드먼아시아와 손잡은 이유', 'senti_score': 86.39, 'sqrt_score': 7.921085784158634, 'score': 62.7436, 'thumb_path': '', 'color': 'rgba(224, 92, 96, 0.7)', 'thumb_width': 12, 'thumb_height': 12}, {'date': '2022-09-06 14:34:00', 'title': '린드먼아시아, 종속사 린드먼아시아투자조합12호 해산사유 발생', 'senti_score': 39.07, 'sqrt_score': 7.747612535484722, 'score': 60.0255, 'thumb_path': '', 'color': 'rgba(141, 200, 232, 0.7)', 'thumb_width': 12, 'thumb_height': 12}, {'date': '2022-07-14 07:30:23', 'title': '린드먼아시아 투자 성장 에이치피오, 신기사 진출\r\n100% 출자 자회사 피오인베스트먼트, 신기사 인가 획득…금융권 경험 인력 이사회 배치', 'senti_score': 83.265, 'sqrt_score': 6.517092910186259, 'score': 42.472500000000004, 'thumb_path': '', 'color': 'rgba(229, 125, 0, 0.7)', 'thumb_width': 11, 'thumb_height': 11}], 'options': {'version': 4, 'chart_type': 'XYChart', 'chart_config': {'type': 'XYChart', 'fontSize': 12, 'colors': {'list': ['#67b7dc', '#fdd400', '#84b761', '#cc4748', '#cd82ad', '#2f4074', '#448e4d', '#b7b83f', '#b9783f', '#b93e3d', '#913167', '#5292AF', '#C9A700', '#6A934E', '#A3393A', '#A36689', '#25335B', '#37723E', '#939332', '#935F32', '#933030', '#752753']}, 'xAxes': [{'type': 'DateAxis', 'visible': True, 'tooltip': {'fontSize': 10}, 'renderer': {'grid': {'template': {'location': 0, 'disabled': True, 'strokeOpacity': 1, 'stroke': '#ebedee'}}, 'labels': {'disabled': True, 'dy': 5}}, 'skipEmptyPeriods': False, 'axisRanges': [{'date': '2022-05-25', 'endDate': '2022-11-26', 'grid': {'disabled': False}, 'tick': {'disabled': True, 'length': 0}, 'label': {'paddingTop': 20, 'location': 0.5, 'horizontalCenter': 'middle', 'fontWeight': 'bolder', 'text': '2022년'}}, {'date': '2022-11-26', 'grid': {'disabled': False}, 'tick': {'disabled': True}, 'label': ''}, {'date': '2022-05-25', 'endDate': '2022-06-01', 'grid': {'disabled': False}, 'tick': {'disabled': False, 'length': 0, 'strokeOpacity': 1, 'stroke': '#ebedee'}, 'label': {'paddingTop': 0, 'location': 0.5, 'horizontalCenter': 'middle', 'text': '5월'}}, {'date': '2022-06-01', 'endDate': '2022-07-01', 'grid': {'disabled': False}, 'tick': {'disabled': False, 'length': 5, 'strokeOpacity': 1, 'stroke': '#ebedee'}, 'label': {'paddingTop': 0, 'location': 0.5, 'horizontalCenter': 'middle', 'text': '6월'}}, {'date': '2022-07-01', 'endDate': '2022-08-01', 'grid': {'disabled': False}, 'tick': {'disabled': False, 'length': 5, 'strokeOpacity': 1, 'stroke': '#ebedee'}, 'label': {'paddingTop': 0, 'location': 0.5, 'horizontalCenter': 'middle', 'text': '7월'}}, {'date': '2022-08-01', 'endDate': '2022-09-01', 'grid': {'disabled': False}, 'tick': {'disabled': False, 'length': 5, 'strokeOpacity': 1, 'stroke': '#ebedee'}, ' ...

# %%
total_news[0]['data']
# Out:
# [{'date': '2022-11-18 08:24:02',
#   'title': "한화자산운용 민간모펀드, PE부문 첫 GP '린드먼아시아'\r\n최소 결성액 대부분 출자 확약, 높은 GP커밋 비중도 가점 요인",
#   'senti_score': 68.185,
#   'sqrt_score': 7.08858236885204,
#   'score': 50.248,
#   'thumb_path': '',
#   'color': 'rgba(229, 125, 0, 0.7)',
#   'thumb_width': 11,
#   'thumb_height': 11},
#  {'date': '2022-11-17 16:57:00',
#   'title': '린드먼아시아, 20억 규모 자사주 취득 신탁계약 체결',
#   'senti_score': 98.01,
#   'sqrt_score': 7.578509088204618,
#   'score': 57.43379999999999,
#   'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg',
#   'color': 'rgba(224, 92, 96, 0.7)',
#   'thumb_width': 12,
#   'thumb_height': 12},
#  {'date': '2022-10-28 08:14:11',
#   'title': "스마트스코어, '뻐꾸기 박사장 창업' 골프백 제조사 인수 추진\r\n박노준 대표·아주IB 보유 '포시즌' 지분 90% 대상, FI로 린드먼아시아 유치",
#   'senti_score': 75.09,
#   'sqrt_score': 6.591835859606942,
#   'score': 43.452299999999994,
#   'thumb_path': 'https://mirae-rpa.some.co.kr/resources/images/miraeasset/thumb_up.svg',
#   'color': 'rgba(229, 125, 0, 0.7)',
#   'thumb_width': 11,
#   'thumb_height': 11},
#  {'date': '2022-10-10 08:30:00',
#   'title': '바이오플러스, 린드먼아시아 대상 200억 유상증자',
#   'senti_score': 72.5,
#   'sqrt_score': 7.836517083500807,
#   'score': 61.410999999999994,
#   'thumb_path': '',
#   'color': 'rgba(229, 125, 0, 0.7)',
#   'thumb_width': 12,
#   'thumb_height': 12},
#  {'date': '2022-10-07 17:31:00',
#   'title': '“단순 자금 투자 아니다” 바이오플러스가 린드먼아시아와 손잡은 이유',
#   'senti_score': 86.39,
#   'sqrt_score': 7.921085784158634,
#   'score': 62.7436,
#   'thumb_path': '',
#   'color': 'rgba(224, 92, 96, 0.7)',
#   'thumb_width': 12,
#   'thumb_height': 12},
#  {'date': '2022-09-06 14:34:00',
#   'title': '린드먼아시아, 종속사 린드먼아시아투자조합12호 해산사유 발생',
#   'senti_score': 39.07,
#   'sqrt_score': 7.747612535484722,
#   'score': 60.0255,
#   'thumb_path': '',
#   'color': 'rgba(141, 200, 232, 0.7)',
#   'thumb_width': 12,
#   'thumb_height': 12},
#  {'date': '2022-07-14 07:30:23',
#   'title': '린드먼아시아 투자 성장 에이치피오, 신기사 진출\r\n100% 출자 자회사 피오인베스트먼트, 신기사 인가 획득…금융권 경험 인력 이사회 배치',
#   'senti_score': 83.265,
#   'sqrt_score': 6.517092910186259,
#   'score': 42.472500000000004,
#   'thumb_path': '',
#   'color': 'rgba(229, 125, 0, 0.7)',
#   'thumb_width': 11,
#   'thumb_height': 11}]

# %%
data.keys()
# Out:
# dict_keys(['report_id', 'template_id', 'template_name', 'complete', 'configs', 'layout', 'all_rendering_data'])

# %%
item
# Out:
# [<Element svg at 0x7f9ac2280180>]

# %%
for i in item[0].iter():
    print(i.text)
# Out:
# None

# %%
item = tree.xpath("/html/body/div[1]/div/div/div[8]/div/div/div[3]/div/div/div/svg/g/g[2]/g[2]/g/g[5]/g[2]/g/g/text[1]/tspan[1]")

# %%
item
# Out:
# []

# %%
item[0].find("tspan")

# %%
item[0].findall('text')
# Out:
# []

# %%
item[0]
# Out:
# <Element g at 0x7f9b002e6300>

# %%
svg_text = etree.tostring(item[0]).decode()

# %%
with open("pp.html", 'w') as f:
    f.write(svg_text)

# %%
text = browser.page_source
ap = []
while(len(text) > 10):
    start_idx = text.find("<svg")
    text = text[start_idx:]

    end_idx = text.find("</svg")
    part = text[:end_idx+6]
    print("=========================================")
    if len(part.strip()) > 600:
        print(part)
        ap.append(part)
    text = text[end_idx+6:]
# Out:
# =========================================
# =========================================
# =========================================
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-46"><rect width="755" height="200"></rect></clipPath><filter id="filter-id-72" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-97" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-118" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-164"><path d="M0,0 L623,0 L623,107 L0,107 L0,0"></path></clipPath><clipPath id="id-184"><path d="M0,0 L623,0 L623,107 L0,107 L0,0"></path></clipPath><clipPath id="id-205"><rect width="623" height="107"></rect></clipPath><clipPath id="id-3524"><rect width="623" height="107"></rect></clipPath><filter id="filter-id-51" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-169" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-189" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="755" height="200"></rect></g><g><g role="region" clip-path="url(&quot;#id-46&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(51,0)" style="touch-action: none; user-select: none; -webkit-user-drag: none;"><g fill="#ffffff" fill-opacity="0"><rect width="623" height="107"></rect></g><g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(623,0)"><path d=" M0,0  L5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,0 L623,0 L623,0 L0,0"></path></g><g stroke="#eceff4" stroke-opacity="1" fill="none"><path d=" M0,0  L623,0 " transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(623,53)"><path d=" M0,0  L5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,53.5 L623,53.5 L623,0 L0,0"></path></g><g stroke="#eceff4" stroke-opacity="1" fill="none" transform="translate(0,53)"><path d=" M0,0  L623,0 " transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(623,107)"><path d=" M0,0  L5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,53.5 L0,107 L623,107 L623,53.5 L0,53.5"></path></g><g stroke="#eceff4" stroke-opacity="1" fill="none" transform="translate(0,107)"><path d=" M0,0  L623,0 " transform="translate(-0.5,-0.5)"></path ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-283"><rect width="747" height="250"></rect></clipPath><filter id="filter-id-309" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-330" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-364"><path d="M0,0 L676,0 L676,176 L0,176 L0,0"></path></clipPath><clipPath id="id-3523"><rect width="676" height="176"></rect></clipPath><filter id="filter-id-288" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-369" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="747" height="250"></rect></g><g><g role="region" clip-path="url(&quot;#id-283&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(41,0)"><g fill="#ffffff" fill-opacity="0"><rect width="676" height="176"></rect></g><g><g><g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,242)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,209)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,176)"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,143)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,-156)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,-73)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,10)"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,93)"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,259)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="0" fill="none" transform="translate(0,342)" display="none"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,176)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,92.951069307238 L0,176 L676,176 L676,92.951069307238 L0,92.951069307238"></path></g><g stroke="#ebedee" stroke-opacity="1" fill="none" stroke-width="2" transform="translate(0,176)"><path d=" M0,0  L676,0 " transform="translate(-0.5,-0.5)"></path> ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-506"><rect width="747" height="300"></rect></clipPath><filter id="filter-id-532" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-553" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-599"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-616"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-633"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-650"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-668"><rect width="677" height="183"></rect></clipPath><clipPath id="id-3522"><rect width="677" height="183"></rect></clipPath><filter id="filter-id-511" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-604" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-621" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-638" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-655" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="747" height="300"></rect></g><g><g role="region" clip-path="url(&quot;#id-506&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(40,0)" style="touch-action: none; user-select: none; -webkit-user-drag: none;"><g fill="#ffffff" fill-opacity="0"><rect width="677" height="183"></rect></g><g><g><g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,256)" display="none"><path d=" M0,0  L677,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,220)" display="none"><path d=" M0,0  L677,0 " transform= ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-801"><rect width="378" height="230"></rect></clipPath><filter id="filter-id-826" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-847" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-881"><path d="M0,0 L237,0 L237,180 L0,180 L0,0"></path></clipPath><clipPath id="id-3521"><rect width="237" height="180"></rect></clipPath><filter id="filter-id-806" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-886" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="378" height="230"></rect></g><g><g role="region" clip-path="url(&quot;#id-801&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(111,0)"><g fill="#ffffff" fill-opacity="0"><rect width="237" height="180"></rect></g><g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,157)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,135 L0,180 L237,180 L237,135 L0,135"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,112)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,90 L0,135 L237,135 L237,90 L0,90"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,67)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,45 L0,90 L237,90 L237,45 L0,45"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,22)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,45 L237,45 L237,0 L0,0"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g></g></g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(79,180)"><path d=" M0,0  L0,5 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M79,0 L79,180 L227.9089484712349,180 L227.9089484712349,0 L79,0"></path></g></g></g><g><g><g role="group" stroke-opacity="0" fill-opacity="1" stroke="#f58220"><g><g clip-path="url(&quot;#id- ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-959"><rect width="378" height="230"></rect></clipPath><filter id="filter-id-984" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-1005" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-1039"><path d="M0,0 L237,0 L237,180 L0,180 L0,0"></path></clipPath><clipPath id="id-3520"><rect width="237" height="180"></rect></clipPath><filter id="filter-id-964" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1044" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="378" height="230"></rect></g><g><g role="region" clip-path="url(&quot;#id-959&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(111,0)"><g fill="#ffffff" fill-opacity="0"><rect width="237" height="180"></rect></g><g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,157)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,135 L0,180 L237,180 L237,135 L0,135"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,112)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,90 L0,135 L237,135 L237,90 L0,90"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,67)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,45 L0,90 L237,90 L237,45 L0,45"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,22)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,45 L237,45 L237,0 L0,0"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g></g></g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(79,180)"><path d=" M0,0  L0,5 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M79,0 L79,180 L213.08466003598218,180 L213.08466003598218,0 L79,0"></path></g></g></g><g><g><g role="group" stroke-opacity="0" fill-opacity="1" stroke="#f58220"><g><g clip-path="url(&quot ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-1117"><rect width="378" height="230"></rect></clipPath><filter id="filter-id-1142" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-1163" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-1197"><path d="M0,0 L237,0 L237,180 L0,180 L0,0"></path></clipPath><clipPath id="id-3519"><rect width="237" height="180"></rect></clipPath><filter id="filter-id-1122" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1202" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="378" height="230"></rect></g><g><g role="region" clip-path="url(&quot;#id-1117&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(111,0)"><g fill="#ffffff" fill-opacity="0"><rect width="237" height="180"></rect></g><g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,157)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,135 L0,180 L237,180 L237,135 L0,135"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,112)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,90 L0,135 L237,135 L237,90 L0,90"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,67)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,45 L0,90 L237,90 L237,45 L0,45"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,22)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,45 L237,45 L237,0 L0,0"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g></g></g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(79,180)"><path d=" M0,0  L0,5 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M79,0 L79,180 L237,180 L237,0 L79,0"></path></g></g></g><g><g><g role="group" stroke-opacity="0" fill-opacity="1" stroke="#f58220"><g><g clip-path="url(&quot;#id-1197&quot;)"><g><g><g ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-1275"><rect width="378" height="230"></rect></clipPath><filter id="filter-id-1300" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-1321" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-1355"><path d="M0,0 L237,0 L237,180 L0,180 L0,0"></path></clipPath><clipPath id="id-3518"><rect width="237" height="180"></rect></clipPath><filter id="filter-id-1280" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1360" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="378" height="230"></rect></g><g><g role="region" clip-path="url(&quot;#id-1275&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(111,0)"><g fill="#ffffff" fill-opacity="0"><rect width="237" height="180"></rect></g><g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,157)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,135 L0,180 L237,180 L237,135 L0,135"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,112)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,90 L0,135 L237,135 L237,90 L0,90"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,67)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,45 L0,90 L237,90 L237,45 L0,45"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(0,22)"><path d=" M0,0  L-5,0 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M0,0 L0,45 L237,45 L237,0 L0,0"></path></g><g stroke="#000000" stroke-opacity="0.15" fill="none" display="none"><path transform="translate(-0.5,-0.5)"></path></g></g></g><g><g><g fill-opacity="0" stroke-opacity="0" stroke="#000000" stroke-width="1" transform="translate(79,180)"><path d=" M0,0  L0,5 " transform="translate(-0.5,-0.5)"></path></g><g fill="#000000" fill-opacity="0" style="pointer-events: none;"><path d="M79,0 L79,180 L198.92409867172677,180 L198.92409867172677,0 L79,0"></path></g></g></g><g><g><g role="group" stroke-opacity="0" fill-opacity="1" stroke="#f58220"><g><g clip-path="url(& ...
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-1433"><rect width="742" height="300"></rect></clipPath><filter id="filter-id-1459" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-1480" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-1526"><path d="M0,0 L665,0 L665,185 L0,185 L0,0"></path></clipPath><clipPath id="id-1543"><path d="M0,0 L665,0 L665,185 L0,185 L0,0"></path></clipPath><clipPath id="id-1560"><path d="M0,0 L665,0 L665,185 L0,185 L0,0"></path></clipPath><clipPath id="id-1577"><path d="M0,0 L665,0 L665,185 L0,185 L0,0"></path></clipPath><clipPath id="id-1595"><rect width="665" height="185"></rect></clipPath><clipPath id="id-3517"><rect width="665" height="185"></rect></clipPath><filter id="filter-id-1438" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1531" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1548" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1565" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1582" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="742" height="300"></rect></g><g><g role="region" clip-path="url(&quot;#id-1433&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(47,0)" style="touch-action: none; user-select: none; -webkit-user-drag: none;"><g fill="#ffffff" fill-opacity="0"><rect width="665" height="185"></rect></g><g><g><g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,231)" display="none"><path d=" M0,0  L665,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,208)" display="none"><path d=" M0,0  L665, ...
# =========================================
# =========================================
# =========================================
# =========================================
# <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-151"><path></path></clipPath><clipPath id="id-351"><path></path></clipPath><clipPath id="id-586"><path></path></clipPath><clipPath id="id-868"><path></path></clipPath><clipPath id="id-1026"><path></path></clipPath><clipPath id="id-1184"><path></path></clipPath><clipPath id="id-1342"><path></path></clipPath><clipPath id="id-1513"><path></path></clipPath><filter id="filter-id-1518" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1347" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1189" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-1031" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-873" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-591" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-356" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-156" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussi ...
# =========================================

# %%
for i, a in enumerate(ap):
    if '3분기 누적' in a:
        print(i)

# %%
ap[2]
# Out:
# '<svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" role="group" style="width: 100%; height: 100%; overflow: visible;"><defs><clipPath id="id-506"><rect width="747" height="300"></rect></clipPath><filter id="filter-id-532" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><filter id="filter-id-553" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"></filter><clipPath id="id-599"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-616"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-633"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-650"><path d="M0,0 L677,0 L677,183 L0,183 L0,0"></path></clipPath><clipPath id="id-668"><rect width="677" height="183"></rect></clipPath><clipPath id="id-3522"><rect width="677" height="183"></rect></clipPath><filter id="filter-id-511" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-604" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-621" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-638" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><filter id="filter-id-655" filterUnits="objectBoundingBox" width="200%" height="200%" x="-50%" y="-50%"><feGaussianBlur result="blurOut" in="SourceGraphic" stdDeviation="1.5"></feGaussianBlur><feOffset result="offsetBlur" dx="1" dy="1"></feOffset><feFlood flood-color="#000000" flood-opacity="0.5"></feFlood><feComposite in2="offsetBlur" operator="in"></feComposite><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter></defs><g><g fill="#ffffff" fill-opacity="0"><rect width="747" height="300"></rect></g><g><g role="region" clip-path="url(&quot;#id-506&quot;)" font-size="12" opacity="1" aria-label="Chart"><g transform="translate(15,15)"><g><g><g><g><g><g><g transform="translate(40,0)" style="touch-action: none; user-select: none; -webkit-user-drag: none;"><g fill="#ffffff" fill-opacity="0"><rect width="677" height="183"></rect></g><g><g><g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,256)" display="none"><path d=" M0,0  L677,0 " transform="translate(-0.5,-0.5)"></path></g><g stroke="#ebedee" stroke-opacity="1" fill="none" transform="translate(0,220)" display="none"><path d=" M0,0  L677,0 " transform ...

# %%
tree2 = etree.parse(StringIO(ap[0]),parser = etree.HTMLParser())

# %%
t = """
<svg width="100%" height="100%" viewBox="0 0 42 42" role="img"><filter id="shadow" color-interpolation-filters="sRGB"><feDropShadow dx="0.5" dy="0.5" stdDeviation="1.5" flood-opacity="0.4"></feDropShadow></filter><circle class="donut-segment" cx="21" cy="21" r="15.91549430918954" stroke-linecap="round" fill="transparent" stroke="#9fa0a0" stroke-width="3.2" stroke-dasharray="75 25" stroke-dashoffset="25"></circle><circle class="donut-hole" cx="21" cy="21" r="14.51549430918954" fill="#fff" filter="url(#shadow)"></circle></svg>
"""

# %%
len(t.strip())
# Out:
# 530
