# %%
from selenium.webdriver.common.by import By
import requests
import re
import pandas as pd
import numpy as np
import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import warnings
warnings.filterwarnings('ignore')
import sqlite3
from bs4 import BeautifulSoup, BeautifulStoneSoup
import json
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent={0}'.format(user_agent))
# options =  webdriver.Chrome('/home/porter/NOTEBOOK/chromedriver',options=options)
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan

# %%
CNT = 15
cnt = CNT

url = "https://www.teamblind.com/kr/topics/주식·투자"
driver = webdriver.Chrome('/home/lsi8505/chromedriver',options=options)
driver.get(url)

while cnt:
#         print(cnt)
    driver.find_element(By.TAG_NAME,'body').send_keys(Keys.PAGE_DOWN)

#     driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)
    cnt -= 1

bs_obj = BeautifulStoneSoup(driver.page_source)
div = bs_obj.find('div', {'class': 'article-list '})
posts = div.find_all('div', {'class' : 'tit'})
posts_title = []
for t in posts:
    try:
        posts_title.append(t.find('a').find('span').decompose().text.strip())
    except:
        posts_title.append(t.find('a').text.strip())
posts_href = []
for l in posts:
    tmp = l.find('a')['href']
    posts_href.append(tmp[tmp.rfind('-'):])
posts_title = [re.sub(r'[~()%":\'/,!?]', '', i).replace(' ', '-').replace('\n', '') for i in posts_title]

root_path = "https://www.teamblind.com/kr/post/"
list_url = list()
list_url2 = list()
cnt = 0
#     print('처리 들어간다')

## 크롤링
for title, link in zip(posts_title, posts_href):
    # cnt += 1
    title2 = re.sub('[.]', '', title)
    list_url.append(root_path + title + link)
    list_url2.append(root_path + title2 + link)
url_dirs = pd.DataFrame({'url_raw' : list_url, 'url' : list_url2})
#     url_dirs.to_csv('urls.csv')
data = []
for i in range(len(url_dirs)):
#     print(i ," // ", len(url_dirs), "// ", url_dirs.loc[i,'url'] )
    headers = {'User-Agent': 'Mozilla/5.0'} 
    response = requests.get(url_dirs.loc[i,'url'],  headers=headers)
    response

    bs_obj = BeautifulSoup(response.text)
    title = bs_obj.find('div', {'class' : 'article-view-head'})
    main = bs_obj.find('div', {'class' : 'article-view-contents'})
    like = bs_obj.find('div', {'class' : 'article_info'})
    comment = bs_obj.find('div', {'class' : 'article-comments'})
    try:
        ti = title.find('h2').text # 제목
        da = title.find('span', {'class' : 'date'}).text.replace('작성일', '') # 날짜
        if '일' in da:
            tmp = int(da.replace('일', ''))
            da = (datetime.datetime.today().date() - datetime.timedelta(days = tmp)).strftime('%Y%m%d')
        elif '어제' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 1)).strftime('%Y%m%d')
        elif '분' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')
        elif '시간' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')
        elif '초' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')

        lo = title.find('span', {'class' : 'pv'}).text.replace('조회수', '') # 조회수

        tmp = main.find('p', {'class' : 'contents-txt'}).text # 본문
        try:
            tmp = tmp[:tmp.index('  ')]
        except:
            pass
        tmp

        try:
            li = like.find('a', {'class' : 'like'}).text.replace('좋아요', '') # 좋아요 수
            if not li:
                li = 0
        except:
            li = 0

        cc = comment.find('h3').text.replace('댓글 ', '') # 댓글 갯수

        if '0' == cc: # 댓글
            co = 0
        else:
            co = ''
            for c in comment.find_all('p', {'class' : 'cmt-txt'}):
                c = c.text
                try:
                    co += (c[:c.index('작성일')] + '\n')
                except:
                    co += (c + '\n')

        dict_data = {'date':da, 'title' : ti, 'main' : tmp, 'comments' : co, 'looks_count' : lo, 'likes_count' : li, 'comments_count' : cc}
    #     print(dict_data)
        data.append(dict_data)

    except:
        print("SPECIAL CHARACTER IN TITLE")    
    time.sleep(0.5)

# %%
df_ = pd.DataFrame(data).iloc[2:].reset_index(drop=True)
df_
# Out:
#         date                               title  \
# 0         방금                        부모님 보기 죄송스럽다
# 1   20220830                          자산 배분 어케하냐
# 2   20220830  내가 삼성이어폰 종류별로 있고 노트북 태블릿 폰까지 갤럭시지만
# 3   20220830                          환율 오르면 hmm
# 4   20220830             불과 1년전에 주식잔고가 3억 5천이었는데
# 5   20220830                   레버리지 곱버스 잘하는 사람특징
# 6   20220830            어제 쫄아서 매도한 제주도 흙두루치기 없제?
# 7   20220830                      스테이킹 하시는분 있나요?
# 8   20220830             삼성전자우 지금 투자하기 딱 좋은 시기??
# 9   20220830                                룰루루루
# 10  20220830               한국판 서브프라임 모기지 사태가 온다!
# 11  20220830                     Skc 52주 신저가 ~~
# 12  20220830                      지금 나스닥 들어가도 될까
# 13  20220830                    70평 땅에 원룸건물 지으려해
# 14  20220830                             소리바다 뭐여
# 15  20220830                         중국 사교육주 TAL
# 16  20220830                              한국맥널티.
# 17  20220830                      진짜 저점이 가을에 올까?
# 18  20220830          담배값 인상하면 KT&G 주가 얼마나 오르나요?
# 19  20220830                          달러 환율 투자??
# 20  20220830                 적금 예금 금리 높은 상품 추천해줘
# 21  20220830                           고려아연 무슨일?
# 22  20220830                                 주린이
# 23  20220830                 다시는 킹스피를 의심하지 않겠습니다
# 24  20220830              글로벌에서 국장이 요근래 제일 센듯???
# 25  20220830          시드머니1억으로매월100만원수익12달연속내는거.
# 26  20220830                      곱버스는 너무 비효율적인듯
# 27  20220830                 우리 사주(동전 주) 받았는데...
# 28  20220830              1년 한국 국채 금리 3.27% ????
# 29  20220830                           예금 2억 박았다
# 30  20220830                      오늘은 2400 깨지는 날
# 31  20220830                        아직도 행복회로 돌리냐
# 32  20220830                     요즘 내 심경이 이래....
# 33  20220830                       20대분들 평균 자산.?
# 34  20220830               금리인상하는데 발행어음금리 왜 내리죠?
# 35  20220830   사회초년생이라 부동산이든 주식이든 쳐물릴 시드도 없으면 개추
# 36  20220830        실비 알릴의무에 30일이상 투약이 안약도 해당되나?
# 37  20220830                            오늘도 날아보자
# 38  20220830       안팔았으면.손해아니라는말.공감합니까.공감하지않읍니까.
# 39  20220830                  하이닉스 낸드는 적자 얘기 나오네
# 40  20220830                            My money
# 41  20220830                         엔비디아 왜 난리야?
# 42  20220830                            나스닥선물 양전
# 43  20220830                   주식에 물리기 vs 집에 물리기
# 44  20220830                 1년전에 시작한 사람 힘들거야 ㅋㅋ
# 45  20220830                            내평단올까..?
# 46  20220830         아우 장난치지말고 빨리 반등좀 줘요!!!!!!!!
# 47  20220830                        오늘 국장 상승...?
# 48  20220830                      97년도랑 오버랩 되는듯해
# 49  20220830                          삼전 4만원 보겠다
#
#                                                  main  \
# 0                           4년 동안 투자했는데 결국 원금 -8천휴...
# 1   작년 말부터 주식 전부 처분. 부동산도 한채 처분.해서 부동산 : 현금 50 : 5...
# 2                                 왜 주식까지 삼전에 몰빵했을까...
# 3                                 죽어나가?hmm은 나락만 가네 계속
# 4                        지금 2억으로 쪼그라듬1년동안 무슨일이 있었던거야ㅠ
# 5                                             둘다 발라먹음
# 6                            남들이 다 아는 공포는 공포가 아닌거 알제?
# 7             이더 198때 20개 매수하긴했는데 스테이킹 수량 마음대로 가능한가요?
# 8                                              강추야???
# 9                                          오만 전자~~~~~
# 10  GDP대비 가계부채 세계 1등. 그중 가장 큰 비중은 주택 담보 대출. 그리고 75...
# 11                                      🤔 지주사 전환 가속화네
# 12                                  이미 4% 빠졌는데더 내려가려나
# 13  땅은 부모님껀데개인이 건축업자랑 미팅하고 진행하는게통상적이라 알고있어근데 신탁사한테...
# 14                                                 갓갓
# 15                           자식 생각하는 부모 마음을 어찌 막으리..?
# 16                                             고맙읍니다.
# 17  7월쯤 푹 떨어졌다가 요즘 다시 슬금슬금 올라오는거같은데 증권강의같은거 보면 바닥에...
# 18  박근혜 시절인가 2500 —&gt 4500 올랐을때 kt&G 주가랑 분위기 어땠는지...
# 19  환율이 끝이 안 보이는데이러다가 타이밍 잘못 잡히면서 환전 후 투자 하면 주식 이익...
# 20                            적금 예금 금리 높은 상품 추천해줘1금융~
# 21                                         요즘 변동성 지기네
# 22  책보면서 공부중이고 조금씩 소액 분산투자중인데 저축을 늘리고 싶어서 적립식 주식을 ...
# 23                   의심해서 죄송합니다 갓스피님앞으로 킹갓황스피로 부르겠습니다
# 24                                하락 제일 약하고 반등 빠르고???
# 25                            쉬운일?어려운일?답변부탁합니다.고맙읍니다.
# 26  성격은 세계파탄, 대공황 기원하면서 부정적으로 바뀌고나스닥 본다고오버나잇한다고 잠도...
# 27                                      모 일단 우리 사주 받고
# 28  우리 기준 금리가 이제 막 2.5에 왔는데, 1년 국채 금리가 3.27이면 내년 기...
# 29                              집살돈으론 주식하면 랄부떨려서 안되겠다
# 30  과연 전저점 이하로 뚫고 내려갈지한달 거품낄때 기분 좋았지?난 좋았어 한여름밤의 꿈...
# 31                                 정신을 못차렸구나 QE 100배!
# 32                       https://youtu.be/biXFnFITzzI
# 33  보통 본인 능력으로만 투자+저축해서 돈을 모은다면 이십대 중후반 정도에 얼마 정도 ...
# 34  기준금리 0.25% 인상하였는데, 181일물 금리는 왜 인하한걸까요?내부기준이나 정...
# 35                                         일단 나부터 ㅋㅋㅋ
# 36  알러지성 결막염이 있어서 안과갈때마다일회용 용기에 든 알러지안약 2박스 (1통에30...
# 37                      오늘도 이수화학 날아보자♡씨아이에스도 같이 날아보자♡
# 38             정말많이듣는말인데말같지않은말같아서여쭤봅니다답변부탁드립니다.고맙읍니다.
# 39  http://www.sisajournal-e.com/news/articleView....
# 40                     do jiggle jiggle. It falls…..ㅠ
# 41  1주 -&gt 4주로 액면분할 받았으니까적어도 640불 이전에 산 사람들은 다 플러...
# 42                                              !!!!!
# 43                             일단 난 전자ㅋㅋㅋㅋㅋㅋㅋㅋㅜㅜ-3000
# 44          1년전에 시작했는데시작하고 나서 금액이 점점 커졌고결과적으로 지금 -28%
# 45                                               Sqqq
# 46                          응으어어ㅓ가거거거어어어거겅어ㅓ야야어거거거어야갸
# 47                                               ...?
# 48                   97년도 상황인데.. 요즘 분위기가 많이 오버랩 되는듯..
# 49                     오늘도 코스피 폭포수일듯 ㅜㅜ조만간 삼전 4만원 보겠다
#
#                                              comments looks_count likes_count  \
# 0                                              코인했나\n           1           1
# 1                                                   0          19           0
# 2                              삼성에서 명예회원 주실거야\n돔황챠!\n          74           0
# 3   여기 35층에 사람있어요~~~\n나도 물림..\n환율 오르면 다 죽어나가\n특히 h...          61           0
# 4            ㅠㅠ\n나 3억에서 1억8천..\n망ㅠ\n나도 그래 ㅠㅠ\n나도 ㅈ망\n         189           0
# 5                                       그러다 한방에 가\n\n          83           1
# 6   제주도 흙두루치기이러니까 제주도 수학여행 생각나네 ㅋㅋㅋ\n흙두루치기는 흑우종류인가...         136           0
# 7                                                   0          36           0
# 8   꼭 사라\n가격차이 많이벌어졌을따사는거 아닌가 우선주는\nㄴ\n비쌈 5깨지면\nㄴㄴ...         288           0
# 9                                              삼만간다\n          55           0
# 10  왔으면 좋겠다\n안오면 말고 ㅇㅈ\n서브프라임 정도는 아니지만 가계대출관련 큰거 올...         255           2
# 11          skc 합병 소식이 있음?\n장대음봉 나올각 ㅋㅋ 도망차\nㅠㅠ\n삿냐\n         100           0
# 12                   분할매수\n$$$\n지수투자는 무적건 무지성 적립식이지\n         202           0
# 13  원룸짓는데 70평이면 그렇게 여유롭진 않을텐데\n지을수는 있지\n나 원룸 주인인데,...         242           0
# 14  아직 상폐 안됐어?\n상폐직전 마지막 설거지\n바다이야기\n소리바다에도 고래가 살까?\n         423           0
# 15                                와 1년전에 한주 샀었는데...\n         145           1
# 16                                  원두 맛있음? 곰곰 쿠팡인가\n         347           1
# 17  연말까지 떨어진다\n강의에서 결론적인 타이밍은 안알려주는가 보군요\n아직 경제 침체...         246           0
# 18  개똥주식\n필립모리스 주식 나두고 케이티 왜삼\n오르긴 했지만 세금 많이 뜯긴다고 ...         295           0
# 19  환률 스프레드가 큰데 과연 돈을 벌 수 있을까?\n미국 주식 내려가는거 보면 투자하...         157           0
# 20                  tqqq\n은행연합회 홈페이지 가면 있어유 ~\nsqqq\n         162           2
# 21                                  영풍에서 분리하려고 지분싸움\n         173           0
# 22  이평선 공부가 되셨다면.. 장기이평선에 자기 평단을 밎춰서 정배열때 리밸런싱해나가는...          98           0
# 23             킹스피의 낚시\n코스피에 갓을 붙여?  미쳤어?\n맨날 의심하면서\n         237           3
# 24  반등 없는데\n뭔소리\n그냥 폭락은 폭락대로 반등은 미비하게 전반적으로 계단식 하락...         261           1
# 25  개어려운일\n하루에12%수익 한번내고 쉬는게 더쉬움\nㅇㅈㅋㅋㅋㅋ\n큰거 한방만 터...         319           1
# 26        ㅇㅇ 차라리 비트코인 숏이 나아보임\n곱버스를 지금 잡아서 더 그런거아님?\n         162           1
# 27                         ㅇㅇ\n매도금지조항 없으면 온전히 내꺼지 뭘\n         185           0
# 28              아 나 뒤졌다\n미국은 올해 기준금리 3퍼후반인데\n4프로 넘음\n         251           0
# 29  랄부 쪼그라듬\n어디꺼 넣었어요?\n지금 우리은행 이율 매우 좋읍니다\n몇프로짜리 ...         373           3
# 30     ㅗ\n요요현상오네 ㅋㅋ\n응??\n틀렸네 아이참 부끄럽게\n오늘은 아니고 이번주\n         189           1
# 31                          QE 100배 하면 하이퍼인플레이션 오겠네\n          57           1
# 32                                      ㅋㅋㅋ 피는 못속이네\n         245           1
# 33  10억?\n직장생활 몇년했냐 따라다르겠지\n한..2-3년?\n직장마다 다르겠지만 최...         335           1
# 34                                                  0         222           0
# 35  이미 쳐 물려있는 사람 개추&lt&ltㅋㅋㅋ\n30년존버해봄\n이미 물려서 사회초년...         216           2
# 36                                 실비니 ㅇㅇ 병원간기록 있자나\n          95           0
# 37                                               ㅇㄷ\n          63           0
# 38  ㅋㅋ\n개소리라는거 알고 물어보는거 아닌가요? 안팔았다가 상폐 가능한 게 주식세상입...         200           2
# 39  낸드는 원래 삼성 빼면 돈 거의 못 벌어서 가격빠지면 적자날 수 있을거야\n인텔이 ...         458           2
# 40                                 🥲\nㅋㅋㅋㅋㅋㅋㅋ음성지원되냐\n          91           1
# 41  2019년 동탄등기치고 푸근해하는놈같네\n19년이면 아직 푸근하잖아\n턱끝까지 왔지...         729           1
# 42  나스닥 선물 일희일비했던 과거의 내가 생각나는군\n날짜 바뀌어서 그런거 아님?\n0...         372           1
# 43  나는 전자 -5000 후자 +10000\n전자 -7000000 후자 +20억\n난 ...         336           2
# 44  결과머냐고\n결과 지옥\n10년전부터 안힘들었던적이 없다ㅋ\n난 벌었는데..한국장은...         614           1
# 45  곰방와~ 근데 횽아 왜 물안탔엉\n나 물 타서 46 ㅋㅋㅋㅋ 평단 올듯\n올해안에는...         242           0
# 46  ㅋ\n올해는 포기.. 내년까지 존버 해야할듯...\n중간선거 끝나고 살짝 반등 줬다...         320           2
# 47  하락\n야간선물 엄청 올랏던뎅\n폭포\n웅..?\n아직 김치맛 덜 봤나보네\n상승이...         460           1
# 48  오버지...  97년에는 원화만 무너진거구 지금은 달러가 강해진거니까   완전 케이...       1,401           2
# 49  개오바하네 꼴랑 1퍼 빠졌구만 나스닥\n\n삼전 4만대오면 코스피 2000언더 아냐...         682           2
#
#    comments_count
# 0               1
# 1               0
# 2               2
# 3               5
# 4               5
# 5               2
# 6               4
# 7               0
# 8               8
# 9               1
# 10              8
# 11              4
# 12              3
# 13              8
# 14              4
# 15              1
# 16              1
# 17              6
# 18              4
# 19              2
# 20              3
# 21              1
# 22              8
# 23              3
# 24              7
# 25              7
# 26              2
# 27              2
# 28              3
# 29              7
# 30              5
# 31              1
# 32              1
# 33             10
# 34              0
# 35              6
# 36              1
# 37              1
# 38              7
# 39              2
# 40              2
# 41              6
# 42              3
# 43              5
# 44              8
# 45              5
# 46              4
# 47              8
# 48             19
# 49              4

# %%
df_['DATETIME'] = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['VIEWS'] = df_['looks_count']
df_['LIKES'] = df_['likes_count']
df_['TITLE'] =  df_['title']
df_['CONTENT'] = df_['main']
df_['WRITER'] = np.nan

df_['SOURCE'] = "블라인드_주식투자"
df_['RELATED_ITEM'] = np.nan
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['comments_count']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)
df_['NUM_REPLY'] = np.nan
df_['CRAWLING_DATETIME'] = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['URL'] =  np.nan
df_ = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_
# Out:
#        SOURCE  RELATED_ITEM         DATETIME  \
# 0   블라인드_주식투자           NaN  20220830-103132
# 1   블라인드_주식투자           NaN  20220830-103132
# 2   블라인드_주식투자           NaN  20220830-103132
# 3   블라인드_주식투자           NaN  20220830-103132
# 4   블라인드_주식투자           NaN  20220830-103132
# 5   블라인드_주식투자           NaN  20220830-103132
# 6   블라인드_주식투자           NaN  20220830-103132
# 7   블라인드_주식투자           NaN  20220830-103132
# 8   블라인드_주식투자           NaN  20220830-103132
# 9   블라인드_주식투자           NaN  20220830-103132
# 10  블라인드_주식투자           NaN  20220830-103132
# 11  블라인드_주식투자           NaN  20220830-103132
# 12  블라인드_주식투자           NaN  20220830-103132
# 13  블라인드_주식투자           NaN  20220830-103132
# 14  블라인드_주식투자           NaN  20220830-103132
# 15  블라인드_주식투자           NaN  20220830-103132
# 16  블라인드_주식투자           NaN  20220830-103132
# 17  블라인드_주식투자           NaN  20220830-103132
# 18  블라인드_주식투자           NaN  20220830-103132
# 19  블라인드_주식투자           NaN  20220830-103132
# 20  블라인드_주식투자           NaN  20220830-103132
# 21  블라인드_주식투자           NaN  20220830-103132
# 22  블라인드_주식투자           NaN  20220830-103132
# 23  블라인드_주식투자           NaN  20220830-103132
# 24  블라인드_주식투자           NaN  20220830-103132
# 25  블라인드_주식투자           NaN  20220830-103132
# 26  블라인드_주식투자           NaN  20220830-103132
# 27  블라인드_주식투자           NaN  20220830-103132
# 28  블라인드_주식투자           NaN  20220830-103132
# 29  블라인드_주식투자           NaN  20220830-103132
# 30  블라인드_주식투자           NaN  20220830-103132
# 31  블라인드_주식투자           NaN  20220830-103132
# 32  블라인드_주식투자           NaN  20220830-103132
# 33  블라인드_주식투자           NaN  20220830-103132
# 34  블라인드_주식투자           NaN  20220830-103132
# 35  블라인드_주식투자           NaN  20220830-103132
# 36  블라인드_주식투자           NaN  20220830-103132
# 37  블라인드_주식투자           NaN  20220830-103132
# 38  블라인드_주식투자           NaN  20220830-103132
# 39  블라인드_주식투자           NaN  20220830-103132
# 40  블라인드_주식투자           NaN  20220830-103132
# 41  블라인드_주식투자           NaN  20220830-103132
# 42  블라인드_주식투자           NaN  20220830-103132
# 43  블라인드_주식투자           NaN  20220830-103132
# 44  블라인드_주식투자           NaN  20220830-103132
# 45  블라인드_주식투자           NaN  20220830-103132
# 46  블라인드_주식투자           NaN  20220830-103132
# 47  블라인드_주식투자           NaN  20220830-103132
# 48  블라인드_주식투자           NaN  20220830-103132
# 49  블라인드_주식투자           NaN  20220830-103132
#
#                                  TITLE  \
# 0                         부모님 보기 죄송스럽다
# 1                           자산 배분 어케하냐
# 2   내가 삼성이어폰 종류별로 있고 노트북 태블릿 폰까지 갤럭시지만
# 3                           환율 오르면 hmm
# 4              불과 1년전에 주식잔고가 3억 5천이었는데
# 5                    레버리지 곱버스 잘하는 사람특징
# 6             어제 쫄아서 매도한 제주도 흙두루치기 없제?
# 7                       스테이킹 하시는분 있나요?
# 8              삼성전자우 지금 투자하기 딱 좋은 시기??
# 9                                 룰루루루
# 10               한국판 서브프라임 모기지 사태가 온다!
# 11                     Skc 52주 신저가 ~~
# 12                      지금 나스닥 들어가도 될까
# 13                    70평 땅에 원룸건물 지으려해
# 14                             소리바다 뭐여
# 15                         중국 사교육주 TAL
# 16                              한국맥널티.
# 17                      진짜 저점이 가을에 올까?
# 18          담배값 인상하면 KT&G 주가 얼마나 오르나요?
# 19                          달러 환율 투자??
# 20                 적금 예금 금리 높은 상품 추천해줘
# 21                           고려아연 무슨일?
# 22                                 주린이
# 23                 다시는 킹스피를 의심하지 않겠습니다
# 24              글로벌에서 국장이 요근래 제일 센듯???
# 25          시드머니1억으로매월100만원수익12달연속내는거.
# 26                      곱버스는 너무 비효율적인듯
# 27                 우리 사주(동전 주) 받았는데...
# 28              1년 한국 국채 금리 3.27% ????
# 29                           예금 2억 박았다
# 30                      오늘은 2400 깨지는 날
# 31                        아직도 행복회로 돌리냐
# 32                     요즘 내 심경이 이래....
# 33                       20대분들 평균 자산.?
# 34               금리인상하는데 발행어음금리 왜 내리죠?
# 35   사회초년생이라 부동산이든 주식이든 쳐물릴 시드도 없으면 개추
# 36        실비 알릴의무에 30일이상 투약이 안약도 해당되나?
# 37                            오늘도 날아보자
# 38       안팔았으면.손해아니라는말.공감합니까.공감하지않읍니까.
# 39                  하이닉스 낸드는 적자 얘기 나오네
# 40                            My money
# 41                         엔비디아 왜 난리야?
# 42                            나스닥선물 양전
# 43                   주식에 물리기 vs 집에 물리기
# 44                 1년전에 시작한 사람 힘들거야 ㅋㅋ
# 45                            내평단올까..?
# 46         아우 장난치지말고 빨리 반등좀 줘요!!!!!!!!
# 47                        오늘 국장 상승...?
# 48                      97년도랑 오버랩 되는듯해
# 49                          삼전 4만원 보겠다
#
#                                               CONTENT  POSITIVITY  NUM_REPLY  \
# 0                           4년 동안 투자했는데 결국 원금 -8천휴...    0.009610        NaN
# 1   작년 말부터 주식 전부 처분. 부동산도 한채 처분.해서 부동산 : 현금 50 : 5...    0.061993        NaN
# 2                                 왜 주식까지 삼전에 몰빵했을까...    0.019269        NaN
# 3                                 죽어나가?hmm은 나락만 가네 계속    0.072932        NaN
# 4                        지금 2억으로 쪼그라듬1년동안 무슨일이 있었던거야ㅠ    0.045163        NaN
# 5                                             둘다 발라먹음    0.088915        NaN
# 6                            남들이 다 아는 공포는 공포가 아닌거 알제?    0.004635        NaN
# 7             이더 198때 20개 매수하긴했는데 스테이킹 수량 마음대로 가능한가요?    0.001564        NaN
# 8                                              강추야???    3.728222        NaN
# 9                                          오만 전자~~~~~    0.081904        NaN
# 10  GDP대비 가계부채 세계 1등. 그중 가장 큰 비중은 주택 담보 대출. 그리고 75...    0.059635        NaN
# 11                                      🤔 지주사 전환 가속화네    0.021296        NaN
# 12                                  이미 4% 빠졌는데더 내려가려나    0.041883        NaN
# 13  땅은 부모님껀데개인이 건축업자랑 미팅하고 진행하는게통상적이라 알고있어근데 신탁사한테...    0.048599        NaN
# 14                                                 갓갓    0.016236        NaN
# 15                           자식 생각하는 부모 마음을 어찌 막으리..?    0.025853        NaN
# 16                                             고맙읍니다.    0.038443        NaN
# 17  7월쯤 푹 떨어졌다가 요즘 다시 슬금슬금 올라오는거같은데 증권강의같은거 보면 바닥에...    0.051433        NaN
# 18  박근혜 시절인가 2500 —&gt 4500 올랐을때 kt&G 주가랑 분위기 어땠는지...    0.390451        NaN
# 19  환율이 끝이 안 보이는데이러다가 타이밍 잘못 잡히면서 환전 후 투자 하면 주식 이익...    0.021131        NaN
# 20                            적금 예금 금리 높은 상품 추천해줘1금융~   99.927155        NaN
# 21                                         요즘 변동성 지기네    0.018715        NaN
# 22  책보면서 공부중이고 조금씩 소액 분산투자중인데 저축을 늘리고 싶어서 적립식 주식을 ...    0.050384        NaN
# 23                   의심해서 죄송합니다 갓스피님앞으로 킹갓황스피로 부르겠습니다    1.752718        NaN
# 24                                하락 제일 약하고 반등 빠르고???   91.273530        NaN
# 25                            쉬운일?어려운일?답변부탁합니다.고맙읍니다.   99.802400        NaN
# 26  성격은 세계파탄, 대공황 기원하면서 부정적으로 바뀌고나스닥 본다고오버나잇한다고 잠도...    0.007941        NaN
# 27                                      모 일단 우리 사주 받고    0.002171        NaN
# 28  우리 기준 금리가 이제 막 2.5에 왔는데, 1년 국채 금리가 3.27이면 내년 기...    0.046045        NaN
# 29                              집살돈으론 주식하면 랄부떨려서 안되겠다    0.057198        NaN
# 30  과연 전저점 이하로 뚫고 내려갈지한달 거품낄때 기분 좋았지?난 좋았어 한여름밤의 꿈...    0.033432        NaN
# 31                                 정신을 못차렸구나 QE 100배!    0.006723        NaN
# 32                       https://youtu.be/biXFnFITzzI    0.024816        NaN
# 33  보통 본인 능력으로만 투자+저축해서 돈을 모은다면 이십대 중후반 정도에 얼마 정도 ...    0.028973        NaN
# 34  기준금리 0.25% 인상하였는데, 181일물 금리는 왜 인하한걸까요?내부기준이나 정...    0.006278        NaN
# 35                                         일단 나부터 ㅋㅋㅋ    0.006045        NaN
# 36  알러지성 결막염이 있어서 안과갈때마다일회용 용기에 든 알러지안약 2박스 (1통에30...    0.032365        NaN
# 37                      오늘도 이수화학 날아보자♡씨아이에스도 같이 날아보자♡   93.847824        NaN
# 38             정말많이듣는말인데말같지않은말같아서여쭤봅니다답변부탁드립니다.고맙읍니다.    0.010089        NaN
# 39  http://www.sisajournal-e.com/news/articleView....    0.006801        NaN
# 40                     do jiggle jiggle. It falls…..ㅠ    0.042172        NaN
# 41  1주 -&gt 4주로 액면분할 받았으니까적어도 640불 이전에 산 사람들은 다 플러...    0.058777        NaN
# 42                                              !!!!!    0.051677        NaN
# 43                             일단 난 전자ㅋㅋㅋㅋㅋㅋㅋㅋㅜㅜ-3000    0.033690        NaN
# 44          1년전에 시작했는데시작하고 나서 금액이 점점 커졌고결과적으로 지금 -28%    0.011551        NaN
# 45                                               Sqqq    0.039563        NaN
# 46                          응으어어ㅓ가거거거어어어거겅어ㅓ야야어거거거어야갸    0.482311        NaN
# 47                                               ...?    0.169981        NaN
# 48                   97년도 상황인데.. 요즘 분위기가 많이 오버랩 되는듯..    0.039354        NaN
# 49                     오늘도 코스피 폭포수일듯 ㅜㅜ조만간 삼전 4만원 보겠다    0.354598        NaN
#
#     URL CRAWLING_DATETIME                    OTHERS
# 0   NaN   20220830-103135   {'comments_count': '1'}
# 1   NaN   20220830-103135   {'comments_count': '0'}
# 2   NaN   20220830-103135   {'comments_count': '2'}
# 3   NaN   20220830-103135   {'comments_count': '5'}
# 4   NaN   20220830-103135   {'comments_count': '5'}
# 5   NaN   20220830-103135   {'comments_count': '2'}
# 6   NaN   20220830-103135   {'comments_count': '4'}
# 7   NaN   20220830-103135   {'comments_count': '0'}
# 8   NaN   20220830-103135   {'comments_count': '8'}
# 9   NaN   20220830-103135   {'comments_count': '1'}
# 10  NaN   20220830-103135   {'comments_count': '8'}
# 11  NaN   20220830-103135   {'comments_count': '4'}
# 12  NaN   20220830-103135   {'comments_count': '3'}
# 13  NaN   20220830-103135   {'comments_count': '8'}
# 14  NaN   20220830-103135   {'comments_count': '4'}
# 15  NaN   20220830-103135   {'comments_count': '1'}
# 16  NaN   20220830-103135   {'comments_count': '1'}
# 17  NaN   20220830-103135   {'comments_count': '6'}
# 18  NaN   20220830-103135   {'comments_count': '4'}
# 19  NaN   20220830-103135   {'comments_count': '2'}
# 20  NaN   20220830-103135   {'comments_count': '3'}
# 21  NaN   20220830-103135   {'comments_count': '1'}
# 22  NaN   20220830-103135   {'comments_count': '8'}
# 23  NaN   20220830-103135   {'comments_count': '3'}
# 24  NaN   20220830-103135   {'comments_count': '7'}
# 25  NaN   20220830-103135   {'comments_count': '7'}
# 26  NaN   20220830-103135   {'comments_count': '2'}
# 27  NaN   20220830-103135   {'comments_count': '2'}
# 28  NaN   20220830-103135   {'comments_count': '3'}
# 29  NaN   20220830-103135   {'comments_count': '7'}
# 30  NaN   20220830-103135   {'comments_count': '5'}
# 31  NaN   20220830-103135   {'comments_count': '1'}
# 32  NaN   20220830-103135   {'comments_count': '1'}
# 33  NaN   20220830-103135  {'comments_count': '10'}
# 34  NaN   20220830-103135   {'comments_count': '0'}
# 35  NaN   20220830-103135   {'comments_count': '6'}
# 36  NaN   20220830-103135   {'comments_count': '1'}
# 37  NaN   20220830-103135   {'comments_count': '1'}
# 38  NaN   20220830-103135   {'comments_count': '7'}
# 39  NaN   20220830-103135   {'comments_count': '2'}
# 40  NaN   20220830-103135   {'comments_count': '2'}
# 41  NaN   20220830-103135   {'comments_count': '6'}
# 42  NaN   20220830-103135   {'comments_count': '3'}
# 43  NaN   20220830-103135   {'comments_count': '5'}
# 44  NaN   20220830-103135   {'comments_count': '8'}
# 45  NaN   20220830-103135   {'comments_count': '5'}
# 46  NaN   20220830-103135   {'comments_count': '4'}
# 47  NaN   20220830-103135   {'comments_count': '8'}
# 48  NaN   20220830-103135  {'comments_count': '19'}
# 49  NaN   20220830-103135   {'comments_count': '4'}

# %%
df_new = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_new['YYYYMMDD'] = df_new['DATETIME'] .str[:8]
df_new
# Out:
#        SOURCE  RELATED_ITEM         DATETIME  \
# 0   블라인드_주식투자           NaN  20220830-103132
# 1   블라인드_주식투자           NaN  20220830-103132
# 2   블라인드_주식투자           NaN  20220830-103132
# 3   블라인드_주식투자           NaN  20220830-103132
# 4   블라인드_주식투자           NaN  20220830-103132
# 5   블라인드_주식투자           NaN  20220830-103132
# 6   블라인드_주식투자           NaN  20220830-103132
# 7   블라인드_주식투자           NaN  20220830-103132
# 8   블라인드_주식투자           NaN  20220830-103132
# 9   블라인드_주식투자           NaN  20220830-103132
# 10  블라인드_주식투자           NaN  20220830-103132
# 11  블라인드_주식투자           NaN  20220830-103132
# 12  블라인드_주식투자           NaN  20220830-103132
# 13  블라인드_주식투자           NaN  20220830-103132
# 14  블라인드_주식투자           NaN  20220830-103132
# 15  블라인드_주식투자           NaN  20220830-103132
# 16  블라인드_주식투자           NaN  20220830-103132
# 17  블라인드_주식투자           NaN  20220830-103132
# 18  블라인드_주식투자           NaN  20220830-103132
# 19  블라인드_주식투자           NaN  20220830-103132
# 20  블라인드_주식투자           NaN  20220830-103132
# 21  블라인드_주식투자           NaN  20220830-103132
# 22  블라인드_주식투자           NaN  20220830-103132
# 23  블라인드_주식투자           NaN  20220830-103132
# 24  블라인드_주식투자           NaN  20220830-103132
# 25  블라인드_주식투자           NaN  20220830-103132
# 26  블라인드_주식투자           NaN  20220830-103132
# 27  블라인드_주식투자           NaN  20220830-103132
# 28  블라인드_주식투자           NaN  20220830-103132
# 29  블라인드_주식투자           NaN  20220830-103132
# 30  블라인드_주식투자           NaN  20220830-103132
# 31  블라인드_주식투자           NaN  20220830-103132
# 32  블라인드_주식투자           NaN  20220830-103132
# 33  블라인드_주식투자           NaN  20220830-103132
# 34  블라인드_주식투자           NaN  20220830-103132
# 35  블라인드_주식투자           NaN  20220830-103132
# 36  블라인드_주식투자           NaN  20220830-103132
# 37  블라인드_주식투자           NaN  20220830-103132
# 38  블라인드_주식투자           NaN  20220830-103132
# 39  블라인드_주식투자           NaN  20220830-103132
# 40  블라인드_주식투자           NaN  20220830-103132
# 41  블라인드_주식투자           NaN  20220830-103132
# 42  블라인드_주식투자           NaN  20220830-103132
# 43  블라인드_주식투자           NaN  20220830-103132
# 44  블라인드_주식투자           NaN  20220830-103132
# 45  블라인드_주식투자           NaN  20220830-103132
# 46  블라인드_주식투자           NaN  20220830-103132
# 47  블라인드_주식투자           NaN  20220830-103132
# 48  블라인드_주식투자           NaN  20220830-103132
# 49  블라인드_주식투자           NaN  20220830-103132
#
#                                  TITLE  \
# 0                         부모님 보기 죄송스럽다
# 1                           자산 배분 어케하냐
# 2   내가 삼성이어폰 종류별로 있고 노트북 태블릿 폰까지 갤럭시지만
# 3                           환율 오르면 hmm
# 4              불과 1년전에 주식잔고가 3억 5천이었는데
# 5                    레버리지 곱버스 잘하는 사람특징
# 6             어제 쫄아서 매도한 제주도 흙두루치기 없제?
# 7                       스테이킹 하시는분 있나요?
# 8              삼성전자우 지금 투자하기 딱 좋은 시기??
# 9                                 룰루루루
# 10               한국판 서브프라임 모기지 사태가 온다!
# 11                     Skc 52주 신저가 ~~
# 12                      지금 나스닥 들어가도 될까
# 13                    70평 땅에 원룸건물 지으려해
# 14                             소리바다 뭐여
# 15                         중국 사교육주 TAL
# 16                              한국맥널티.
# 17                      진짜 저점이 가을에 올까?
# 18          담배값 인상하면 KT&G 주가 얼마나 오르나요?
# 19                          달러 환율 투자??
# 20                 적금 예금 금리 높은 상품 추천해줘
# 21                           고려아연 무슨일?
# 22                                 주린이
# 23                 다시는 킹스피를 의심하지 않겠습니다
# 24              글로벌에서 국장이 요근래 제일 센듯???
# 25          시드머니1억으로매월100만원수익12달연속내는거.
# 26                      곱버스는 너무 비효율적인듯
# 27                 우리 사주(동전 주) 받았는데...
# 28              1년 한국 국채 금리 3.27% ????
# 29                           예금 2억 박았다
# 30                      오늘은 2400 깨지는 날
# 31                        아직도 행복회로 돌리냐
# 32                     요즘 내 심경이 이래....
# 33                       20대분들 평균 자산.?
# 34               금리인상하는데 발행어음금리 왜 내리죠?
# 35   사회초년생이라 부동산이든 주식이든 쳐물릴 시드도 없으면 개추
# 36        실비 알릴의무에 30일이상 투약이 안약도 해당되나?
# 37                            오늘도 날아보자
# 38       안팔았으면.손해아니라는말.공감합니까.공감하지않읍니까.
# 39                  하이닉스 낸드는 적자 얘기 나오네
# 40                            My money
# 41                         엔비디아 왜 난리야?
# 42                            나스닥선물 양전
# 43                   주식에 물리기 vs 집에 물리기
# 44                 1년전에 시작한 사람 힘들거야 ㅋㅋ
# 45                            내평단올까..?
# 46         아우 장난치지말고 빨리 반등좀 줘요!!!!!!!!
# 47                        오늘 국장 상승...?
# 48                      97년도랑 오버랩 되는듯해
# 49                          삼전 4만원 보겠다
#
#                                               CONTENT  POSITIVITY  NUM_REPLY  \
# 0                           4년 동안 투자했는데 결국 원금 -8천휴...    0.009610        NaN
# 1   작년 말부터 주식 전부 처분. 부동산도 한채 처분.해서 부동산 : 현금 50 : 5...    0.061993        NaN
# 2                                 왜 주식까지 삼전에 몰빵했을까...    0.019269        NaN
# 3                                 죽어나가?hmm은 나락만 가네 계속    0.072932        NaN
# 4                        지금 2억으로 쪼그라듬1년동안 무슨일이 있었던거야ㅠ    0.045163        NaN
# 5                                             둘다 발라먹음    0.088915        NaN
# 6                            남들이 다 아는 공포는 공포가 아닌거 알제?    0.004635        NaN
# 7             이더 198때 20개 매수하긴했는데 스테이킹 수량 마음대로 가능한가요?    0.001564        NaN
# 8                                              강추야???    3.728222        NaN
# 9                                          오만 전자~~~~~    0.081904        NaN
# 10  GDP대비 가계부채 세계 1등. 그중 가장 큰 비중은 주택 담보 대출. 그리고 75...    0.059635        NaN
# 11                                      🤔 지주사 전환 가속화네    0.021296        NaN
# 12                                  이미 4% 빠졌는데더 내려가려나    0.041883        NaN
# 13  땅은 부모님껀데개인이 건축업자랑 미팅하고 진행하는게통상적이라 알고있어근데 신탁사한테...    0.048599        NaN
# 14                                                 갓갓    0.016236        NaN
# 15                           자식 생각하는 부모 마음을 어찌 막으리..?    0.025853        NaN
# 16                                             고맙읍니다.    0.038443        NaN
# 17  7월쯤 푹 떨어졌다가 요즘 다시 슬금슬금 올라오는거같은데 증권강의같은거 보면 바닥에...    0.051433        NaN
# 18  박근혜 시절인가 2500 —&gt 4500 올랐을때 kt&G 주가랑 분위기 어땠는지...    0.390451        NaN
# 19  환율이 끝이 안 보이는데이러다가 타이밍 잘못 잡히면서 환전 후 투자 하면 주식 이익...    0.021131        NaN
# 20                            적금 예금 금리 높은 상품 추천해줘1금융~   99.927155        NaN
# 21                                         요즘 변동성 지기네    0.018715        NaN
# 22  책보면서 공부중이고 조금씩 소액 분산투자중인데 저축을 늘리고 싶어서 적립식 주식을 ...    0.050384        NaN
# 23                   의심해서 죄송합니다 갓스피님앞으로 킹갓황스피로 부르겠습니다    1.752718        NaN
# 24                                하락 제일 약하고 반등 빠르고???   91.273530        NaN
# 25                            쉬운일?어려운일?답변부탁합니다.고맙읍니다.   99.802400        NaN
# 26  성격은 세계파탄, 대공황 기원하면서 부정적으로 바뀌고나스닥 본다고오버나잇한다고 잠도...    0.007941        NaN
# 27                                      모 일단 우리 사주 받고    0.002171        NaN
# 28  우리 기준 금리가 이제 막 2.5에 왔는데, 1년 국채 금리가 3.27이면 내년 기...    0.046045        NaN
# 29                              집살돈으론 주식하면 랄부떨려서 안되겠다    0.057198        NaN
# 30  과연 전저점 이하로 뚫고 내려갈지한달 거품낄때 기분 좋았지?난 좋았어 한여름밤의 꿈...    0.033432        NaN
# 31                                 정신을 못차렸구나 QE 100배!    0.006723        NaN
# 32                       https://youtu.be/biXFnFITzzI    0.024816        NaN
# 33  보통 본인 능력으로만 투자+저축해서 돈을 모은다면 이십대 중후반 정도에 얼마 정도 ...    0.028973        NaN
# 34  기준금리 0.25% 인상하였는데, 181일물 금리는 왜 인하한걸까요?내부기준이나 정...    0.006278        NaN
# 35                                         일단 나부터 ㅋㅋㅋ    0.006045        NaN
# 36  알러지성 결막염이 있어서 안과갈때마다일회용 용기에 든 알러지안약 2박스 (1통에30...    0.032365        NaN
# 37                      오늘도 이수화학 날아보자♡씨아이에스도 같이 날아보자♡   93.847824        NaN
# 38             정말많이듣는말인데말같지않은말같아서여쭤봅니다답변부탁드립니다.고맙읍니다.    0.010089        NaN
# 39  http://www.sisajournal-e.com/news/articleView....    0.006801        NaN
# 40                     do jiggle jiggle. It falls…..ㅠ    0.042172        NaN
# 41  1주 -&gt 4주로 액면분할 받았으니까적어도 640불 이전에 산 사람들은 다 플러...    0.058777        NaN
# 42                                              !!!!!    0.051677        NaN
# 43                             일단 난 전자ㅋㅋㅋㅋㅋㅋㅋㅋㅜㅜ-3000    0.033690        NaN
# 44          1년전에 시작했는데시작하고 나서 금액이 점점 커졌고결과적으로 지금 -28%    0.011551        NaN
# 45                                               Sqqq    0.039563        NaN
# 46                          응으어어ㅓ가거거거어어어거겅어ㅓ야야어거거거어야갸    0.482311        NaN
# 47                                               ...?    0.169981        NaN
# 48                   97년도 상황인데.. 요즘 분위기가 많이 오버랩 되는듯..    0.039354        NaN
# 49                     오늘도 코스피 폭포수일듯 ㅜㅜ조만간 삼전 4만원 보겠다    0.354598        NaN
#
#     URL CRAWLING_DATETIME                    OTHERS  YYYYMMDD
# 0   NaN   20220830-103135   {'comments_count': '1'}  20220830
# 1   NaN   20220830-103135   {'comments_count': '0'}  20220830
# 2   NaN   20220830-103135   {'comments_count': '2'}  20220830
# 3   NaN   20220830-103135   {'comments_count': '5'}  20220830
# 4   NaN   20220830-103135   {'comments_count': '5'}  20220830
# 5   NaN   20220830-103135   {'comments_count': '2'}  20220830
# 6   NaN   20220830-103135   {'comments_count': '4'}  20220830
# 7   NaN   20220830-103135   {'comments_count': '0'}  20220830
# 8   NaN   20220830-103135   {'comments_count': '8'}  20220830
# 9   NaN   20220830-103135   {'comments_count': '1'}  20220830
# 10  NaN   20220830-103135   {'comments_count': '8'}  20220830
# 11  NaN   20220830-103135   {'comments_count': '4'}  20220830
# 12  NaN   20220830-103135   {'comments_count': '3'}  20220830
# 13  NaN   20220830-103135   {'comments_count': '8'}  20220830
# 14  NaN   20220830-103135   {'comments_count': '4'}  20220830
# 15  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 16  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 17  NaN   20220830-103135   {'comments_count': '6'}  20220830
# 18  NaN   20220830-103135   {'comments_count': '4'}  20220830
# 19  NaN   20220830-103135   {'comments_count': '2'}  20220830
# 20  NaN   20220830-103135   {'comments_count': '3'}  20220830
# 21  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 22  NaN   20220830-103135   {'comments_count': '8'}  20220830
# 23  NaN   20220830-103135   {'comments_count': '3'}  20220830
# 24  NaN   20220830-103135   {'comments_count': '7'}  20220830
# 25  NaN   20220830-103135   {'comments_count': '7'}  20220830
# 26  NaN   20220830-103135   {'comments_count': '2'}  20220830
# 27  NaN   20220830-103135   {'comments_count': '2'}  20220830
# 28  NaN   20220830-103135   {'comments_count': '3'}  20220830
# 29  NaN   20220830-103135   {'comments_count': '7'}  20220830
# 30  NaN   20220830-103135   {'comments_count': '5'}  20220830
# 31  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 32  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 33  NaN   20220830-103135  {'comments_count': '10'}  20220830
# 34  NaN   20220830-103135   {'comments_count': '0'}  20220830
# 35  NaN   20220830-103135   {'comments_count': '6'}  20220830
# 36  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 37  NaN   20220830-103135   {'comments_count': '1'}  20220830
# 38  NaN   20220830-103135   {'comments_count': '7'}  20220830
# 39  NaN   20220830-103135   {'comments_count': '2'}  20220830
# 40  NaN   20220830-103135   {'comments_count': '2'}  20220830
# 41  NaN   20220830-103135   {'comments_count': '6'}  20220830
# 42  NaN   20220830-103135   {'comments_count': '3'}  20220830
# 43  NaN   20220830-103135   {'comments_count': '5'}  20220830
# 44  NaN   20220830-103135   {'comments_count': '8'}  20220830
# 45  NaN   20220830-103135   {'comments_count': '5'}  20220830
# 46  NaN   20220830-103135   {'comments_count': '4'}  20220830
# 47  NaN   20220830-103135   {'comments_count': '8'}  20220830
# 48  NaN   20220830-103135  {'comments_count': '19'}  20220830
# 49  NaN   20220830-103135   {'comments_count': '4'}  20220830

# %%
df_already = pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE = '블라인드_주식투자'",conn)
df_already['YYYYMMDD'] = df_already['DATETIME'] .str[:8]
df_already
# Out:
#           SOURCE RELATED_ITEM         DATETIME                  TITLE  \
# 0      블라인드_주식투자         None  20220708-085444    이상한 변호사 우영우 드라마 봐요?
# 1      블라인드_주식투자         None  20220708-085444    HPSP 공모주 결과 나옴 확인ㄱㄱ
# 2      블라인드_주식투자         None  20220708-085444      비트는 그냥 완전 나스닥의 개네
# 3      블라인드_주식투자         None  20220708-085444  형누님들 제테크좀 알려주세요...!!!
# 4      블라인드_주식투자         None  20220708-085444               아베가 골로갔다
# ...          ...          ...              ...                    ...
# 23064  블라인드_주식투자         None  20220830-084847              망해봐서 쓰는 글
# 23065  블라인드_주식투자         None  20220830-084847                 나스닥 폭망
# 23066  블라인드_주식투자         None  20220830-084847         티큐큐큐 물렸어 오케 ㅠㅠ
# 23067  블라인드_주식투자         None  20220830-084847            셀트리온 어떻게생각해
# 23068  블라인드_주식투자         None  20220830-084847                     망텔
#
#                                                  CONTENT  POSITIVITY  \
# 0      이상한 변호사 우영우라는 드라마가 있는데🍯꿀잼🍯이거든요1화 보고 제가 가장 먼저 한...   46.151110
# 1                                              많이 받았누ㅋㅋㅋ    0.055281
# 2                                            이런게 탈중앙화 라니    0.006330
# 3      현재 중금채 예금으로 하나 갖고있고정기적금2개 자유적금1개 가지고 있어요.그래서 자...    0.078738
# 4                                            모나미말고 뭐사면돼?    0.011195
# ...                                                  ...         ...
# 23064  1.기본 베이스는 회사의 실적, 가치, 현금 흐름을 봐야됨2. 매크로 중요함. 근데...    0.006272
# 23065                              올해 말까지 떨어질 예정반박시 만수무강    0.006292
# 23066                                            어뜨케 ㅠㅠㅠ    0.053120
# 23067                                         내일 투자할까하는데    0.028045
# 23068                                  6년전 주가네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ    0.006614
#
#       NUM_REPLY   URL CRAWLING_DATETIME  \
# 0            44  None   20220805-085444
# 1             2  None   20220805-085444
# 2            10  None   20220805-085444
# 3             3  None   20220805-085444
# 4             5  None   20220805-085444
# ...         ...   ...               ...
# 23064      None  None   20220830-084850
# 23065      None  None   20220830-084850
# 23066      None  None   20220830-084850
# 23067      None  None   20220830-084850
# 23068      None  None   20220830-084850
#
#                                                   OTHERS  YYYYMMDD
# 0      {'LIKES': 0, 'VIEWS': '1,066', 'COMMENTS': '드라...  20220708
# 1      {'LIKES': 1, 'VIEWS': '501', 'COMMENTS': '6000...  20220708
# 2      {'LIKES': 2, 'VIEWS': '408', 'COMMENTS': '미국이 ...  20220708
# 3      {'LIKES': 1, 'VIEWS': '141', 'COMMENTS': '재테크 ...  20220708
# 4      {'LIKES': 1, 'VIEWS': '648', 'COMMENTS': '신고에 ...  20220708
# ...                                                  ...       ...
# 23064                            {'comments_count': '5'}  20220830
# 23065                            {'comments_count': '6'}  20220830
# 23066                           {'comments_count': '13'}  20220830
# 23067                            {'comments_count': '4'}  20220830
# 23068                            {'comments_count': '5'}  20220830
#
# [23069 rows x 11 columns]

# %%
df_ttl = df_new[~df_new.index .isin(df_new.merge(df_already, on=['YYYYMMDD','TITLE']).index)]
df_ttl = df_ttl.drop(['YYYYMMDD'],axis=1)
df_ttl
# Out:
# Empty DataFrame
# Columns: [SOURCE, RELATED_ITEM, DATETIME, TITLE, CONTENT, POSITIVITY, NUM_REPLY, URL, CRAWLING_DATETIME, OTHERS]
# Index: []

# %%
df_new = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_new['YYYYMMDD'] = df_new['DATETIME'] .str[:8]
df_new

## 기존 DF에서 겹치는꺼 빼야하니 기존꺼ㅏ 불러오기

df_already = pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE = '블라인드_주식투자'",conn)
df_already
df_already['YYYYMMDD'] = df_already['DATETIME'] .str[:8]

# %%
df_ttl = df_new.iloc[:df_new.merge(df_already, on=['YYYYMMDD','TITLE'], how='left')['CONTENT_y'].dropna().index[0]]
df_ttl = df_ttl.drop(['YYYYMMDD'],axis=1)
df_ttl
# Out:
#        SOURCE  RELATED_ITEM         DATETIME  \
# 0   블라인드_주식투자           NaN  20220830-103132
# 1   블라인드_주식투자           NaN  20220830-103132
# 2   블라인드_주식투자           NaN  20220830-103132
# 3   블라인드_주식투자           NaN  20220830-103132
# 4   블라인드_주식투자           NaN  20220830-103132
# 5   블라인드_주식투자           NaN  20220830-103132
# 6   블라인드_주식투자           NaN  20220830-103132
# 7   블라인드_주식투자           NaN  20220830-103132
# 8   블라인드_주식투자           NaN  20220830-103132
# 9   블라인드_주식투자           NaN  20220830-103132
# 10  블라인드_주식투자           NaN  20220830-103132
# 11  블라인드_주식투자           NaN  20220830-103132
# 12  블라인드_주식투자           NaN  20220830-103132
# 13  블라인드_주식투자           NaN  20220830-103132
# 14  블라인드_주식투자           NaN  20220830-103132
# 15  블라인드_주식투자           NaN  20220830-103132
# 16  블라인드_주식투자           NaN  20220830-103132
# 17  블라인드_주식투자           NaN  20220830-103132
# 18  블라인드_주식투자           NaN  20220830-103132
# 19  블라인드_주식투자           NaN  20220830-103132
# 20  블라인드_주식투자           NaN  20220830-103132
# 21  블라인드_주식투자           NaN  20220830-103132
# 22  블라인드_주식투자           NaN  20220830-103132
# 23  블라인드_주식투자           NaN  20220830-103132
# 24  블라인드_주식투자           NaN  20220830-103132
# 25  블라인드_주식투자           NaN  20220830-103132
# 26  블라인드_주식투자           NaN  20220830-103132
# 27  블라인드_주식투자           NaN  20220830-103132
# 28  블라인드_주식투자           NaN  20220830-103132
# 29  블라인드_주식투자           NaN  20220830-103132
# 30  블라인드_주식투자           NaN  20220830-103132
# 31  블라인드_주식투자           NaN  20220830-103132
# 32  블라인드_주식투자           NaN  20220830-103132
#
#                                  TITLE  \
# 0                         부모님 보기 죄송스럽다
# 1                           자산 배분 어케하냐
# 2   내가 삼성이어폰 종류별로 있고 노트북 태블릿 폰까지 갤럭시지만
# 3                           환율 오르면 hmm
# 4              불과 1년전에 주식잔고가 3억 5천이었는데
# 5                    레버리지 곱버스 잘하는 사람특징
# 6             어제 쫄아서 매도한 제주도 흙두루치기 없제?
# 7                       스테이킹 하시는분 있나요?
# 8              삼성전자우 지금 투자하기 딱 좋은 시기??
# 9                                 룰루루루
# 10               한국판 서브프라임 모기지 사태가 온다!
# 11                     Skc 52주 신저가 ~~
# 12                      지금 나스닥 들어가도 될까
# 13                    70평 땅에 원룸건물 지으려해
# 14                             소리바다 뭐여
# 15                         중국 사교육주 TAL
# 16                              한국맥널티.
# 17                      진짜 저점이 가을에 올까?
# 18          담배값 인상하면 KT&G 주가 얼마나 오르나요?
# 19                          달러 환율 투자??
# 20                 적금 예금 금리 높은 상품 추천해줘
# 21                           고려아연 무슨일?
# 22                                 주린이
# 23                 다시는 킹스피를 의심하지 않겠습니다
# 24              글로벌에서 국장이 요근래 제일 센듯???
# 25          시드머니1억으로매월100만원수익12달연속내는거.
# 26                      곱버스는 너무 비효율적인듯
# 27                 우리 사주(동전 주) 받았는데...
# 28              1년 한국 국채 금리 3.27% ????
# 29                           예금 2억 박았다
# 30                      오늘은 2400 깨지는 날
# 31                        아직도 행복회로 돌리냐
# 32                     요즘 내 심경이 이래....
#
#                                               CONTENT  POSITIVITY  NUM_REPLY  \
# 0                           4년 동안 투자했는데 결국 원금 -8천휴...    0.009610        NaN
# 1   작년 말부터 주식 전부 처분. 부동산도 한채 처분.해서 부동산 : 현금 50 : 5...    0.061993        NaN
# 2                                 왜 주식까지 삼전에 몰빵했을까...    0.019269        NaN
# 3                                 죽어나가?hmm은 나락만 가네 계속    0.072932        NaN
# 4                        지금 2억으로 쪼그라듬1년동안 무슨일이 있었던거야ㅠ    0.045163        NaN
# 5                                             둘다 발라먹음    0.088915        NaN
# 6                            남들이 다 아는 공포는 공포가 아닌거 알제?    0.004635        NaN
# 7             이더 198때 20개 매수하긴했는데 스테이킹 수량 마음대로 가능한가요?    0.001564        NaN
# 8                                              강추야???    3.728222        NaN
# 9                                          오만 전자~~~~~    0.081904        NaN
# 10  GDP대비 가계부채 세계 1등. 그중 가장 큰 비중은 주택 담보 대출. 그리고 75...    0.059635        NaN
# 11                                      🤔 지주사 전환 가속화네    0.021296        NaN
# 12                                  이미 4% 빠졌는데더 내려가려나    0.041883        NaN
# 13  땅은 부모님껀데개인이 건축업자랑 미팅하고 진행하는게통상적이라 알고있어근데 신탁사한테...    0.048599        NaN
# 14                                                 갓갓    0.016236        NaN
# 15                           자식 생각하는 부모 마음을 어찌 막으리..?    0.025853        NaN
# 16                                             고맙읍니다.    0.038443        NaN
# 17  7월쯤 푹 떨어졌다가 요즘 다시 슬금슬금 올라오는거같은데 증권강의같은거 보면 바닥에...    0.051433        NaN
# 18  박근혜 시절인가 2500 —&gt 4500 올랐을때 kt&G 주가랑 분위기 어땠는지...    0.390451        NaN
# 19  환율이 끝이 안 보이는데이러다가 타이밍 잘못 잡히면서 환전 후 투자 하면 주식 이익...    0.021131        NaN
# 20                            적금 예금 금리 높은 상품 추천해줘1금융~   99.927155        NaN
# 21                                         요즘 변동성 지기네    0.018715        NaN
# 22  책보면서 공부중이고 조금씩 소액 분산투자중인데 저축을 늘리고 싶어서 적립식 주식을 ...    0.050384        NaN
# 23                   의심해서 죄송합니다 갓스피님앞으로 킹갓황스피로 부르겠습니다    1.752718        NaN
# 24                                하락 제일 약하고 반등 빠르고???   91.273530        NaN
# 25                            쉬운일?어려운일?답변부탁합니다.고맙읍니다.   99.802400        NaN
# 26  성격은 세계파탄, 대공황 기원하면서 부정적으로 바뀌고나스닥 본다고오버나잇한다고 잠도...    0.007941        NaN
# 27                                      모 일단 우리 사주 받고    0.002171        NaN
# 28  우리 기준 금리가 이제 막 2.5에 왔는데, 1년 국채 금리가 3.27이면 내년 기...    0.046045        NaN
# 29                              집살돈으론 주식하면 랄부떨려서 안되겠다    0.057198        NaN
# 30  과연 전저점 이하로 뚫고 내려갈지한달 거품낄때 기분 좋았지?난 좋았어 한여름밤의 꿈...    0.033432        NaN
# 31                                 정신을 못차렸구나 QE 100배!    0.006723        NaN
# 32                       https://youtu.be/biXFnFITzzI    0.024816        NaN
#
#     URL CRAWLING_DATETIME                   OTHERS
# 0   NaN   20220830-103135  {'comments_count': '1'}
# 1   NaN   20220830-103135  {'comments_count': '0'}
# 2   NaN   20220830-103135  {'comments_count': '2'}
# 3   NaN   20220830-103135  {'comments_count': '5'}
# 4   NaN   20220830-103135  {'comments_count': '5'}
# 5   NaN   20220830-103135  {'comments_count': '2'}
# 6   NaN   20220830-103135  {'comments_count': '4'}
# 7   NaN   20220830-103135  {'comments_count': '0'}
# 8   NaN   20220830-103135  {'comments_count': '8'}
# 9   NaN   20220830-103135  {'comments_count': '1'}
# 10  NaN   20220830-103135  {'comments_count': '8'}
# 11  NaN   20220830-103135  {'comments_count': '4'}
# 12  NaN   20220830-103135  {'comments_count': '3'}
# 13  NaN   20220830-103135  {'comments_count': '8'}
# 14  NaN   20220830-103135  {'comments_count': '4'}
# 15  NaN   20220830-103135  {'comments_count': '1'}
# 16  NaN   20220830-103135  {'comments_count': '1'}
# 17  NaN   20220830-103135  {'comments_count': '6'}
# 18  NaN   20220830-103135  {'comments_count': '4'}
# 19  NaN   20220830-103135  {'comments_count': '2'}
# 20  NaN   20220830-103135  {'comments_count': '3'}
# 21  NaN   20220830-103135  {'comments_count': '1'}
# 22  NaN   20220830-103135  {'comments_count': '8'}
# 23  NaN   20220830-103135  {'comments_count': '3'}
# 24  NaN   20220830-103135  {'comments_count': '7'}
# 25  NaN   20220830-103135  {'comments_count': '7'}
# 26  NaN   20220830-103135  {'comments_count': '2'}
# 27  NaN   20220830-103135  {'comments_count': '2'}
# 28  NaN   20220830-103135  {'comments_count': '3'}
# 29  NaN   20220830-103135  {'comments_count': '7'}
# 30  NaN   20220830-103135  {'comments_count': '5'}
# 31  NaN   20220830-103135  {'comments_count': '1'}
# 32  NaN   20220830-103135  {'comments_count': '1'}

# %%
if len(df_ttl) >0:
    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " SUCCESS  : ",len(df_ttl))

else:
    print((datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " NO DATA TO UPDATE")
# Out:
# 20220830-090426  NO DATA TO UPDATE

# %%
## 기존 DF에서 겹치는꺼 빼야하니 기존꺼ㅏ 불러오기

df = pd.read_sql('SELECT * FROM BLIND_STOCK',conn)
df
# Out:
#            date                       title  \
# 0      20220708         이상한 변호사 우영우 드라마 봐요?
# 1      20220708         HPSP 공모주 결과 나옴 확인ㄱㄱ
# 2      20220708           비트는 그냥 완전 나스닥의 개네
# 3      20220708       형누님들 제테크좀 알려주세요...!!!
# 4      20220708                    아베가 골로갔다
# ...         ...                         ...
# 25572  20220824                         주린이
# 25573  20220824     지금 타이밍 VTI나 VOO 분할매수 어때
# 25574  20220824      코스피 훼이크 상승에 낚인 흑우들 업제?
# 25575  20220824  운동하고 편의점 앞에서 정체모를 벌레에 쏘였어요
# 25576  20220824              해외주식 다들 어디서 해?
#
#                                                     main  \
# 0      이상한 변호사 우영우라는 드라마가 있는데🍯꿀잼🍯이거든요1화 보고 제가 가장 먼저 한...
# 1                                              많이 받았누ㅋㅋㅋ
# 2                                            이런게 탈중앙화 라니
# 3      현재 중금채 예금으로 하나 갖고있고정기적금2개 자유적금1개 가지고 있어요.그래서 자...
# 4                                            모나미말고 뭐사면돼?
# ...                                                  ...
# 25572                     주린이 주식 추천 좀그리고 보통 언제마다 몇 주씩 사?
# 25573  장기 3년 이상 보고 가는거면 언제 들어가도 상관 X지?5000불 환전해놓은거 어제...
# 25574                        유구한 전강후약 전통의 코스피 나락 시원하게 빼노
# 25575  쏘인건지 물린건지 모르겠는데..파스바른거 처럼 화끈화끈히네요혹시 아시는분...난생 ...
# 25576                         늦었지만 관심 가져 보려구.. 방법 좀 알려줘~
#
#                                                 comments looks_count  \
# 0      드라마 너무 재밌지. 근데 저점 대비 너무 너무 많이 올라서 지금 사면 큰일나. 이...       1,066
# 1                       6000주 샀지만 내년에나 팔 수 있겠네요\n몇개없노ㅋ\n         501
# 2      미국이 기를쓰고 장악하려는 이유\n탈중앙화를 막기위한 미국의 개입?\nㄹㅇ 걍 5q...         408
# 3            재테크 책부터 읽으시는거 추천합니다\n중금채???\n네 기업은행 중금채요!\n         141
# 4             신고에 의해 숨김 처리 되었습니다.\n\n엔화\n골로프킨\n골판지 인버스\n         648
# ...                                                  ...         ...
# 25572  사람들이 곡소리 내면 술값 담뱃값으로 사. 주린이면 적당히 업계 1순위만 골라 사도...          69
# 25573              유 토스 자동모으기는 소수점 거래인가???\n분할매수면 상관없지\n         121
# 25574  더 빼봐 더 빼봐\n음전까지는 안갈듯?\n음전 직전\n와우 ㅋㅋㅋㅋ역시 코스피\n짜...         134
# 25575  벌\n의사 태그를 달아보시는게\n이런거 달지마\n알려드리면 불법입니다\n이제 곧 손...         450
# 25576  증권사어플. 근데 지금은 마니 늦음\n아 글을 보니 지금 들어가야겠내\nㅋㅋㅋㅋ그래...         214
#
#        likes_count  comments_count          updated
# 0                0              44  20220805-085444
# 1                1               2  20220805-085444
# 2                2              10  20220805-085444
# 3                1               3  20220805-085444
# 4                1               5  20220805-085444
# ...            ...             ...              ...
# 25572            0               6  20220824-123420
# 25573            1               2  20220824-123420
# 25574            0               6  20220824-123420
# 25575            1              14  20220824-123420
# 25576            0              10  20220824-123420
#
# [25577 rows x 8 columns]

# %%
from selenium.webdriver.common.by import By
import requests
import re
import pandas as pd
import numpy as np
import datetime
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import warnings
warnings.filterwarnings('ignore')
import sqlite3
from bs4 import BeautifulSoup, BeautifulStoneSoup
import json
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent={0}'.format(user_agent))
# options =  webdriver.Chrome('/home/porter/NOTEBOOK/chromedriver',options=options)
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan     
    
    
    

CNT = 100
cnt = CNT

url = "https://www.teamblind.com/kr/topics/주식·투자"
driver = webdriver.Chrome('/home/lsi8505/chromedriver',options=options)
driver.get(url)

while cnt:
#         print(cnt)
    driver.find_element(By.TAG_NAME,'body').send_keys(Keys.PAGE_DOWN)

#     driver.find_element_by_tag_name('body').send_keys(Keys.PAGE_DOWN)
    cnt -= 1

bs_obj = BeautifulStoneSoup(driver.page_source)
div = bs_obj.find('div', {'class': 'article-list '})
posts = div.find_all('div', {'class' : 'tit'})
posts_title = []
for t in posts:
    try:
        posts_title.append(t.find('a').find('span').decompose().text.strip())
    except:
        posts_title.append(t.find('a').text.strip())
posts_href = []
for l in posts:
    tmp = l.find('a')['href']
    posts_href.append(tmp[tmp.rfind('-'):])
posts_title = [re.sub(r'[~()%":\'/,!?]', '', i).replace(' ', '-').replace('\n', '') for i in posts_title]

root_path = "https://www.teamblind.com/kr/post/"
list_url = list()
list_url2 = list()
cnt = 0
#     print('처리 들어간다')

## 크롤링
for title, link in zip(posts_title, posts_href):
    # cnt += 1
    title2 = re.sub('[.]', '', title)
    list_url.append(root_path + title + link)
    list_url2.append(root_path + title2 + link)
url_dirs = pd.DataFrame({'url_raw' : list_url, 'url' : list_url2})
#     url_dirs.to_csv('urls.csv')
data = []
for i in range(len(url_dirs)):
#     print(i ," // ", len(url_dirs), "// ", url_dirs.loc[i,'url'] )
    headers = {'User-Agent': 'Mozilla/5.0'} 
    response = requests.get(url_dirs.loc[i,'url'],  headers=headers)
    response

    bs_obj = BeautifulSoup(response.text)
    title = bs_obj.find('div', {'class' : 'article-view-head'})
    main = bs_obj.find('div', {'class' : 'article-view-contents'})
    like = bs_obj.find('div', {'class' : 'article_info'})
    comment = bs_obj.find('div', {'class' : 'article-comments'})
    try:
        ti = title.find('h2').text # 제목
        da = title.find('span', {'class' : 'date'}).text.replace('작성일', '') # 날짜
        if '일' in da:
            tmp = int(da.replace('일', ''))
            da = (datetime.datetime.today().date() - datetime.timedelta(days = tmp)).strftime('%Y%m%d')
        elif '어제' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 1)).strftime('%Y%m%d')
        elif '분' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')
        elif '시간' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')
        elif '초' in da:
            da = (datetime.datetime.today().date() - datetime.timedelta(days = 0)).strftime('%Y%m%d')

        lo = title.find('span', {'class' : 'pv'}).text.replace('조회수', '') # 조회수

        tmp = main.find('p', {'class' : 'contents-txt'}).text # 본문
        try:
            tmp = tmp[:tmp.index('  ')]
        except:
            pass
        tmp

        try:
            li = like.find('a', {'class' : 'like'}).text.replace('좋아요', '') # 좋아요 수
            if not li:
                li = 0
        except:
            li = 0

        cc = comment.find('h3').text.replace('댓글 ', '') # 댓글 갯수

        if '0' == cc: # 댓글
            co = 0
        else:
            co = ''
            for c in comment.find_all('p', {'class' : 'cmt-txt'}):
                c = c.text
                try:
                    co += (c[:c.index('작성일')] + '\n')
                except:
                    co += (c + '\n')

        dict_data = {'date':da, 'title' : ti, 'main' : tmp, 'comments' : co, 'looks_count' : lo, 'likes_count' : li, 'comments_count' : cc}
    #     print(dict_data)
        data.append(dict_data)

    except:
        print("SPECIAL CHARACTER IN TITLE")    
    time.sleep(0.5)

    
df_ = pd.DataFrame(data).iloc[2:].reset_index(drop=True)

df_['DATETIME'] = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['VIEWS'] = df_['looks_count']
df_['LIKES'] = df_['likes_count']
df_['TITLE'] =  df_['title']
df_['CONTENT'] = df_['main']
df_['WRITER'] = np.nan

df_['SOURCE'] = "블라인드_주식투자"
df_['RELATED_ITEM'] = np.nan
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['comments_count']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)
df_['NUM_REPLY'] = np.nan
df_['CRAWLING_DATETIME'] = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['URL'] =  np.nan
df_ = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_

df_new = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_new['YYYYMMDD'] = df_new['DATETIME'] .str[:8]
df_new

## 기존 DF에서 겹치는꺼 빼야하니 기존꺼ㅏ 불러오기

df_already = pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE = '블라인드_주식투자'",conn)
df_already
df_already['YYYYMMDD'] = df_already['DATETIME'] .str[:8]
if len(df_new.merge(df_already, on=['YYYYMMDD','TITLE'], how='left')['CONTENT_y'].dropna()) ==0:
    df_ttl = df_new.copy()
else:
    print("==========")
    df_ttl = df_new.iloc[:df_new.merge(df_already, on=['YYYYMMDD','TITLE'], how='left')['CONTENT_y'].dropna().index[0]]

df_ttl = df_ttl.drop(['YYYYMMDD'],axis=1)
df_ttl
# Out:
# SPECIAL CHARACTER IN TITLE

# %%
len(df_new.merge(df_already, on=['YYYYMMDD','TITLE'], how='left')['CONTENT_y'].dropna())
# Out:
# 0

# %%
df_already
# Out:
#           SOURCE RELATED_ITEM         DATETIME                   TITLE  \
# 0      블라인드_주식투자         None  20220708-085444     이상한 변호사 우영우 드라마 봐요?
# 1      블라인드_주식투자         None  20220708-085444     HPSP 공모주 결과 나옴 확인ㄱㄱ
# 2      블라인드_주식투자         None  20220708-085444       비트는 그냥 완전 나스닥의 개네
# 3      블라인드_주식투자         None  20220708-085444   형누님들 제테크좀 알려주세요...!!!
# 4      블라인드_주식투자         None  20220708-085444                아베가 골로갔다
# ...          ...          ...              ...                     ...
# 23306  블라인드_주식투자         None  20220830-231607  Soxl 52주 최고가가 74달러네 ㄷㄷ
# 23307  블라인드_주식투자         None  20220830-231607       저축및투자 분배 조언부탁드립니다
# 23308  블라인드_주식투자         None  20220830-231607                    고급정보
# 23309  블라인드_주식투자         None  20220830-231607      아빠 알약으로 컴퓨터 먹통되셔서
# 23310  블라인드_주식투자         None  20220830-231607       해외주식하려면 나무? 미래에셋?
#
#                                                  CONTENT  POSITIVITY  \
# 0      이상한 변호사 우영우라는 드라마가 있는데🍯꿀잼🍯이거든요1화 보고 제가 가장 먼저 한...   46.151110
# 1                                              많이 받았누ㅋㅋㅋ    0.055281
# 2                                            이런게 탈중앙화 라니    0.006330
# 3      현재 중금채 예금으로 하나 갖고있고정기적금2개 자유적금1개 가지고 있어요.그래서 자...    0.078738
# 4                                            모나미말고 뭐사면돼?    0.011195
# ...                                                  ...         ...
# 23306                               그때 산 사람들은 언제 구조될까...    0.315377
# 23307  부동산 보유하는게 꿈인 회사입사 0년차입니다 ㅎㅎㅎㅎ저축투자 가능금액은 150입니다...    0.027932
# 23308  cpi 발표 전까지 하락 -&gt 8월 cpi 발표 후 fomc까지 랠리가 있을 가...    0.052083
# 23309  https://n.news.naver.com/mnews/article/009/000...    0.003429
# 23310  매매 수수료랑 환전율 고려했을때 어디가 나을까..At&t 배당소득세 보면 나무 조금...    0.028981
#
#       NUM_REPLY   URL CRAWLING_DATETIME  \
# 0            44  None   20220805-085444
# 1             2  None   20220805-085444
# 2            10  None   20220805-085444
# 3             3  None   20220805-085444
# 4             5  None   20220805-085444
# ...         ...   ...               ...
# 23306      None  None   20220830-231610
# 23307      None  None   20220830-231610
# 23308      None  None   20220830-231610
# 23309      None  None   20220830-231610
# 23310      None  None   20220830-231610
#
#                                                   OTHERS  YYYYMMDD
# 0      {'LIKES': 0, 'VIEWS': '1,066', 'COMMENTS': '드라...  20220708
# 1      {'LIKES': 1, 'VIEWS': '501', 'COMMENTS': '6000...  20220708
# 2      {'LIKES': 2, 'VIEWS': '408', 'COMMENTS': '미국이 ...  20220708
# 3      {'LIKES': 1, 'VIEWS': '141', 'COMMENTS': '재테크 ...  20220708
# 4      {'LIKES': 1, 'VIEWS': '648', 'COMMENTS': '신고에 ...  20220708
# ...                                                  ...       ...
# 23306                            {'comments_count': '1'}  20220830
# 23307                            {'comments_count': '9'}  20220830
# 23308                            {'comments_count': '4'}  20220830
# 23309                            {'comments_count': '2'}  20220830
# 23310                            {'comments_count': '5'}  20220830
#
# [23311 rows x 11 columns]

# %%
if len(df_ttl) >0:
    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " SUCCESS  : ",len(df_ttl))

else:
    print((datetime.datetime.now() + datetime.timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " NO DATA TO UPDATE")
