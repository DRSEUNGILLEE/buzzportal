# %%
import sqlite3 
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

import pandas as pd
import xmltodict
import requests
import os
import json
import numpy as np
from datetime import datetime, timedelta
client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan

# %%
appid = 1255352523

# %%
url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid
try:
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)
    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]
    
except Exception as e:
    print (url)
    print ('\tNo Reviews: appid %i' %appid)
    print ('\tException:', e)

# %%
result = list()
for idx in range(1, 14+1):
    url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
#     print(url)
    response = requests.get(url).content.decode('utf8')
    try:
        xml = xmltodict.parse(response)
    except Exception as e:
        print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
        continue

    try:
        num_reivews= len(xml['feed']['entry'])
    except Exception as e:
        print ('\tNo Entry', e)
        continue

    try:
        xml['feed']['entry'][0]['author']['name']
        single_reviews = False
    except:
        #print ('\tOnly 1 review!!!')
        single_reviews = True
        pass

    if single_reviews:
            result.append({
                'USER': xml['feed']['entry']['author']['name'],
                'DATE': xml['feed']['entry']['updated'],
                'STAR': int(xml['feed']['entry']['im:rating']),
                'LIKE': int(xml['feed']['entry']['im:voteSum']),
                'TITLE': xml['feed']['entry']['title'],
                'REVIEW': xml['feed']['entry']['content'][0]['#text'],
            })
    else:
        for i in range(len(xml['feed']['entry'])):
            result.append({
                'USER': xml['feed']['entry'][i]['author']['name'],
                'DATE': xml['feed']['entry'][i]['updated'],
                'STAR': int(xml['feed']['entry'][i]['im:rating']),
                'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                'TITLE': xml['feed']['entry'][i]['title'],
                'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
            })

df_ = pd.DataFrame(result)
df_
# Out:
# 	No Entry 'entry'
# 	No Entry 'entry'
# 	No Entry 'entry'
# 	No Entry 'entry'
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=11/id=1255352523/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1255352523/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=12/id=1255352523/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1255352523/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=13/id=1255352523/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1255352523/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=14/id=1255352523/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1255352523/sortBy=mostRecent/xml :
#                 USER                       DATE  STAR  LIKE  \
# 0               또키호테  2022-08-25T04:15:28-07:00     3     0
# 1                 브잊  2022-08-05T04:26:09-07:00     5     0
# 2    NightGangbuster  2022-08-05T02:15:37-07:00     3     0
# 3             아이폰8플러  2022-07-20T08:19:58-07:00     1     0
# 4             개선좀 해줘  2022-07-19T18:45:01-07:00     3     0
# ..               ...                        ...   ...   ...
# 285             무니사항  2018-01-23T19:52:48-07:00     1     0
# 286      Oooooupdate  2018-01-09T09:27:18-07:00     3     0
# 287           ㅇㄱㄱㄱㄱㄱ  2017-11-25T04:59:38-07:00     1     0
# 288          한명의 이용자  2017-09-18T06:58:17-07:00     1     0
# 289             간큰뚝지  2017-09-15T22:59:42-07:00     1     0
#
#                             TITLE  \
# 0                     UI 개선좀 해주세요
# 1                 통합되어 없어지는거 아니죠?
# 2                     해외 주식 가져오기.
# 3    오류가 있으면 고쳐야지 왜 리뷰로 답변만 하냐 ㅋㅋ
# 4                       스탑로스 제발….
# ..                            ...
# 285                   뭔가 엄청 불편한데요
# 286                            요청
# 287                   앱이 실행이 안됩니다
# 288                          수정요망
# 289             미국시세 실시간 조회 안됩니다.
#
#                                                 REVIEW
# 0    차트는 흐리고 선도 구분 안되고\n주문하고 주문 정정할 때 현재가 확인하는것도 헷갈...
# 1                                   국내/해외 분리돼있어서 좋아요..
# 2    해외주식 가져오기 관련 제안 합니다. 해외주식 가져오기 한 걸 국내 주식 항목끝으로...
# 3    대우 한계인가요 ?네?? 절차를 만드는 건 이해를 하는데 \n왜 이렇게 만들었는지 ...
# 4    스탑로스가 없으니 그냥 배팅을 못하겠어요 지금 저 밀고도 수많은 사람들이 이야기 한...
# ..                                                 ...
# 285                                  해외 주식 검색을 어떻게 해요?
# 286  제것만 그런지 모르겠는데 “해외주식현재가”에 “차트”들어가서 확대하면 차트가 갑자기...
# 287                          첨에조금되더니 이젠 아예실행도 안되고 튕겨버림
# 288  - 최근들어 장개시 후, 차트 안열림\n- 차트에 수정주가 반영 안됨\n- 자주쓰는...
# 289        돈을 지불했고 사용중이라고 표시되는데...\n계속 15분지연시세로 조회됩니다.
#
# [290 rows x 6 columns]

# %%
df_['DATETIME'] = df_['DATE'].str.replace("-","").str.replace("T","-").str.replace(":","").str[:15]
df_['VIEWS'] = np.nan
df_['LIKES'] = df_['LIKE']
df_['TITLE'] =  df_['TITLE']
df_['CONTENT'] = df_['REVIEW']
df_['WRITER'] = df_['USER']

df_['SOURCE'] = "Appstore_m.Global"
df_['RELATED_ITEM'] = "미래에셋증권"
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['STAR']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)
df_['NUM_REPLY'] = np.nan
df_['CRAWLING_DATETIME'] = (datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['URL'] =  np.nan
df_ttl = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_ttl
# Out:
#                 SOURCE RELATED_ITEM         DATETIME  \
# 0    Appstore_m.Global       미래에셋증권  20220825-041528
# 1    Appstore_m.Global       미래에셋증권  20220805-042609
# 2    Appstore_m.Global       미래에셋증권  20220805-021537
# 3    Appstore_m.Global       미래에셋증권  20220720-081958
# 4    Appstore_m.Global       미래에셋증권  20220719-184501
# ..                 ...          ...              ...
# 285  Appstore_m.Global       미래에셋증권  20180123-195248
# 286  Appstore_m.Global       미래에셋증권  20180109-092718
# 287  Appstore_m.Global       미래에셋증권  20171125-045938
# 288  Appstore_m.Global       미래에셋증권  20170918-065817
# 289  Appstore_m.Global       미래에셋증권  20170915-225942
#
#                             TITLE  \
# 0                     UI 개선좀 해주세요
# 1                 통합되어 없어지는거 아니죠?
# 2                     해외 주식 가져오기.
# 3    오류가 있으면 고쳐야지 왜 리뷰로 답변만 하냐 ㅋㅋ
# 4                       스탑로스 제발….
# ..                            ...
# 285                   뭔가 엄청 불편한데요
# 286                            요청
# 287                   앱이 실행이 안됩니다
# 288                          수정요망
# 289             미국시세 실시간 조회 안됩니다.
#
#                                                CONTENT  POSITIVITY  NUM_REPLY  \
# 0    차트는 흐리고 선도 구분 안되고\n주문하고 주문 정정할 때 현재가 확인하는것도 헷갈...    0.159200        NaN
# 1                                   국내/해외 분리돼있어서 좋아요..    0.005168        NaN
# 2    해외주식 가져오기 관련 제안 합니다. 해외주식 가져오기 한 걸 국내 주식 항목끝으로...    0.088803        NaN
# 3    대우 한계인가요 ?네?? 절차를 만드는 건 이해를 하는데 \n왜 이렇게 만들었는지 ...    0.003751        NaN
# 4    스탑로스가 없으니 그냥 배팅을 못하겠어요 지금 저 밀고도 수많은 사람들이 이야기 한...    0.082768        NaN
# ..                                                 ...         ...        ...
# 285                                  해외 주식 검색을 어떻게 해요?    0.001793        NaN
# 286  제것만 그런지 모르겠는데 “해외주식현재가”에 “차트”들어가서 확대하면 차트가 갑자기...    0.035845        NaN
# 287                          첨에조금되더니 이젠 아예실행도 안되고 튕겨버림    0.003076        NaN
# 288  - 최근들어 장개시 후, 차트 안열림\n- 차트에 수정주가 반영 안됨\n- 자주쓰는...    0.003915        NaN
# 289        돈을 지불했고 사용중이라고 표시되는데...\n계속 15분지연시세로 조회됩니다.    0.003746        NaN
#
#      URL CRAWLING_DATETIME       OTHERS
# 0    NaN   20220830-093734  {'STAR': 3}
# 1    NaN   20220830-093734  {'STAR': 5}
# 2    NaN   20220830-093734  {'STAR': 3}
# 3    NaN   20220830-093734  {'STAR': 1}
# 4    NaN   20220830-093734  {'STAR': 3}
# ..   ...               ...          ...
# 285  NaN   20220830-093734  {'STAR': 1}
# 286  NaN   20220830-093734  {'STAR': 3}
# 287  NaN   20220830-093734  {'STAR': 1}
# 288  NaN   20220830-093734  {'STAR': 1}
# 289  NaN   20220830-093734  {'STAR': 1}
#
# [290 rows x 10 columns]

# %%
df_already= pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE  = 'Appstore_m.Global' ORDER BY DATETIME desc",conn)
df_already
# Out:
#                 SOURCE RELATED_ITEM         DATETIME  \
# 0    Appstore_m.Global       미래에셋증권  20220825-041528
# 1    Appstore_m.Global       미래에셋증권  20220805-042609
# 2    Appstore_m.Global       미래에셋증권  20220805-021537
# 3    Appstore_m.Global       미래에셋증권  20220720-081958
# 4    Appstore_m.Global       미래에셋증권  20220719-184501
# ..                 ...          ...              ...
# 285  Appstore_m.Global       미래에셋증권  20180123-195248
# 286  Appstore_m.Global       미래에셋증권  20180109-092718
# 287  Appstore_m.Global       미래에셋증권  20171125-045938
# 288  Appstore_m.Global       미래에셋증권  20170918-065817
# 289  Appstore_m.Global       미래에셋증권  20170915-225942
#
#                             TITLE  \
# 0                     UI 개선좀 해주세요
# 1                 통합되어 없어지는거 아니죠?
# 2                     해외 주식 가져오기.
# 3    오류가 있으면 고쳐야지 왜 리뷰로 답변만 하냐 ㅋㅋ
# 4                       스탑로스 제발….
# ..                            ...
# 285                   뭔가 엄청 불편한데요
# 286                            요청
# 287                   앱이 실행이 안됩니다
# 288                          수정요망
# 289             미국시세 실시간 조회 안됩니다.
#
#                                                CONTENT  POSITIVITY NUM_REPLY  \
# 0    차트는 흐리고 선도 구분 안되고\n주문하고 주문 정정할 때 현재가 확인하는것도 헷갈...    0.159200      None
# 1                                   국내/해외 분리돼있어서 좋아요..    0.005168      None
# 2    해외주식 가져오기 관련 제안 합니다. 해외주식 가져오기 한 걸 국내 주식 항목끝으로...    0.088803      None
# 3    대우 한계인가요 ?네?? 절차를 만드는 건 이해를 하는데 \n왜 이렇게 만들었는지 ...    0.003751      None
# 4    스탑로스가 없으니 그냥 배팅을 못하겠어요 지금 저 밀고도 수많은 사람들이 이야기 한...    0.082768      None
# ..                                                 ...         ...       ...
# 285                                  해외 주식 검색을 어떻게 해요?    0.001793      None
# 286  제것만 그런지 모르겠는데 “해외주식현재가”에 “차트”들어가서 확대하면 차트가 갑자기...    0.035845      None
# 287                          첨에조금되더니 이젠 아예실행도 안되고 튕겨버림    0.003076      None
# 288  - 최근들어 장개시 후, 차트 안열림\n- 차트에 수정주가 반영 안됨\n- 자주쓰는...    0.003915      None
# 289        돈을 지불했고 사용중이라고 표시되는데...\n계속 15분지연시세로 조회됩니다.    0.003746      None
#
#       URL CRAWLING_DATETIME       OTHERS
# 0    None   20220830-093734  {'STAR': 3}
# 1    None   20220830-093734  {'STAR': 5}
# 2    None   20220830-093734  {'STAR': 3}
# 3    None   20220830-093734  {'STAR': 1}
# 4    None   20220830-093734  {'STAR': 3}
# ..    ...               ...          ...
# 285  None   20220830-093734  {'STAR': 1}
# 286  None   20220830-093734  {'STAR': 3}
# 287  None   20220830-093734  {'STAR': 1}
# 288  None   20220830-093734  {'STAR': 1}
# 289  None   20220830-093734  {'STAR': 1}
#
# [290 rows x 10 columns]

# %%
df_ttl = df_ttl[df_ttl['DATETIME'] > df_already['DATETIME'].max()].reset_index()
df_ttl
# Out:
# Empty DataFrame
# Columns: [index, SOURCE, RELATED_ITEM, DATETIME, TITLE, CONTENT, POSITIVITY, NUM_REPLY, URL, CRAWLING_DATETIME, OTHERS]
# Index: []

# %%
if len(df_ttl) >0:

    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl
    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')  , " SUCCESS  : ",len(df_ttl))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " NO DATA TO UPDATE")
# Out:
# 20220830-093759  SUCCESS  :  290

# %%
import sqlite3 
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

import pandas as pd
import xmltodict
import requests
import os
import json
import numpy as np
from datetime import datetime, timedelta
client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan     
    
    
appid = 1068023690

url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid
try:
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)
    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]
    
except Exception as e:
    print (url)
#     print ('\tNo Reviews: appid %i' %appid)
#     print ('\tException:', e)
    
    
result = list()
for idx in range(1, 14+1):
    url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
#     print(url)
    response = requests.get(url).content.decode('utf8')
    try:
        xml = xmltodict.parse(response)
    except Exception as e:
        print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
        continue

    try:
        num_reivews= len(xml['feed']['entry'])
    except Exception as e:
#         print ('\tNo Entry', e)
        continue

    try:
        xml['feed']['entry'][0]['author']['name']
        single_reviews = False
    except:
        #print ('\tOnly 1 review!!!')
        single_reviews = True
        pass

    if single_reviews:
            result.append({
                'USER': xml['feed']['entry']['author']['name'],
                'DATE': xml['feed']['entry']['updated'],
                'STAR': int(xml['feed']['entry']['im:rating']),
                'LIKE': int(xml['feed']['entry']['im:voteSum']),
                'TITLE': xml['feed']['entry']['title'],
                'REVIEW': xml['feed']['entry']['content'][0]['#text'],
            })
    else:
        for i in range(len(xml['feed']['entry'])):
            result.append({
                'USER': xml['feed']['entry'][i]['author']['name'],
                'DATE': xml['feed']['entry'][i]['updated'],
                'STAR': int(xml['feed']['entry'][i]['im:rating']),
                'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                'TITLE': xml['feed']['entry'][i]['title'],
                'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
            })

df_ = pd.DataFrame(result)
df_

df_['DATETIME'] = df_['DATE'].str.replace("-","").str.replace("T","-").str.replace(":","").str[:15]
df_['VIEWS'] = np.nan
df_['LIKES'] = df_['LIKE']
df_['TITLE'] =  df_['TITLE']
df_['CONTENT'] = df_['REVIEW']
df_['WRITER'] = df_['USER']

df_['SOURCE'] = "Appstore_m.All"
df_['RELATED_ITEM'] = "미래에셋증권"
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['STAR']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)
df_['NUM_REPLY'] = np.nan
df_['CRAWLING_DATETIME'] = (datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['URL'] =  np.nan
df_ttl = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_ttl

# df_already= pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE  = 'Appstore_m.Global' ORDER BY DATETIME desc",conn)
# df_already


# df_ttl = df_ttl[df_ttl['DATETIME'] > df_already['DATETIME'].max()].reset_index()
# df_ttl

# if len(df_ttl) >0:

#     df_ttl = df_ttl.reset_index(drop=True)

#     df_ttl
#     df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
#     print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')  , " m.Global // SUCCESS  : ",len(df_ttl))

# else:
#     print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " m.Global //  NO DATA TO UPDATE")
# Out:
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=11/id=1068023690/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1068023690/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=12/id=1068023690/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1068023690/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=13/id=1068023690/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1068023690/sortBy=mostRecent/xml :
# 	Xml Parse Error syntax error: line 1, column 0
# 	Skip https://itunes.apple.com/kr/rss/customerreviews/page=14/id=1068023690/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1068023690/sortBy=mostRecent/xml :
#              SOURCE RELATED_ITEM         DATETIME                    TITLE  \
# 0    Appstore_m.All       미래에셋증권  20220731-204856     실현손익 왜  1년이 까지만 봐지나요
# 1    Appstore_m.All       미래에셋증권  20220718-205534               어플 구동이 안돼요
# 2    Appstore_m.All       미래에셋증권  20220623-202052       스플래시 이미지에서 안넘어가는데요
# 3    Appstore_m.All       미래에셋증권  20220608-091710                이체 기능 좀..
# 4    Appstore_m.All       미래에셋증권  20220601-180252             인증서 갱신이 안됩니다
# ..              ...          ...              ...                      ...
# 380  Appstore_m.All       미래에셋증권  20160308-163917  앱이 열리지도 않고, 기존 앱에 새 앱까지
# 381  Appstore_m.All       미래에셋증권  20160308-080647              사용자를 고려한 개편
# 382  Appstore_m.All       미래에셋증권  20160228-165244               로딩이 너무 느려요
# 383  Appstore_m.All       미래에셋증권  20160212-043600             미래에셋증권 자산관리앱
# 384  Appstore_m.All       미래에셋증권  20160212-001154             속도 빠르고 깔끔하네요
#
#                                                CONTENT  POSITIVITY  NUM_REPLY  \
# 0    최신 업데이트 전엔   원하는 기간 다봐졌는데\n\n업데이트 이후로\n\n1년치만 ...    0.003288        NaN
# 1                         어케하나요 다시 깔아도 시작합니다 문구에서 멈추네요    0.001953        NaN
# 2    스플래시 이미지에서 안넘어가요\n우편오는거 해제 하려고했더니 이딴 어플 깔라고나 하...    0.026430        NaN
# 3    주식안하고 걍 계좌만 있는데 이체하려면 주식앱을 또 받아야하니 번거롭네요\n왜 이렇...    0.020032        NaN
# 4    잊으서 갱신하려고 하는데 계좌번호, 비번, 핸드폰 번호 모두 맞는데(오류도 뜨지 않...    0.002933        NaN
# ..                                                 ...         ...        ...
# 380  다른데는 한 앱에서 모든걸 다 할수 있는데 기존앱업데이트도 아니고 새앱 설치하고 ....    0.059912        NaN
# 381  왠만해선 리뷰 작성 안하는데. 이번 업데이트는 정말 사용자 입장에서 필요한 것들을 ...    0.029541        NaN
# 382            로딩은 다 끝난것 같은데 계속 빙글빙글 돌아요.. \n\n답답해 죽겠음    0.001708        NaN
# 383      화면도 심플해지고 사용하기 넘 편하게 만들었네요..자산관리가 더욱 편해질 듯 ^^    0.019662        NaN
# 384  메인 화면이 군더더기 없이 깔끔합니다. 구동 속도도 빠르고 안정적이어서 마음에 듭니...   99.995600        NaN
#
#      URL CRAWLING_DATETIME       OTHERS
# 0    NaN   20220830-094435  {'STAR': 1}
# 1    NaN   20220830-094435  {'STAR': 2}
# 2    NaN   20220830-094435  {'STAR': 1}
# 3    NaN   20220830-094435  {'STAR': 1}
# 4    NaN   20220830-094435  {'STAR': 1}
# ..   ...               ...          ...
# 380  NaN   20220830-094435  {'STAR': 1}
# 381  NaN   20220830-094435  {'STAR': 5}
# 382  NaN   20220830-094435  {'STAR': 1}
# 383  NaN   20220830-094435  {'STAR': 5}
# 384  NaN   20220830-094435  {'STAR': 5}
#
# [385 rows x 10 columns]

# %%
if len(df_ttl) >0:

    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl
    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')  , " m.All // SUCCESS  : ",len(df_ttl))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " m.All //  NO DATA TO UPDATE")
# Out:
# 20220830-094453  m.All // SUCCESS  :  385

# %%
import sqlite3 
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()

import pandas as pd
import xmltodict
import requests
import os
import json
import numpy as np
from datetime import datetime, timedelta
client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan     
    
    
appid = 1068023690

url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid
try:
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)
    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]
    
except Exception as e:
    print (url)
#     print ('\tNo Reviews: appid %i' %appid)
#     print ('\tException:', e)
    
    
result = list()
for idx in range(1, 14+1):
    url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
#     print(url)
    response = requests.get(url).content.decode('utf8')
    try:
        xml = xmltodict.parse(response)
    except Exception as e:
#         print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
        continue

    try:
        num_reivews= len(xml['feed']['entry'])
    except Exception as e:
#         print ('\tNo Entry', e)
        continue

    try:
        xml['feed']['entry'][0]['author']['name']
        single_reviews = False
    except:
        #print ('\tOnly 1 review!!!')
        single_reviews = True
        pass

    if single_reviews:
            result.append({
                'USER': xml['feed']['entry']['author']['name'],
                'DATE': xml['feed']['entry']['updated'],
                'STAR': int(xml['feed']['entry']['im:rating']),
                'LIKE': int(xml['feed']['entry']['im:voteSum']),
                'TITLE': xml['feed']['entry']['title'],
                'REVIEW': xml['feed']['entry']['content'][0]['#text'],
            })
    else:
        for i in range(len(xml['feed']['entry'])):
            result.append({
                'USER': xml['feed']['entry'][i]['author']['name'],
                'DATE': xml['feed']['entry'][i]['updated'],
                'STAR': int(xml['feed']['entry'][i]['im:rating']),
                'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                'TITLE': xml['feed']['entry'][i]['title'],
                'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
            })

df_ = pd.DataFrame(result)
df_

df_['DATETIME'] = df_['DATE'].str.replace("-","").str.replace("T","-").str.replace(":","").str[:15]
df_['VIEWS'] = np.nan
df_['LIKES'] = df_['LIKE']
df_['TITLE'] =  df_['TITLE']
df_['CONTENT'] = df_['REVIEW']
df_['WRITER'] = df_['USER']

df_['SOURCE'] = "Appstore_m.All"
df_['RELATED_ITEM'] = "미래에셋증권"
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['STAR']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)
df_['NUM_REPLY'] = np.nan
df_['CRAWLING_DATETIME'] = (datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')
df_['URL'] =  np.nan
df_ttl = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]
df_ttl

df_already= pd.read_sql("SELECT * FROM TABLE_BUZZ where SOURCE  = 'Appstore_m.All' ORDER BY DATETIME desc",conn)
df_already


df_ttl = df_ttl[df_ttl['DATETIME'] > df_already['DATETIME'].max()].reset_index(drop=True)
df_ttl

if len(df_ttl) >0:

    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl
    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S')  , " m.All // SUCCESS  : ",len(df_ttl))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " m.All //  NO DATA TO UPDATE")
# Out:
# 20220831-095805  m.All // SUCCESS  :  1

# %%
df_ttl
# Out:
#            SOURCE RELATED_ITEM         DATETIME TITLE  \
# 0  Appstore_m.All       미래에셋증권  20220829-021108    뱅킹
#
#                                              CONTENT  POSITIVITY  NUM_REPLY  \
# 0  아이폰 ios 15.6.1 버전인데\n뱅킹에서 이체 버튼을 누르면 \n계속적으로 멈...    0.020382        NaN
#
#    URL CRAWLING_DATETIME       OTHERS
# 0  NaN   20220831-095805  {'STAR': 1}
