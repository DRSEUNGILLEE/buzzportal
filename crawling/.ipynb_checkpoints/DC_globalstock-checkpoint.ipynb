# %%
import json
import requests
import re
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, timedelta
import time
import warnings
warnings.filterwarnings('ignore')

from bs4 import BeautifulSoup, BeautifulStoneSoup

import sqlite3 
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()


client_id = "l5s8tg1g0w" # 개발자센터에서 발급받은 Client ID 값
client_secret = "RPNXQKCp8erMRW4KvKWsME5m3F9QOYVJTZ8Lvj56" # 개발자센터에서 발급받은 Client Secret 값

def get_sentiment(content):
    printout = True
    url="https://naveropenapi.apigw.ntruss.com/sentiment-analysis/v1/analyze"

    headers = {
        "X-NCP-APIGW-API-KEY-ID": client_id,
        "X-NCP-APIGW-API-KEY": client_secret,
        "Content-Type": "application/json"
    }

    data = {
      "content": content
    }

    response = requests.post(url, data=json.dumps(data), headers=headers)
    rescode = response.status_code

    if(rescode == 200):        
        sentiment = json.loads(response.text)['document']['sentiment'] 
        pos_score = json.loads(response.text)['document']['confidence']['positive']
        neg_score = json.loads(response.text)['document']['confidence']['negative']
        neu_score = json.loads(response.text)['document']['confidence']['neutral']
#         if printout:
#             print("\n=== 감성분석 ===")
#             print("판정: {}\n점수: 긍정 {}, 중립 {}, 부정 {}".format(sentiment, pos_score, neu_score, neg_score)) 
#         return sentiment, pos_score, neu_score, neg_score
        return pos_score

    else:
        print("Error : " + response.text)
        return np.nan

# %%
df_already = pd.read_sql("SELECT OTHERS FROM TABLE_BUZZ where SOURCE = 'dcinside_해외주식갤러리' ORDER BY DATETIME desc limit 1",conn)


start_id = eval(df_already['OTHERS'][0])['boards_ID']+ 1 #4630000#
err_cnt = 0
boards_ID_l = []
boards_title_l = []
board_main_l = []
board_read_l = []
board_recommend_l = []
board_reply_l = []
board_writer_l = []
board_writerip_l = []
board_time_l = []
board_crawl_time_l = []
board_url_l = []
while True:
    try:

        headers = [
        {'User-Agent' : '' },

        ]
        BASE_URL = 'https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=' + str(start_id)
        response = requests.get(BASE_URL,  headers=headers[0])

        soup = BeautifulSoup(response.content, 'html.parser')
        boards_ID = start_id
        boards_title    = soup.find('title').text.replace(' - 비트코인 갤러리','')
        board_main      = soup.find('div', {"class": "write_div"}).text.replace('\n','')
        board_read      = int(soup.find('span', {"class": "gall_count"}).text.replace('조회 ',''))
        board_recommend = int(soup.find('span', {"class": "gall_reply_num"}).text.replace('추천 ',''))
        board_reply     = int(soup.find('span', {"class": "gall_comment"}).text.replace('댓글 ',''))
        board_writer    = soup.find('span', {"class": "nickname"}).text
        board_writerip  = soup.find('span', {"class": "ip"}).text
        board_time      = soup.find('span', {"class": "gall_date"}).text
        board_url= BASE_URL
        print(boards_ID, "//", boards_title, '/',board_main, '/',board_read, '/',board_recommend , '/',board_reply , '/',board_writer, '/',board_url, '/',board_time, '/',
          )
        start_id += 1

        boards_ID_l.append(boards_ID) 
        boards_title_l.append(boards_title) 
        board_main_l.append(board_main) 
        board_read_l.append(board_read) 
        board_recommend_l.append(board_recommend) 
        board_reply_l.append(board_reply) 
        board_writer_l.append(board_writer) 
        board_writerip_l.append(board_writerip) 
        board_time_l.append(board_time) 
        board_crawl_time_l.append(datetime.now())
        board_url_l.append(board_url)


        err_cnt = 0
    except:
        print(start_id,'err')
        err_cnt +=1
        start_id += 1


        if err_cnt > 50:
            break
    time.sleep(0.7)
# Out:
# 4638985 // 릴라 야 한번 봐줘 - 해외주식 마이너 갤러리 / 매매 기법좀 알려죠라 1. 시드가 200 이면  매수를 어떻게 쪼개서 하냐2. 본장초에 쏘는 애들 삼십분뒤 떨어지면 그거 사도돼냐3. 프장에서 매매는 어케하냐4. 돈을 계속 날려서 미치겠다 매수타점이랑 매수금 비율좀 공유해봐라 / 92 / 0 / 1 / 아 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638985 / 2022.08.31 11:06:20 /
# 4638986 // 보통 단타칠때 창 어떻게 보냐 - 해외주식 마이너 갤러리 / 한번에 여러개 티커 들락날락 해야되고 분봉 틱봉 다 뭐로 보냐 궁금하다자꾸 잃어서 힘들구만  / 42 / 0 / 0 / 비비 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638986 / 2022.08.31 11:11:58 /
# 4638987 // Muln  어텋게 보노? - 해외주식 마이너 갤러리 / 오늘부터 반등 시작인거 같은데일단 ㆍ60 에 사긴 샀다 / 140 / 0 / 4 / 문라이트 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638987 / 2022.08.31 11:13:11 /
# 4638988 // 자살하면아프냐 - 해외주식 마이너 갤러리 / 시발  - dc official App / 145 / 1 / 4 / ㅇㅇ / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638988 / 2022.08.31 11:13:42 /
# 4638989 // nbev 0.22에 들고 있다가 - 해외주식 마이너 갤러리 / 프장에 졸려서 0.29에 팔고 새벽에 잠깐 일어나서 비몽사몽한 상태에서 0.39불 보고 배아팠었는데  지금 일어나서 확인해보고 개소름이노   - dc official App / 169 / 0 / 4 / ㅇㅇ / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638989 / 2022.08.31 11:16:17 /
# 4638990 // amtd 이거 주가 떨어지긴해도 망하진 않지? - 해외주식 마이너 갤러리 / 주갤 갔다가 코스피갤 갔었는데 해주갤이 있었네 / 80 / 0 / 1 / ㅇㅇ / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638990 / 2022.08.31 11:20:51 /
# 4638991 // 어제 그냥 mgam 무지성 홀드했어도 40퍼정도 먹었겠네 ㅋㅋ - 해외주식 마이너 갤러리 / 물론 다 결과론 / 113 / 0 / 3 / 50웍 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638991 / 2022.08.31 11:20:58 /
# 4638992 err
# 4638993 // Muln 사지마라 부2탁이다 부2탁 ㅋㅋ - 해외주식 마이너 갤러리 / Muln이 무한 우하향하는 이유는 숏 억까가 아니라 전환사채를 과도하게 발행해서 희석효과로 인해 주당가격이 떨어진거임그냥 주주들을 atm기로 생각하는 회사라고..희석효과로 상장 후 -99.99%인 주식 ㅈㄴ 많다 제발 속지마라회사 자체도 비전없고 그냥 십스캠이다오르는걸 사야지, 이제 한 번 반등하지않을까? 라는 헛된 기대를 하지마. 약반등은 어느 종목이나 다 있는거고 그런거 노릴바에는 다른거 사는게 나음. 3프로 오르고 5프로 떨어지고 이런거 무한반복임 / 265 / 5 / 5 / 50웍 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4638993 / 2022.08.31 11:25:30 /
# 4638994 // BIAF 상장하네 - 해외주식 마이너 갤러리 / ㄱ? / 77 / 0 / 3 / ㅇㅇ / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4
https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4639044 / 2022.08.31 13:47:05 /
# 4639045 // 원달러 환율 1500 돌파 ㄷㄷ - 해외주식 마이너 갤러리 / 연습 / 41 / 0 / 0 / 헹우 / https://gall.dcinside.com/mgallery/board/view/?id=tenbagger&no=4639045 / 2022.08.31 13:50:09 /
# 4639046 err
# 4639047 err
# 4639048 err
# 4639049 err
# 4639050 err
# 4639051 err
# 4639052 err
# 4639053 err
# 4639054 err
# 4639055 err
# 4639056 err
# 4639057 err
# 4639058 err
# 4639059 err
# 4639060 err
# 4639061 err
# 4639062 err
# 4639063 err
# 4639064 err
# 4639065 err
# 4639066 err
# 4639067 err
# 4639068 err
# 4639069 err
# 4639070 err
# 4639071 err
# 4639072 err
# 4639073 err
# 4639074 err
# 4639075 err
# 4639076 err
# 4639077 err
# 4639078 err
# 4639079 err
# 4639080 err
# 4639081 err
# 4639082 err
# 4639083 err
# 4639084 err
# 4639085 err
# 4639086 err
# 4639087 err
# 4639088 err
# 4639089 err
# 4639090 err
# 4639091 err
# 4639092 err
# 4639093 err
# 4639094 err
# 4639095 err
# 4639096 err

# %%
df_ = pd.DataFrame()
df_['boards_ID'] = boards_ID_l 
df_['boards_title'] = boards_title_l 
df_['board_main'] = board_main_l 
df_['board_read'] = board_read_l 
df_['board_recommend'] = board_recommend_l 
df_['board_reply'] = board_reply_l 
df_['board_writer'] = board_writer_l 
df_['board_writerip'] = board_writerip_l 
df_['board_time'] = board_time_l 
df_['board_time'] = df_['board_time'].apply(lambda x :  datetime.strptime(x, '%Y.%m.%d %H:%M:%S')) 
df_['board_crawl_time'] =  board_crawl_time_l
df_['board_url'] =  board_url_l
df_['source'] = 'dc_gall'
df_['updated'] = (datetime.now() + timedelta(hours=9)).strftime("%Y%m%d-%H%M%S")

df_['DATETIME'] = df_['board_time'].apply(lambda x :  x.strftime("%Y%m%d-%H%M%S") ) 
df_['VIEWS'] = df_['board_read']
df_['LIKES'] = df_['board_recommend']
df_['TITLE'] =  df_['boards_title']
df_['CONTENT'] = df_['board_main']
df_['WRITER'] =df_['board_writer']
df_['SOURCE'] = "dcinside_해외주식갤러리"
df_['RELATED_ITEM'] = np.nan
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['boards_ID','board_reply','board_writerip']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)

df_['NUM_REPLY'] = df_['board_reply'] 
df_['CRAWLING_DATETIME'] =df_['updated'] 
df_['URL'] =  df_['board_url']
df_ttl = df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]]

df_ttl
# Out:
#               SOURCE  RELATED_ITEM         DATETIME  \
# 0   dcinside_해외주식갤러리           NaN  20220831-110620
# 1   dcinside_해외주식갤러리           NaN  20220831-111158
# 2   dcinside_해외주식갤러리           NaN  20220831-111311
# 38                           Avct 매각날짜 - 해외주식 마이너 갤러리
# 39                          tgl하고 lucy - 해외주식 마이너 갤러리
# 40                  뉴에이지 어케됨?? 기다리다 잤어 - 해외주식 마이너 갤러리
# 41                         mgam 어제 거래량 - 해외주식 마이너 갤러리
# 42                    Ape amc 다시 말해준다. - 해외주식 마이너 갤러리
# 43                    뉴에이지 평단 2.001 인증 - 해외주식 마이너 갤러리
# 44     프프장 BBBY 44프로 급등ㅋㅋㅋㅋ 감마스퀴즈시작인가? - 해외주식 마이너 갤러리
# 45                              게임주 사라 - 해외주식 마이너 갤러리
# 46                           원자재 슈퍼싸이클 - 해외주식 마이너 갤러리
# 47                               우영우 너 - 해외주식 마이너 갤러리
# 48                         slno 어케 보냐? - 해외주식 마이너 갤러리
# 49                     환경 대학원 어떻게 생각함? - 해외주식 마이너 갤러리
# 50                    27 졷소퇴사후 진로생각중이다 - 해외주식 마이너 갤러리
# 51                        mgam 개잡주 갔냐? - 해외주식 마이너 갤러리
# 52                하. 인생 의미없다. 이젠 돈도 없다 - 해외주식 마이너 갤러리
# 53                달러 너무 올라서 엔화 환전하려는데  - 해외주식 마이너 갤러리
# 54             얘들아 오늘 티커 진지하게 추천바란다 ㅠ  - 해외주식 마이너 갤러리
# 55                   원달러 환율 1500 돌파 ㄷㄷ - 해외주식 마이너 갤러리
#
#                                               CONTENT  POSITIVITY  NUM_REPLY  \
# 0   매매 기법좀 알려죠라 1. 시드가 200 이면  매수를 어떻게 쪼개서 하냐2. 본장...    0.562024          1
# 1   한번에 여러개 티커 들락날락 해야되고 분봉 틱봉 다 뭐로 보냐 궁금하다자꾸 잃어서 ...    0.103356          0
# 2                      오늘부터 반등 시작인거 같은데일단 ㆍ60 에 사긴 샀다    0.024056          4
# 3                               시발  - dc official App    0.006456          4
# 4   프장에 졸려서 0.29에 팔고 새벽에 잠깐 일어나서 비몽사몽한 상태에서 0.39불 ...    0.047194          4
# 5                           주갤 갔다가 코스피갤 갔었는데 해주갤이 있었네    0.028572          1
# 6                                            물론 다 결과론    0.040576          3
# 7   Muln이 무한 우하향하는 이유는 숏 억까가 아니라 전환사채를 과도하게 발행해서 희...    0.012717          5
# 8                                                  ㄱ?    0.032522          3
# 9                 200으로 300만들어야하는데저중에 제일 좋아보이는게 뭘까요..    0.038954         10
# 10                                               짜증난다    0.027760          0
# 11            항상 미국 중간선거때 주가 급락하는거 알지?9월 중순때는 들고 있지마라    0.010737          4
# 12  대체 대체 대체 뭐여 살려줘!!!!!Integration of the AHI sol...    0.011564          1
# 13                       믿거 리스트 속이려고 해주하는 ㅂㅅ 인증 ㅋㅋㅋㅋ     0.033130          0
# 14  난 지켜볼만 하다고 보는데무빙은 거지 같은데 아직 지표 살아있고오퍼링 마감도 때렸고...    0.022493          3
# 15  h.ttps://www.sec.gov/Archives/edgar/data/11560...    0.029796          0
# 16                                   프장에 2.35 시작임????   85.481575          2
# 17                                                 ㅎㅎ    0.036745          0
# 18  미국 파산법 11장, 자발적파산 신청한 기업들 보니까 파산법원이랑 수개월 청문회 하...    0.029811          1
# 19  너희 이거 알고 있었냐?? 서치하다가 발견 했는데.... swag라는 나스닥 티커는...    0.032925          3
# 20  이거 미국.주식만 시장가로 매도가 안 되던데 왜 그런거임?!프장에선 시장가가 안 되...    0.031348          3
# 21                           나가겠지?  - dc official App    0.035622          0
# 22  화이팅다단계회사고ceo 1월에 사퇴하고cfo(재무책임자) 7월에 사퇴함아 물론 파산...    0.006505          1
# 23                                 오늘'까지'는 불장이겠지가 위험함    0.024516          0
# 24                 기관 보유 좀 되는것 같은데  - dc official App    0.007578          0
# 25          형은 ?불 본다, 고수는 ?탄다, 컵앤핸들, ?에 대한 조롱이 극에 달했다    0.006274          2
# 26  필리핀회사 air21 holdings inc(ahi)해주갤에서 탄거는advanced...    0.093888          3
# 27                                                       0.031494          0
# 28                                      유리 관련주 뭐잇냐 ㅋㅋ    0.032008          0
# 29                                 미래가 없는회사에 투자할리는없고     0.007497          1
# 30  최근 매출 상향중 성장성 기대 인수 3가지 호재가 겹쳐있고걍 시발 일단 지켜보자인수...    0.033814          3
# 31                                난 요즘 종가에 매수하는걸 선호함     0.155983          2
# 32  일반기계기사 토스 컴활1 한국사2 학점 3.91/4.5 그외 잡다 현재 식품졷소 7...    0.007355          5
# 33               가스 유가 관련주 오르겟네 어제 nbev 난리칠 동안 관련주 삿지    0.028569          0
# 34                      대부분 저점인듯. 참고는 하겟지만 주식은 본인이 한다    0.013180          2
# 35                                             튀어야하나     0.006013          1
# 36                                         ㅋㅋㅋ파산빔 안오나    0.030186          2
# 37                    ㅋㅋㅋㅋ오른 걸 타더라도 고점에서 타지말고 좀만 기다려봐    0.059618         15
# 38                             누구랑 하는지 언제하는지 아직 발표없지?    0.019242          3
# 39                                   봐라 며칠 연속 빠지는지 ㅋㅋ    0.039030          0
# 40                                  - dc official App    0.053683          1
# 41  상장하고 이틀전까지 거래량 합한거보다 어제 하루 거래량이 훨씬 더 많노ㄷㄷ mgam...    0.028005          2
# 42  AA 이새끼 헤지 쁘락찌 맞다니까 ㅋㅋㅋApe는 조만간 반등올것같은데 잘 내려라분사...    0.038842          1
# 43                              2 3에팔앗다 ㅅㅂ...ㅠㅠ 아이고배야    0.041655          4
# 44                    가즈앗!!! 프장 열리면 바로 추미애!!!!!!!!!!    71.123800          2
# 45                          대공황이 오면뭐다? 도박게임에 사람들은 몰린다    0.028121          6
# 46                   원자재가 폭발력이 젤 많다50배는 기본이다천만원만 박아놔라    0.024719          9
# 47                    친환경 사라하지않앗냐 친환경도 좋은데 잠잠해질때 사볼만해    0.024179          3
# 48                                           난 3d로 본다    0.025807          0
# 49  친구가 미국 탑10 학부에서 환경 관련 과 전공하다가 이번에 서울대 환경대학원 온다...    0.022674          4
# 50  세무사 노무사 공부 석사루트 입갤 로스크아크 쌀먹 고덕 노가다 원정 자살 뭐가 가장...    0.027353          5
# 51                                    개잡주 욕한지 4일차에 갔다    0.007390          0
# 52  분명 7300만원 있었는데분명 그랬는데...8월 1개동안 동안 몬일이 일어난거지. ...    0.024472          1
# 53     어떻게 생각함? 원화 들고있는것보단 낫지? 개인적으로 후쿠자와 유키치 성님 존경함     0.013694          2
# 54                     추천 한거 보고 들가서 수익나면 치킨이라두 드릴게..     0.390857          3
# 55                                                 연습    0.058943          0
#
#                                                   URL CRAWLING_DATETIME  \
# 0   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 1   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 2   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 3   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 4   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 5   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 6   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 7   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 8   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 9   https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 10  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 11  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 12  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 13  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 14  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 15  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 16  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 17  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 18  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 19  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 20  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 21  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 22  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 23  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 24  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 25  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 26  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 27  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 28  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 29  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 30  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 31  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 32  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 33  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 34  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 35  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 36  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 37  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 38  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 39  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 40  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 41  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 42  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 43  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 44  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 45  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 46  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 47  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 48  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 49  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 50  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 51  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 52  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 53  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 54  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
# 55  https://gall.dcinside.com/mgallery/board/view/...   20220831-135551
#
#                                                OTHERS
# 0   {'boards_ID': 4638985, 'board_reply': 1, 'boar...
# 1   {'boards_ID': 4638986, 'board_reply': 0, 'boar...
# 2   {'boards_ID': 4638987, 'board_reply': 4, 'boar...
# 3   {'boards_ID': 4638988, 'board_reply': 4, 'boar...
# 4   {'boards_ID': 4638989, 'board_reply': 4, 'boar...
# 5   {'boards_ID': 4638990, 'board_reply': 1, 'boar...
# 6   {'boards_ID': 4638991, 'board_reply': 3, 'boar...
# 7   {'boards_ID': 4638993, 'board_reply': 5, 'boar...
# 8   {'boards_ID': 4638994, 'board_reply': 3, 'boar...
# 9   {'boards_ID': 4638995, 'board_reply': 10, 'boa...
# 10  {'boards_ID': 4638996, 'board_reply': 0, 'boar...
# 11  {'boards_ID': 4638997, 'board_reply': 4, 'boar...
# 12  {'boards_ID': 4638998, 'board_reply': 1, 'boar...
# 13  {'boards_ID': 4638999, 'board_reply': 0, 'boar...
# 14  {'boards_ID': 4639001, 'board_reply': 3, 'boar...
# 15  {'boards_ID': 4639002, 'board_reply': 0, 'boar...
# 16  {'boards_ID': 4639003, 'board_reply': 2, 'boar...
# 17  {'boards_ID': 4639004, 'board_reply': 0, 'boar...
# 18  {'boards_ID': 4639005, 'board_reply': 1, 'boar...
# 19  {'boards_ID': 4639006, 'board_reply': 3, 'boar...
# 20  {'boards_ID': 4639007, 'board_reply': 3, 'boar...
# 21  {'boards_ID': 4639008, 'board_reply': 0, 'boar...
# 22  {'boards_ID': 4639009, 'board_reply': 1, 'boar...
# 23  {'boards_ID': 4639010, 'board_reply': 0, 'boar...
# 24  {'boards_ID': 4639011, 'board_reply': 0, 'boar...
# 25  {'boards_ID': 4639014, 'board_reply': 2, 'boar...
# 26  {'boards_ID': 4639015, 'board_reply': 3, 'boar...
# 27  {'boards_ID': 4639016, 'board_reply': 0, 'boar...
# 28  {'boards_ID': 4639017, 'board_reply': 0, 'boar...
# 29  {'boards_ID': 4639018, 'board_reply': 1, 'boar...
# 30  {'boards_ID': 4639019, 'board_reply': 3, 'boar...
# 31  {'boards_ID': 4639020, 'board_reply': 2, 'boar...
# 32  {'boards_ID': 4639022, 'board_reply': 5, 'boar...
# 33  {'boards_ID': 4639023, 'board_reply': 0, 'boar...
# 34  {'boards_ID': 4639024, 'board_reply': 2, 'boar...
# 35  {'boards_ID': 4639025, 'board_reply': 1, 'boar...
# 36  {'boards_ID': 4639026, 'board_reply': 2, 'boar...
# 37  {'boards_ID': 4639027, 'board_reply': 15, 'boa...
# 38  {'boards_ID': 4639028, 'board_reply': 3, 'boar...
# 39  {'boards_ID': 4639029, 'board_reply': 0, 'boar...
# 40  {'boards_ID': 4639030, 'board_reply': 1, 'boar...
# 41  {'boards_ID': 4639031, 'board_reply': 2, 'boar...
# 42  {'boards_ID': 4639032, 'board_reply': 1, 'boar...
# 43  {'boards_ID': 4639033, 'board_reply': 4, 'boar...
# 44  {'boards_ID': 4639034, 'board_reply': 2, 'boar...
# 45  {'boards_ID': 4639035, 'board_reply': 6, 'boar...
# 46  {'boards_ID': 4639036, 'board_reply': 9, 'boar...
# 47  {'boards_ID': 4639037, 'board_reply': 3, 'boar...
# 48  {'boards_ID': 4639038, 'board_reply': 0, 'boar...
# 49  {'boards_ID': 4639039, 'board_reply': 4, 'boar...
# 50  {'boards_ID': 4639040, 'board_reply': 5, 'boar...
# 51  {'boards_ID': 4639041, 'board_reply': 0, 'boar...
# 52  {'boards_ID': 4639042, 'board_reply': 1, 'boar...
# 53  {'boards_ID': 4639043, 'board_reply': 2, 'boar...
# 54  {'boards_ID': 4639044, 'board_reply': 3, 'boar...
# 55  {'boards_ID': 4639045, 'board_reply': 0, 'boar...

# %%
if len(df_ttl) >0:
    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " SUCCESS  : ",len(df_ttl))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " NO DATA TO UPDATE")
# Out:
# 20220831-135601  SUCCESS  :  56

# %%
df_ttl = pd.DataFrame()

# %%
df_ = pd.DataFrame()
df_['boards_ID'] = boards_ID_l 
df_['boards_title'] = boards_title_l 
df_['board_main'] = board_main_l 
df_['board_read'] = board_read_l 
df_['board_recommend'] = board_recommend_l 
df_['board_reply'] = board_reply_l 
df_['board_writer'] = board_writer_l 
df_['board_writerip'] = board_writerip_l 
df_['board_time'] = board_time_l 
df_['board_time'] = df_['board_time'].apply(lambda x :  datetime.strptime(x, '%Y.%m.%d %H:%M:%S')) 
df_['board_crawl_time'] =  board_crawl_time_l
df_['board_url'] =  board_url_l
df_['source'] = 'dc_gall'
df_['updated'] = (datetime.now() + timedelta(hours=9)).strftime("%Y%m%d-%H%M%S")

df_['DATETIME'] = df_['board_time'].apply(lambda x :  x.strftime("%Y%m%d-%H%M%S") ) 
df_['VIEWS'] = df_['board_read']
df_['LIKES'] = df_['board_recommend']
df_['TITLE'] =  df_['boards_title']
df_['CONTENT'] = df_['board_main']
df_['WRITER'] =df_['board_writer']
df_['SOURCE'] = "dcinside_해외주식갤러리"
df_['RELATED_ITEM'] = np.nan
df_['POSITIVITY'] = np.nan
for i in range(len(df_)):
    df_.loc[i,"POSITIVITY"] = get_sentiment(df_.loc[i,"TITLE"])
    
df_['OTHERS'] = df_[['boards_ID','board_reply','board_writerip']].to_dict('records')
df_['OTHERS'] = df_['OTHERS'].astype(str)

df_['NUM_REPLY'] = df_['board_reply'] 
df_['CRAWLING_DATETIME'] =df_['updated'] 
df_['URL'] =  df_['board_url']
df_ttl = df_ttl.append(df_[['SOURCE','RELATED_ITEM',"DATETIME","TITLE","CONTENT","POSITIVITY","NUM_REPLY",'URL',"CRAWLING_DATETIME","OTHERS"]])
df_ttl
# Out:
#                 SOURCE  RELATED_ITEM         DATETIME  \
# 0     dcinside_해외주식갤러리           NaN  20220830-153043
# 1     dcinside_해외주식갤러리           NaN  20220830-153136
# 2     dcinside_해외주식갤러리           NaN  20220830-153353
# 3     dcinside_해외주식갤러리           NaN  20220830-153448
# 4     dcinside_해외주식갤러리           NaN  20220830-153453
# ...                ...           ...              ...
# 2013  dcinside_해외주식갤러리           NaN  20220831-104647
# 2014  dcinside_해외주식갤러리           NaN  20220831-104849
# 2015  dcinside_해외주식갤러리           NaN  20220831-105427
# 2016  dcinside_해외주식갤러리           NaN  20220831-105505
# 2017  dcinside_해외주식갤러리           NaN  20220831-105546
#
#                                               TITLE  \
# 0     BBBY offering 31 Aug confirmed - 해외주식 마이너 갤러리
# 1             avct 121.184 억까새끼 어디갔노 - 해외주식 마이너 갤러리
# 2                      bbby 오퍼링이네... - 해외주식 마이너 갤러리
# 3                        비비비와이 유증 확정 - 해외주식 마이너 갤러리
# 4                      bbby 오퍼링ㅋㅋㅋㅋㅋ - 해외주식 마이너 갤러리
# ...                                             ...
# 2013                 BBBY 오늘 발표 몇시임? - 해외주식 마이너 갤러리
# 2014          오늘 스타박스 반등 구간이다 무조건 타라 - 해외주식 마이너 갤러리
# 2015                          와 nogn - 해외주식 마이너 갤러리
# 2016          나 윤모 찐 맞음 본캐 아이피 차단당해서 - 해외주식 마이너 갤러리
# 2017                       nbev 끝이냐? - 해외주식 마이너 갤러리
#
#                                                 CONTENT  POSITIVITY  \
# 0                                 ㅅㄱ  - dc official App    0.025226
# 1                     오르니깐 싸물고 있네 ㅋㅋ  - dc official App    0.007236
# 2                                하..  - dc official App    0.094986
# 3                                  하  - dc official App    0.034671
# 4                                            ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ    0.071702
# ...                                                 ...         ...
# 2013                        21:30이었나  - dc official App    0.025760
# 2014                          안타면 너 손해- dc official App    0.854511
# 2015  Onfo 뮬타다가 손절하고 그거 그대로nogn 4.45에 넣고 새벽 4시에 onfo...    0.039104
# 2016                                          통피로 글올리는중    0.006474
# 2017                     자고나니 앱장 ㅈ같네  - dc official App    0.045931
#
#       NUM_REPLY                                                URL  \
# 0             9  https://gall.dcinside.com/mgallery/board/view/...
# 1             2  https://gall.dcinside.com/mgallery/board/view/...
# 2             4  https://gall.dcinside.com/mgallery/board/view/...
# 3             0  https://gall.dcinside.com/mgallery/board/view/...
# 4             0  https://gall.dcinside.com/mgallery/board/view/...
# ...         ...                                                ...
# 2013          0  https://gall.dcinside.com/mgallery/board/view/...
# 2014          1  https://gall.dcinside.com/mgallery/board/view/...
# 2015          1  https://gall.dcinside.com/mgallery/board/view/...
# 2016          0  https://gall.dcinside.com/mgallery/board/view/...
# 2017          0  https://gall.dcinside.com/mgallery/board/view/...
#
#      CRAWLING_DATETIME                                             OTHERS
# 0      20220831-105936  {'boards_ID': 4636841, 'board_reply': 9, 'boar...
# 1      20220831-105936  {'boards_ID': 4636842, 'board_reply': 2, 'boar...
# 2      20220831-105936  {'boards_ID': 4636843, 'board_reply': 4, 'boar...
# 3      20220831-105936  {'boards_ID': 4636844, 'board_reply': 0, 'boar...
# 4      20220831-105936  {'boards_ID': 4636845, 'board_reply': 0, 'boar...
# ...                ...                                                ...
# 2013   20220831-105936  {'boards_ID': 4638980, 'board_reply': 0, 'boar...
# 2014   20220831-105936  {'boards_ID': 4638981, 'board_reply': 1, 'boar...
# 2015   20220831-105936  {'boards_ID': 4638982, 'board_reply': 1, 'boar...
# 2016   20220831-105936  {'boards_ID': 4638983, 'board_reply': 0, 'boar...
# 2017   20220831-105936  {'boards_ID': 4638984, 'board_reply': 0, 'boar...
#
# [2018 rows x 10 columns]

# %%
eval("{'boards_ID': '4630000' , 'sd':'sdd'}")['']
# Out:
# {'boards_ID': '4630000', 'sd': 'sdd'}

# %%
df_already = pd.read_sql("SELECT OTHERS FROM TABLE_BUZZ where SOURCE = 'dcinside_해외주식갤러리' ORDER BY DATETIME desc limit 1",conn)
eval(df_already['OTHERS'][0])['boards_ID']
# Out:
# 4638984

# %%
while True:
    max_id = pd.read_sql('SELECT max(boards_ID) FROM STOCK_GALLERY',conn)
    
    start_id = max_id.iloc[0,0] +1
    err_cnt = 0
    boards_ID_l = []
    boards_title_l = []
    board_main_l = []
    board_read_l = []
    board_recommend_l = []
    board_reply_l = []
    board_writer_l = []
    board_writerip_l = []
    board_time_l = []
    board_crawl_time_l = []
    board_url_l = []
    while True:
        try:

            headers = [
            {'User-Agent' : '' },

            ]
            BASE_URL = 'https://gall.dcinside.com/board/view/?id=neostock&no=' + str(start_id)
            response = requests.get(BASE_URL,  headers=headers[0])

            soup = BeautifulSoup(response.content, 'html.parser')
            boards_ID = start_id
            boards_title    = soup.find('title').text.replace(' - 비트코인 갤러리','')
            board_main      = soup.find('div', {"class": "write_div"}).text.replace('\n','')
            board_read      = int(soup.find('span', {"class": "gall_count"}).text.replace('조회 ',''))
            board_recommend = int(soup.find('span', {"class": "gall_reply_num"}).text.replace('추천 ',''))
            board_reply     = int(soup.find('span', {"class": "gall_comment"}).text.replace('댓글 ',''))
            board_writer    = soup.find('span', {"class": "nickname"}).text
            board_writerip  = soup.find('span', {"class": "ip"}).text
            board_time      = soup.find('span', {"class": "gall_date"}).text
            board_url= BASE_URL
            print(boards_ID, "//", boards_title, '/',board_main, '/',board_read, '/',board_recommend , '/',board_reply , '/',board_writer, '/',board_url, '/',board_time, '/',
              )
            start_id += 1

            boards_ID_l.append(boards_ID) 
            boards_title_l.append(boards_title) 
            board_main_l.append(board_main) 
            board_read_l.append(board_read) 
            board_recommend_l.append(board_recommend) 
            board_reply_l.append(board_reply) 
            board_writer_l.append(board_writer) 
            board_writerip_l.append(board_writerip) 
            board_time_l.append(board_time) 
            board_crawl_time_l.append(datetime.datetime.now())
            board_url_l.append(board_url)


            err_cnt = 0
        except:
            print(start_id,'err')
            err_cnt +=1
            start_id += 1


            if err_cnt > 100:
                break
        time.sleep(0.7)
        
    df_board = pd.DataFrame()
    df_board['boards_ID'] = boards_ID_l 
    df_board['boards_title'] = boards_title_l 
    df_board['board_main'] = board_main_l 
    df_board['board_read'] = board_read_l 
    df_board['board_recommend'] = board_recommend_l 
    df_board['board_reply'] = board_reply_l 
    df_board['board_writer'] = board_writer_l 
    df_board['board_writerip'] = board_writerip_l 
    df_board['board_time'] = board_time_l 
    df_board['board_time'] = df_board['board_time'].apply(lambda x :  datetime.datetime.strptime(x, '%Y.%m.%d %H:%M:%S')) 
    df_board['board_crawl_time'] =  board_crawl_time_l
    df_board['board_url'] =  board_url_l
    df_board['source'] = 'dc_gall'

    df_board['updated'] = (datetime.datetime.now() + datetime.timedelta(hours=9)).strftime("%Y%m%d-%H%M%S")
            
    df_board.to_sql('STOCK_GALLERY',conn,if_exists = 'append',index = False)
    print(datetime.datetime.now(), " CRAWL COMPLETED================== inserted data : ",len(df_board) )
    time.sleep(60 * 60)

# %%
df_ttl
# Out:
#                 SOURCE  RELATED_ITEM         DATETIME  \
# 0     dcinside_해외주식갤러리           NaN  20220825-124205
# 1     dcinside_해외주식갤러리           NaN  20220825-125409
# 2     dcinside_해외주식갤러리           NaN  20220825-125616
# 3     dcinside_해외주식갤러리           NaN  20220825-125712
# 4     dcinside_해외주식갤러리           NaN  20220825-125828
# ...                ...           ...              ...
# 8262  dcinside_해외주식갤러리           NaN  20220831-092648
# 8263  dcinside_해외주식갤러리           NaN  20220831-092904
# 8264  dcinside_해외주식갤러리           NaN  20220831-093542
# 8265  dcinside_해외주식갤러리           NaN  20220831-093736
# 8266  dcinside_해외주식갤러리           NaN  20220831-094101
#
#                                           TITLE  \
# 0             (홀)(짝)(홀)(짝)(홀)(?) - 해외주식 마이너 갤러리
# 1       월급받고 매일 5만원씩 달러환전 어케생각하냐 - 해외주식 마이너 갤러리
# 2                AMC,APE 오늘 장 예상 - 해외주식 마이너 갤러리
# 3                      야스각은 살아있다 - 해외주식 마이너 갤러리
# 4                 오늘 관심가질만한건 없나? - 해외주식 마이너 갤러리
# ...                                         ...
# 8262             환율때메 멀사길 망설여 지네 - 해외주식 마이너 갤러리
# 8263  Ahi 는 뭐 얼마나 대단한짓하길래 거래정지냐  - 해외주식 마이너 갤러리
# 8264      BBBY 병.신.들.아. 내 말들어봐ㅋㅋ - 해외주식 마이너 갤러리
# 8265             해주 친구들은 속고만 살았니 - 해외주식 마이너 갤러리
# 8266              뉴에이지 어케됨? 상폐임? - 해외주식 마이너 갤러리
#
#                                                 CONTENT  POSITIVITY  \
# 0                                           아직 안튄 흑우없제?    0.017420
# 1                         27 계약 3200  - dc official App    0.007051
# 2     오늘자로 한국 주주들도 APE 배당받았고 다른나라도 T3적용받으면 대부분이 오늘 받...    0.020652
# 3                                                          0.101114
# 4                   요근래 오늘은 언급되는게 별로 없네ㅋㅋㅋ 새로운 티커의 시작인가    0.011893
# ...                                                 ...         ...
# 8262                                                 ㅅㅂ    0.006399
# 8263                          별것도 없을거 같은데 존나 떨구기만해봐 ㅅㅂ     0.007065
# 8264  소문난 잔칫상에 먹을 거 없다.뉴스에 팔아라. 적어도 발표 2일전은 털으라했다.다신...    0.010902
# 8265  형아가 앞으로 급등주 미리미리 파악해서 알려줄게단!톡에 있으니 답답해서 하산 한건데...    0.007481
# 8266                               어제 거정 뚜두려 맞고 잠들었는디..    0.016574
#
#       NUM_REPLY                                                URL  \
# 0             3  https://gall.dcinside.com/mgallery/board/view/...
# 1             1  https://gall.dcinside.com/mgallery/board/view/...
# 2            14  https://gall.dcinside.com/mgallery/board/view/...
# 3             1  https://gall.dcinside.com/mgallery/board/view/...
# 4             6  https://gall.dcinside.com/mgallery/board/view/...
# ...         ...                                                ...
# 8262          1  https://gall.dcinside.com/mgallery/board/view/...
# 8263          0  https://gall.dcinside.com/mgallery/board/view/...
# 8264          1  https://gall.dcinside.com/mgallery/board/view/...
# 8265          8  https://gall.dcinside.com/mgallery/board/view/...
# 8266          0  https://gall.dcinside.com/mgallery/board/view/...
#
#      CRAWLING_DATETIME                                             OTHERS
# 0      20220831-094440  {'boards_ID': 4630000, 'board_reply': 3, 'boar...
# 1      20220831-094440  {'boards_ID': 4630001, 'board_reply': 1, 'boar...
# 2      20220831-094440  {'boards_ID': 4630002, 'board_reply': 14, 'boa...
# 3      20220831-094440  {'boards_ID': 4630003, 'board_reply': 1, 'boar...
# 4      20220831-094440  {'boards_ID': 4630004, 'board_reply': 6, 'boar...
# ...                ...                                                ...
# 8262   20220831-094440  {'boards_ID': 4638960, 'board_reply': 1, 'boar...
# 8263   20220831-094440  {'boards_ID': 4638961, 'board_reply': 0, 'boar...
# 8264   20220831-094440  {'boards_ID': 4638962, 'board_reply': 1, 'boar...
# 8265   20220831-094440  {'boards_ID': 4638963, 'board_reply': 8, 'boar...
# 8266   20220831-094440  {'boards_ID': 4638964, 'board_reply': 0, 'boar...
#
# [8267 rows x 10 columns]

# %%
if len(df_ttl) >0:
    df_ttl = df_ttl.reset_index(drop=True)

    df_ttl.to_sql('TABLE_BUZZ',conn,if_exists = 'append',index = False)
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " SUCCESS  : ",len(df_ttl))

else:
    print((datetime.now() + timedelta(hours=9)).strftime('%Y%m%d-%H%M%S') , " NO DATA TO UPDATE")
# Out:
# 20220831-135058  SUCCESS  :  2018
