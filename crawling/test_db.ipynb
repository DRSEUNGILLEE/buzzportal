# %%
import pandas as pd
import numpy as np
import datetime
import sqlite3

# %%
conn = sqlite3.connect("/home/lsi8505/miraeasset/crawling/opinion_outside.db")
cur = conn.cursor()
df_already= pd.read_sql(
"""
SELECT 
* 
FROM 
TABLE_BUZZ 
LIMIT 2000
"""

,conn)
df_already
# Out:
#          SOURCE RELATED_ITEM         DATETIME                    TITLE  \
# 0     네이버_종목토론실       미래에셋증권  20220816-125200                  고생 많으시네
# 1     네이버_종목토론실       미래에셋증권  20220816-121100                     환장하네
# 2     네이버_종목토론실       미래에셋증권  20220816-115900         주문  못하겠다 미  친눔들아
# 3     네이버_종목토론실       미래에셋증권  20220816-115500              개 더러운 주식...
# 4     네이버_종목토론실       미래에셋증권  20220816-114000      옛날 성국이형 있을때가 좋았다[1]
# ...         ...          ...              ...                      ...
# 1995  네이버_종목토론실       미래에셋증권  20220101-090900     올해는 개행주  현만이의 역대급저주로
# 1996  네이버_종목토론실       미래에셋증권  20211231-102600           배당금 얼마 주나요?[6]
# 1997  네이버_종목토론실       미래에셋증권  20211230-223000  왜 출금이 안되지.미래에셋증권 쓰는데[1]
# 1998  네이버_종목토론실       미래에셋증권  20211230-211100         개행주 현만이 쫏아내지 않는한
# 1999  네이버_종목토론실       미래에셋증권  20211230-141800                UBS88,411
#
#      CONTENT  POSITIVITY NUM_REPLY  \
# 0       None   99.635650         0
# 1       None    0.005247         0
# ...

# %%
df_already.SOURCE.unique()
# Out:
# array(['네이버_종목토론실'], dtype=object)

# %%
html_string = df_already.to_html(classes='data')
html_string
# Out:
# '<table border="1" class="dataframe data">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>SOURCE</th>\n      <th>RELATED_ITEM</th>\n      <th>DATETIME</th>\n      <th>TITLE</th>\n      <th>CONTENT</th>\n      <th>POSITIVITY</th>\n      <th>NUM_REPLY</th>\n      <th>URL</th>\n      <th>CRAWLING_DATETIME</th>\n      <th>OTHERS</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>네이버_종목토론실</td>\n      <td>미래에셋증권</td>\n      <td>20220816-125200</td>\n      <td>고생 많으시네</td>\n      <td>None</td>\n      <td>99.635650</td>\n      <td>0</td>\n      <td>https://finance.naver.com//item/board_read.naver?code=006800&amp;nid=228350234&amp;st=&amp;sw=&amp;page=2</td>\n      <td>20220817-143541</td>\n      <td>{\'WRITER\': \'odgy****\'}</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>네이버_종목토론실</td>\n      <td>미래에셋증권</td>\n      <td>20220816-121100</td>\n      <td>환장하네</td>\n      <td>None</td>\n      <td>0.005247</td>\n      <td>0</td>\n  
# ...

# %%
df_feeds.to_html(classes='data')

# %%
from bs4 import BeautifulSoup
print(BeautifulSoup(html_string, 'html.parser').prettify())
# Out:
# <table border="1" class="dataframe data">
#  <thead>
#   <tr style="text-align: right;">
#    <th>
#    </th>
#    <th>
#     SOURCE
#    </th>
#    <th>
#     RELATED_ITEM
#    </th>
#    <th>
#     DATETIME
#    </th>
#    <th>
#     TITLE
#    </th>
#    <th>
#     CONTENT
#    </th>
#    <th>
#     POSITIVITY
#    </th>
#    <th>
#     NUM_REPLY
#    </th>
#    <th>
#     URL
#    </th>
#    <th>
#     CRAWLING_DATETIME
#    </th>
#    <th>
#     OTHERS
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <th>
#     0
#    </th>
#    <td>
#     네이버_종목토론실
#    </td>
#    <td>
#     미래에셋증권
#    </td>
#    <td>
#     20220816-125200
#    </td>
#    <td>
#     고생 많으시네
#    </td>
#    <td>
#     None
#    </td>
#    <td>
#     99.635650
#    </td>
#    <td>
#     0
#    </td>
#    <td>
#     https://finance.naver.com//item/board_read.naver?code=006800&amp;nid=228350234&amp;st=&amp;sw=&amp;page=2
#    </td>
#    <td>
#     20220817-143541
#    </td>
#    <td>
# ...
